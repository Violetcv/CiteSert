# %%
from datetime import timedelta
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
# Load the filtered DataFrame from the CSV file
# Define the file path
file_path = r'C:\Users\disch\Desktop\CiteSert\Project_1\Version3_40krows_n1\input_data\filtered_data_2_n1.csv'


# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

df = df.dropna(subset=['expected_return', 'actual_return'])


# Display the first few rows of the DataFrame to verify it loaded correctly
print(df.head())
# Out:
#           date                    Company Name      Symbol  \
# 0   2015-11-16  speciality restaurants limited  SPECIALITY
# 1   2015-08-13  speciality restaurants limited  SPECIALITY
# 8   2024-05-17           eicher motors limited   EICHERMOT
# 9   2024-05-13           eicher motors limited   EICHERMOT
# 11  2024-05-13           eicher motors limited   EICHERMOT
#
#                       author         Sector  expected_return  actual_return
# 0                      Karvy     Technology         9.432421       0.025820
# 1        Reliance Securities     Technology         7.189542      -0.013226
# 8   BOB Capital Markets Ltd.  Manufacturing        -1.297429       0.004935
# 9               ICICI Direct  Manufacturing        18.090371       0.013530
# 11               Axis Direct  Manufacturing        10.253465       0.013530

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35107 entries, 0 to 41819
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             35107 non-null  object
#  1   Company Name     35107 non-null  object
#  2   Symbol           35107 non-null  object
#  3   author           35107 non-null  object
#  4   Sector           35107 non-null  object
#  5   expected_return  35107 non-null  float64
#  6   actual_return    35107 non-null  float64
# dtypes: float64(2), object(5)
# memory usage: 2.1+ MB

# %%
def calculate_correlation(expected_returns, actual_returns):
    """
    Calculate the correlation between expected and actual returns,
    ensuring no division by zero occurs.
    
    Args:
        expected_returns (pd.Series): Expected returns.
        actual_returns (pd.Series): Actual returns.

    Returns:
        float: Correlation coefficient, or NaN if not calculable.
    """
    # Check standard deviation to avoid division by zero
    if np.std(expected_returns) == 0 or np.std(actual_returns) == 0:
        return np.nan
    
    # Calculate correlation
    return np.corrcoef(expected_returns, actual_returns)[0, 1]

# %%
def get_best_authors_by_sector(df, start_date, end_date, corr_threshold, perf_threshold, max_authors=10):
    """
    Identify the best-performing authors per sector within a specific date range based on 
    correlation and mean performance thresholds.
    """
    print("\n### get_best_authors_by_sector ###")
    print(f"Start Date: {start_date}, End Date: {end_date}")
    print(f"Max Authors per Sector: {max_authors}, Correlation Threshold: {corr_threshold}, Performance Threshold: {perf_threshold}")
    
    # Convert date column to datetime if necessary
    df['date'] = pd.to_datetime(df['date'])
    
    # Filter data for the specified date range
    period_df = df[(df['date'] >= start_date) & (df['date'] <= end_date)].copy()
    print(f"Filtered Data Shape: {period_df.shape}")

    if period_df.empty:
        print("No data available for the specified date range.")
        return pd.DataFrame(columns=['Sector', 'author', 'correlation', 'mean_performance'])

    # Calculate performance metrics for each sector-author pair
    author_sector_performance = []
    grouped = period_df.groupby(['Sector', 'author'])
    print(f"Number of Sector-Author Groups: {len(grouped)}")

    for (sector, author), group in grouped:
        print(f"\nProcessing Sector: {sector}, Author: {author}")
        print(f"Group Size: {len(group)}")

        if len(group) == 1:  # Ensure enough data points for correlation calculation
            correlation = -1
            continue

        # Compute correlation between expected and actual returns
        correlation = calculate_correlation(group['expected_return'], group['actual_return'])
        print(f"Correlation: {correlation}")

        # Compute mean performance
        group['performance'] = np.sign(group['expected_return']) * group['actual_return']
        mean_performance = group['performance'].mean()
        print(f"Mean Performance: {mean_performance}")

        # Store results if thresholds are met
        if not np.isnan(correlation) and correlation > corr_threshold and mean_performance > perf_threshold:
            print("Thresholds met. Adding to results.")
            author_sector_performance.append({
                'Sector': sector,
                'author': author,
                'correlation': correlation,
                'mean_performance': mean_performance
            })
        else:
            continue
            print("Thresholds not met. Skipping.")

    # Create a DataFrame from the results
    performance_df = pd.DataFrame(author_sector_performance)
    print(f"\nPerformance DataFrame Shape: {performance_df.shape}")

    if performance_df.empty:
        print("No authors met the thresholds.")
        return pd.DataFrame(columns=['Sector', 'author', 'correlation', 'mean_performance'])

    # Sort authors by correlation and mean performance, and retain top authors per sector
    print("Sorting and selecting top authors by sector.")
    top_authors_df = (performance_df
                      .sort_values(['correlation', 'mean_performance'], ascending=[False, False])
                      .groupby('Sector')
                      .head(max_authors)
                      .reset_index(drop=True))
    print(f"Top Authors DataFrame Shape: {top_authors_df.shape}")
    print(f"Top Authors DataFrame Sample:\n{top_authors_df}")

    return top_authors_df

# %%
def calculate_monthly_performance(df, best_authors_df, target_month):
    """
    Calculate performance for each author-sector pair for a specific month
    using sign(expected_return) * actual_return
    """
    print(f"\nCalculating monthly performance for: {target_month.strftime('%Y-%m')}")

    # Define month range
    month_start = target_month.replace(day=1)
    month_end = (month_start + pd.offsets.MonthEnd(1))
    print(f"Month Start: {month_start}, Month End: {month_end}")

    # Filter data for the target month
    mask = (df['date'] >= month_start) & (df['date'] <= month_end)
    month_df = df[mask].copy()
    print(f"Filtered Data for Month: {month_df.shape[0]} rows")

    # Merge with best authors
    print(f"Best Authors DataFrame Shape: {best_authors_df.shape}")
    month_df = month_df.merge(
        best_authors_df[['Sector', 'author']],
        on=['Sector', 'author'],
        how='inner'
    )
    print(f"Data After Merging with Best Authors: {month_df.shape[0]} rows")

    # Calculate performance
    month_df['performance'] = np.sign(month_df['expected_return']) * month_df['actual_return']
    print(f"Performance Column Calculated. Sample Data:\n{month_df[['Sector', 'author', 'performance']].head()}")

    # Group and summarize performance
    performance_summary = (month_df.groupby(['Sector', 'author'])
                           ['performance']
                           .agg(mean_performance='mean', count='count')
                           .reset_index())
    performance_summary['month'] = month_start
    print(f"Performance Summary for {target_month.strftime('%Y-%m')}:\n{performance_summary.head()}")

    return performance_summary

def run_rolling_analysis(df, start_date, end_date, a, b, lookback_period=12):
    """
    Run the rolling analysis month by month
    """
    print("\nStarting Rolling Analysis")
    print(f"Start Date: {start_date}, End Date: {end_date}, Lookback Period: {lookback_period} months")
    print(f"Thresholds: Correlation (a={a}), Performance (b={b})")

    # Convert dates if they're strings
    start_date = pd.to_datetime(start_date)
    end_date = pd.to_datetime(end_date)

    all_monthly_performance = []
    current_date = start_date

    while current_date <= end_date:
        print(f"\nProcessing Month: {current_date.strftime('%Y-%m')}")
        
        # Define training period
        training_end = current_date - timedelta(days=1)
        training_start = training_end - pd.DateOffset(months=lookback_period)
        print(f"Training Period: Start {training_start}, End {training_end}")

        # Get best authors
        best_authors = get_best_authors_by_sector(df, training_start, training_end, a, b)
        print(f"Best Authors DataFrame Shape: {best_authors.shape}")

        # Calculate performance for the current month
        if not best_authors.empty:
            monthly_perf = calculate_monthly_performance(df, best_authors, current_date)
            all_monthly_performance.append(monthly_perf)

            print(f"Monthly Performance for {current_date.strftime('%Y-%m')}:\n", monthly_perf.head())
        else:
            print(f"No Best Authors Found for {current_date.strftime('%Y-%m')}")

        # Move to next month
        current_date = current_date + pd.DateOffset(months=1)

    # Combine all results
    if all_monthly_performance:
        combined_results = pd.concat(all_monthly_performance, ignore_index=True)
        print(f"\nCombined Performance DataFrame Shape: {combined_results.shape}")
        return combined_results
    else:
        print("No performance data collected.")
        return pd.DataFrame()

# %%
def main(df):
    """
    Main function to analyze performance based on correlation and performance thresholds
    using a grid search approach.
    """
    print("\n### MAIN FUNCTION STARTED ###")

    # Convert date column to datetime if it's not already
    print("\nConverting 'date' column to datetime format.")
    df['date'] = pd.to_datetime(df['date'], errors='coerce')
    
    # Define the grid for correlation and performance thresholds
    print("\nDefining thresholds grid for correlation and performance.")
    correlation_thresholds = np.arange(0, 0.011, 0.01)
    performance_thresholds = np.arange(0, 0.011, 0.01)
    print(f"Correlation Thresholds: {correlation_thresholds}")
    print(f"Performance Thresholds: {performance_thresholds}")
    
    # Initialize a dictionary to store results for each iteration
    all_results = {}
    iteration_results = []
    iteration = 0

    print("\n### Starting grid search ###")
    
    # Iterate over the grid of thresholds
    for a in tqdm(correlation_thresholds, desc="Correlation Thresholds"):
        for b in tqdm(performance_thresholds, desc="Performance Thresholds", leave=False):
            print(f"\nGrid Combination - Correlation Threshold: {a}, Performance Threshold: {b}")
            
            # Run the rolling analysis
            try:
                print("Running rolling analysis for the current thresholds.")
                results_df = run_rolling_analysis(
                    df,
                    start_date='2014-06-01',
                    end_date='2022-12-31',
                    lookback_period=12,
                    a=a,
                    b=b
                )
                print(f"Rolling Analysis Completed. Results Shape: {results_df.shape}")
            except Exception as e:
                print(f"Error during rolling analysis for a={a}, b={b}: {e}")
                results_df = pd.DataFrame()  # Empty DataFrame in case of errors
            
            # Calculate mean performance for the iteration
            if not results_df.empty and 'mean_performance' in results_df.columns:
                mean_of_mean_performance = results_df['mean_performance'].mean()
                print(f"Mean of Mean Performance for Current Thresholds: {mean_of_mean_performance:.4f}")
            else:
                print("Column 'mean_performance' not found or results_df is empty. Assigning NaN.")
                mean_of_mean_performance = np.nan

            # Calculate rows selected per month
            if not results_df.empty and 'date' in results_df.columns:
                number_of_monthly_predictions = results_df['count'].mean()
                print(f"Mean of Counts Per Month for Thresholds a={a}, b={b}:\n{number_of_monthly_predictions}")
            else:
                print("No valid data for rows selected per month calculation.")
                number_of_monthly_predictions = np.nan

            
            # Save the results DataFrame for the iteration
            iteration_key = f"iter_{iteration}_a_{a}_b_{b}"
            all_results[iteration_key] = results_df
            print(f"Iteration {iteration_key}: Results Saved.")
            
            # Append the iteration result
            iteration_results.append({
                'correlation_threshold': a,
                'performance_threshold': b,
                'mean_of_mean_performance': mean_of_mean_performance,
                'number_of_monthly_predictions': number_of_monthly_predictions
            })
            
            # Increment iteration counter
            iteration += 1

    # Convert iteration results to a DataFrame for analysis
    print("\nConverting iteration results to a DataFrame for final analysis.")
    grid_performance_df = pd.DataFrame(iteration_results)
    print(f"Grid Performance DataFrame Shape: {grid_performance_df.shape}")
    print(f"Grid Performance DataFrame Head:\n{grid_performance_df.head()}")

    # Handle case where no valid data is available
    if grid_performance_df.empty:
        print("\nNo valid data available. Ensure the input data and thresholds are correct.")
    else:
        print("\nGrid Performance DataFrame successfully created.")

    print("\n### MAIN FUNCTION COMPLETED ###")
    return all_results, grid_performance_df

# %%
all_results, grid_performance_df = main(df)
# Out:
# ### MAIN FUNCTION STARTED ###
#
# Converting 'date' column to datetime format.
#
# Defining thresholds grid for correlation and performance.
# Correlation Thresholds: [0.   0.01]
# Performance Thresholds: [0.   0.01]
#
# ### Starting grid search ###
# Correlation Thresholds:   0%|                                                                    | 0/2 [00:00<?, ?it/s]
# Performance Thresholds:   0%|                                                                    | 0/2 [00:00<?, ?it/s]
# Grid Combination - Correlation Threshold: 0.0, Performance Threshold: 0.0
# Running rolling analysis for the current thresholds.
#
# Starting Rolling Analysis
# Start Date: 2014-06-01, End Date: 2022-12-31, Lookback Period: 12 months
# Thresholds: Correlation (a=0.0), Performance (b=0.0)
#
# Processing Month: 2014-06
# Training Period: Start 2013-05-31 00:00:00, End 2014-05-31 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2013-05-31 00:00:00, End Date: 2014-05-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (129, 7)
# Number of Sector-Author Groups: 24
#
# Processing Sector: Agriculture, Author: Chola Wealth Direct
# Group Size: 2
# Correlation: 1.0
# Mean Performance: -0.0068251087563013495
#
# Processing Sector: Consumer Goods, Author: Ashika Research
# Group Size: 2
# Correlation: -1.0
# Mean Performance: 0.0294873137575189
#
# Processing Sector: Consumer Goods, Author: Chola Wealth Direct
# Group Size: 4
# Correlation: -0.987788164549611
# Mean Performance: -0.008422075039376576
#
# Processing Sector: Consumer Goods, Author: Reliance Securities
# Group Size: 1
#
# Processing Sector: Consumer Goods, Author: Systematix Group
# Group Size: 1
#
# Processing Sector: Energy, Author: Chola Wealth Direct
# Group Size: 4
# Correlation: 0.7339417566914485
# Mean Performance: 0.0032756124434924
# Thresholds met. Adding to results.
#
# Processing Sector: Finance, Author: Ajcon Global
# Group Size: 1
#
# Processing Sector: Finance, Author: Ashika Research
# Group Size: 5
# Correlation: 0.32296206334784006
# Mean Performance: 0.01979124315093234
# Thresholds met. Adding to results.
#
# Processing Sector: Finance, Author: Chola Wealth Direct
# Group Size: 33
# Correlation: 0.11316534738616925
# Mean Performance: -0.0021146624547803733
#
# Processing Sector: Finance, Author: GEPL Capital
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Ajcon Global
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Ashika Research
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Chola Wealth Direct
# Group Size: 12
# Correlation: 0.20985189389162703
# Mean Performance: -0.006456132851656357
#
# Processing Sector: Healthcare, Author: Reliance Securities
# Group Size: 3
# Correlation: 0.4320876108953363
# Mean Performance: 0.010185701047142934
# Thresholds met. Adding to results.
#
# Processing Sector: Manufacturing, Author: Ashika Research
# Group Size: 2
# Correlation: 1.0
# Mean Performance: -0.0032666726421122
#
# Processing Sector: Manufacturing, Author: Chola Wealth Direct
# Group Size: 23
# Correlation: 0.039054534238953234
# Mean Performance: -0.0040478773187625225
#
# Processing Sector: Manufacturing, Author: Systematix Group
# Group Size: 1
#
# Processing Sector: Real Estate, Author: Chola Wealth Direct
# Group Size: 2
# Correlation: -1.0
# Mean Performance: -0.0011617640134878003
#
# Processing Sector: Technology, Author: Ajcon Global
# Group Size: 1
#
# Processing Sector: Technology, Author: Ashika Research
# Group Size: 2
# Correlation: -1.0
# Mean Performance: 0.028126989376214197
#
# Processing Sector: Technology, Author: Chola Wealth Direct
# Group Size: 21
# Correlation: 0.12129790027695937
# Mean Performance: 0.003926458683498835
# Thresholds met. Adding to results.
#
# Processing Sector: Technology, Author: Reliance Securities
# Group Size: 1
#
# Processing Sector: Unknown, Author: Chola Wealth Direct
# Group Size: 4
# Correlation: -0.1275359263137706
# Mean Performance: -0.0007599356345358
#
# Processing Sector: Utilities, Author: Ashika Research
# Group Size: 1
#
# Performance DataFrame Shape: (4, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (4, 4)
# Top Authors DataFrame Sample:
#        Sector               author  correlation  mean_performance
# 0      Energy  Chola Wealth Direct     0.733942          0.003276
# 1  Healthcare  Reliance Securities     0.432088          0.010186
# 2     Finance      Ashika Research     0.322962          0.019791
# 3  Technology  Chola Wealth Direct     0.121298          0.003926
# Best Authors DataFrame Shape: (4, 4)
#
# Calculating monthly performance for: 2014-06
# Month Start: 2014-06-01 00:00:00, Month End: 2014-06-30 00:00:00
# Filtered Data for Month: 5 rows
# Best Authors DataFrame Shape: (4, 4)
# Data After Merging with Best Authors: 1 rows
# Performance Column Calculated. Sample Data:
#    Sector               author  performance
# 0  Energy  Chola Wealth Direct    -0.007949
# Performance Summary for 2014-06:
#    Sector               author  mean_performance  count      month
# 0  Energy  Chola Wealth Direct         -0.007949      1 2014-06-01
# Monthly Performance for 2014-06:
#     Sector               author  mean_performance  count      month
# 0  Energy  Chola Wealth Direct         -0.007949      1 2014-06-01
#
# Processing Month: 2014-07
# Training Period: Start 2013-06-30 00:00:00, End 2014-06-30 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2013-06-30 00:00:00, End Date: 2014-06-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (126, 7)
# Number of Sector-Author Groups: 23
#
# Processing Sector: Agriculture, Author: Chola Wealth Direct
# Group Size: 3
# Correlation: 0.41424413951820466
# Mean Performance: -0.0026001814366627663
#
# Processing Sector: Consumer Goods, Author: Ashika Research
# Group Size: 2
# Correlation: -1.0
# Mean Performance: 0.0294873137575189
#
# Processing Sector: Consumer Goods, Author: Chola Wealth Direct
# Group Size: 5
# Correlation: -0.7796231436641226
# Mean Performance: -0.00609264736160954
#
# Processing Sector: Consumer Goods, Author: Reliance Securities
# Group Size: 1
#
# Processing Sector: Consumer Goods, Author: Systematix Group
# Group Size: 1
#
# Processing Sector: Energy, Author: Chola Wealth Direct
# Group Size: 4
# Correlation: 0.9040424015090553
# Mean Performance: -0.003227999429252075
#
# Processing Sector: Finance, Author: Ajcon Global
# Group Size: 1
#
# Processing Sector: Finance, Author: Ashika Research
# Group Size: 5
# Correlation: 0.32296206334784006
# Mean Performance: 0.01979124315093234
# Thresholds met. Adding to results.
#
# Processing Sector: Finance, Author: Chola Wealth Direct
# Group Size: 34
# Correlation: 0.020486630622205678
# Mean Performance: -0.00034468661408000286
#
# Processing Sector: Finance, Author: GEPL Capital
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Ajcon Global
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Ashika Research
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Chola Wealth Direct
# Group Size: 12
# Correlation: 0.8168932349641187
# Mean Performance: -0.005962883934978451
#
# Processing Sector: Healthcare, Author: Reliance Securities
# Group Size: 3
# Correlation: 0.4320876108953363
# Mean Performance: 0.010185701047142934
# Thresholds met. Adding to results.
#
# Processing Sector: Manufacturing, Author: Ashika Research
# Group Size: 2
# Correlation: 1.0
# Mean Performance: -0.0032666726421122
#
# Processing Sector: Manufacturing, Author: Chola Wealth Direct
# Group Size: 20
# Correlation: -0.14417698807724125
# Mean Performance: -0.005366531153417425
#
# Processing Sector: Manufacturing, Author: Systematix Group
# Group Size: 1
#
# Processing Sector: Real Estate, Author: Chola Wealth Direct
# Group Size: 2
# Correlation: -1.0
# Mean Performance: -0.0011617640134878003
#
# Processing Sector: Technology, Author: Ajcon Global
# Group Size: 1
#
# Processing Sector: Technology, Author: Ashika Research
# Group Size: 2
# Correlation: -1.0
# Mean Performance: 0.028126989376214197
#
# Processing Sector: Technology, Author: Chola Wealth Direct
# Group Size: 19
# Correlation: 0.09614398698192515
# Mean Performance: 0.005833826175119585
# Thresholds met. Adding to results.
#
# Processing Sector: Technology, Author: Reliance Securities
# Group Size: 1
#
# Processing Sector: Unknown, Author: Chola Wealth Direct
# Group Size: 4
# Correlation: -0.1275359263137706
# Mean Performance: -0.0007599356345358
#
# Performance DataFrame Shape: (3, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (3, 4)
# Top Authors DataFrame Sample:
#        Sector               author  correlation  mean_performance
# 0  Healthcare  Reliance Securities     0.432088          0.010186
# 1     Finance      Ashika Research     0.322962          0.019791
# 2  Technology  Chola Wealth Direct     0.096144          0.005834
# Best Authors DataFrame Shape: (3, 4)
#
# Calculating monthly performance for: 2014-07
# Month Start: 2014-07-01 00:00:00, Month End: 2014-07-31 00:00:00
# Filtered Data for Month: 15 rows
# Best Authors DataFrame Shape: (3, 4)
# Data After Merging with Best Authors: 2 rows
# Performance Column Calculated. Sample Data:
#        Sector               author  performance
# 0  Technology  Chola Wealth Direct    -0.026299
# 1  Healthcare  Reliance Securities    -0.038635
# Performance Summary for 2014-07:
#        Sector               author  mean_performance  count      month
# 0  Healthcare  Reliance Securities         -0.038635      1 2014-07-01
# 1  Technology  Chola Wealth Direct         -0.026299      1 2014-07-01
# Monthly Performance for 2014-07:
#         Sector               author  mean_performance  count      month
# 0  Healthcare  Reliance Securities         -0.038635      1 2014-07-01
# 1  Technology  Chola Wealth Direct         -0.026299      1 2014-07-01
#
# Processing Month: 2014-08
# Training Period: Start 2013-07-31 00:00:00, End 2014-07-31 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2013-07-31 00:00:00, End Date: 2014-07-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (134, 7)
# Number of Sector-Author Groups: 24
#
# Processing Sector: Agriculture, Author: Chola Wealth Direct
# Group Size: 3
# Correlation: 0.41424413951820466
# Mean Performance: -0.0026001814366627663
#
# Processing Sector: Consumer Goods, Author: Ashika Research
# Group Size: 2
# Correlation: -1.0
# Mean Performance: 0.0294873137575189
#
# Processing Sector: Consumer Goods, Author: Chola Wealth Direct
# Group Size: 5
# Correlation: -0.7796231436641226
# Mean Performance: -0.00609264736160954
#
# Processing Sector: Consumer Goods, Author: Reliance Securities
# Group Size: 1
#
# Processing Sector: Consumer Goods, Author: Systematix Group
# Group Size: 1
#
# Processing Sector: Energy, Author: Chola Wealth Direct
# Group Size: 4
# Correlation: 0.9040424015090553
# Mean Performance: -0.003227999429252075
#
# Processing Sector: Finance, Author: Ashika Research
# Group Size: 5
# Correlation: 0.32296206334784006
# Mean Performance: 0.01979124315093234
# Thresholds met. Adding to results.
#
# Processing Sector: Finance, Author: Chola Wealth Direct
# Group Size: 38
# Correlation: 0.11844436439708864
# Mean Performance: 0.0019821481009619606
# Thresholds met. Adding to results.
#
# Processing Sector: Finance, Author: GEPL Capital
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Ajcon Global
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Ashika Research
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Chola Wealth Direct
# Group Size: 12
# Correlation: 0.8168932349641187
# Mean Performance: -0.005962883934978451
#
# Processing Sector: Healthcare, Author: GEPL Capital
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Reliance Securities
# Group Size: 4
# Correlation: 0.6593144370326508
# Mean Performance: -0.0020195815923657497
#
# Processing Sector: Manufacturing, Author: Ashika Research
# Group Size: 2
# Correlation: 1.0
# Mean Performance: -0.0032666726421122
#
# Processing Sector: Manufacturing, Author: Chola Wealth Direct
# Group Size: 20
# Correlation: -0.210975708164498
# Mean Performance: -0.004673337037382984
#
# Processing Sector: Manufacturing, Author: Systematix Group
# Group Size: 1
#
# Processing Sector: Real Estate, Author: Chola Wealth Direct
# Group Size: 2
# Correlation: -1.0
# Mean Performance: -0.0011617640134878003
#
# Processing Sector: Technology, Author: Ajcon Global
# Group Size: 1
#
# Processing Sector: Technology, Author: Ashika Research
# Group Size: 2
# Correlation: -1.0
# Mean Performance: 0.028126989376214197
#
# Processing Sector: Technology, Author: Chola Wealth Direct
# Group Size: 20
# Correlation: 0.12345797005709909
# Mean Performance: 0.004227181239124371
# Thresholds met. Adding to results.
#
# Processing Sector: Technology, Author: Karvy
# Group Size: 2
# Correlation: 1.0
# Mean Performance: -0.0063540677429566005
#
# Processing Sector: Technology, Author: Reliance Securities
# Group Size: 1
#
# Processing Sector: Unknown, Author: Chola Wealth Direct
# Group Size: 4
# Correlation: -0.1275359263137706
# Mean Performance: -0.0007599356345358
#
# Performance DataFrame Shape: (3, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (3, 4)
# Top Authors DataFrame Sample:
#        Sector               author  correlation  mean_performance
# 0     Finance      Ashika Research     0.322962          0.019791
# 1  Technology  Chola Wealth Direct     0.123458          0.004227
# 2     Finance  Chola Wealth Direct     0.118444          0.001982
# Best Authors DataFrame Shape: (3, 4)
#
# Calculating monthly performance for: 2014-08
# Month Start: 2014-08-01 00:00:00, Month End: 2014-08-31 00:00:00
# Filtered Data for Month: 20 rows
# Best Authors DataFrame Shape: (3, 4)
# Data After Merging with Best Authors: 8 rows
# Performance Column Calculated. Sample Data:
#        Sector               author  performance
# 0     Finance  Chola Wealth Direct     0.000903
# 1     Finance  Chola Wealth Direct    -0.031264
# 2  Technology  Chola Wealth Direct    -0.012935
# 3     Finance  Chola Wealth Direct     0.036677
# 4  Technology  Chola Wealth Direct    -0.001773
# Performance Summary for 2014-08:
#        Sector               author  mean_performance  count      month
# 0     Finance  Chola Wealth Direct          0.002723      4 2014-08-01
# 1  Technology  Chola Wealth Direct         -0.010966      4 2014-08-01
# Monthly Performance for 2014-08:
#         Sector               author  mean_performance  count      month
# 0     Finance  Chola Wealth Direct          0.002723      4 2014-08-01
# 1  Technology  Chola Wealth Direct         -0.010966      4 2014-08-01
#
# Processing Month: 2014-09
# Training Period: Start 2013-08-31 00:00:00, End 2014-08-31 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2013-08-31 00:00:00, End Date: 2014-08-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (131, 7)
# Number of Sector-Author Groups: 22
#
# Processing Sector: Agriculture, Author: Chola Wealth Direct
# Group Size: 3
# Correlation: 0.41424413951820466
# Mean Performance: -0.0026001814366627663
#
# Processing Sector: Consumer Goods, Author: Ashika Research
# Group Size: 1
#
# Processing Sector: Consumer Goods, Author: Chola Wealth Direct
# Group Size: 6
# Correlation: -0.8353780859068541
# Mean Performance: 0.004392666788401316
#
# Processing Sector: Consumer Goods, Author: Reliance Securities
# Group Size: 1
#
# Processing Sector: Energy, Author: Chola Wealth Direct
# Group Size: 4
# Correlation: -0.1715617339989049
# Mean Performance: -0.0020118283290542502
#
# Processing Sector: Finance, Author: Ashika Research
# Group Size: 3
# Correlation: 0.032910380914346414
# Mean Performance: 0.010253322906227802
# Thresholds met. Adding to results.
#
# Processing Sector: Finance, Author: Chola Wealth Direct
# Group Size: 38
# Correlation: 0.098958961105073
# Mean Performance: 0.0022305540172158447
# Thresholds met. Adding to results.
#
# Processing Sector: Finance, Author: GEPL Capital
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Ajcon Global
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Ashika Research
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Chola Wealth Direct
# Group Size: 11
# Correlation: 0.499441238059027
# Mean Performance: -0.005190814281202364
#
# Processing Sector: Healthcare, Author: GEPL Capital
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Reliance Securities
# Group Size: 5
# Correlation: 0.28945979128778815
# Mean Performance: -0.0017465553262486194
#
# Processing Sector: Manufacturing, Author: Ashika Research
# Group Size: 1
#
# Processing Sector: Manufacturing, Author: Chola Wealth Direct
# Group Size: 21
# Correlation: -0.12828340635102112
# Mean Performance: -0.0035617073506699942
#
# Processing Sector: Real Estate, Author: Chola Wealth Direct
# Group Size: 3
# Correlation: -0.25253032792416713
# Mean Performance: -0.002984495483090066
#
# Processing Sector: Technology, Author: Ajcon Global
# Group Size: 1
#
# Processing Sector: Technology, Author: Ashika Research
# Group Size: 2
# Correlation: -1.0
# Mean Performance: 0.028126989376214197
#
# Processing Sector: Technology, Author: Chola Wealth Direct
# Group Size: 19
# Correlation: 0.15206223787404877
# Mean Performance: -0.00043071082354597946
#
# Processing Sector: Technology, Author: Karvy
# Group Size: 2
# Correlation: 1.0
# Mean Performance: -0.0063540677429566005
#
# Processing Sector: Technology, Author: Reliance Securities
# Group Size: 1
#
# Processing Sector: Unknown, Author: Chola Wealth Direct
# Group Size: 5
# Correlation: 0.4809266955004953
# Mean Performance: 0.00588344369467544
# Thresholds met. Adding to results.
#
# Performance DataFrame Shape: (3, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (3, 4)
# Top Authors DataFrame Sample:
#     Sector               author  correlation  mean_performance
# 0  Unknown  Chola Wealth Direct     0.480927          0.005883
# 1  Finance  Chola Wealth Direct     0.098959          0.002231
# 2  Finance      Ashika Research     0.032910          0.010253
# Best Authors DataFrame Shape: (3, 4)
#
# Calculating monthly performance for: 2014-09
# Month Start: 2014-09-01 00:00:00, Month End: 2014-09-30 00:00:00
# Filtered Data for Month: 4 rows
# Best Authors DataFrame Shape: (3, 4)
# Data After Merging with Best Authors: 0 rows
# Performance Column Calculated. Sample Data:
# Empty DataFrame
# Columns: [Sector, author, performance]
# Index: []
# Performance Summary for 2014-09:
# Empty DataFrame
# Columns: [Sector, author, mean_performance, count, month]
# Index: []
# Monthly Performance for 2014-09:
#  Empty DataFrame
# Columns: [Sector, author, mean_performance, count, month]
# Index: []
#
# Processing Month: 2014-10
# Training Period: Start 2013-09-30 00:00:00, End 2014-09-30 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2013-09-30 00:00:00, End Date: 2014-09-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (133, 7)
# Number of Sector-Author Groups: 21
#
# Processing Sector: Agriculture, Author: Chola Wealth Direct
# Group Size: 3
# Correlation: 0.41424413951820466
# Mean Performance: -0.0026001814366627663
#
# Processing Sector: Consumer Goods, Author: Chola Wealth Direct
# Group Size: 6
# Correlation: -0.8353780859068541
# Mean Performance: 0.004392666788401316
#
# Processing Sector: Consumer Goods, Author: Reliance Securities
# Group Size: 1
#
# Processing Sector: Energy, Author: Chola Wealth Direct
# Group Size: 4
# Correlation: -0.1715617339989049
# Mean Performance: -0.0020118283290542502
#
# Processing Sector: Finance, Author: Ashika Research
# Group Size: 3
# Correlation: 0.032910380914346414
# Mean Performance: 0.010253322906227802
# Thresholds met. Adding to results.
#
# Processing Sector: Finance, Author: Chola Wealth Direct
# Group Size: 38
# Correlation: 0.098958961105073
# Mean Performance: 0.0022305540172158447
# Thresholds met. Adding to results.
#
# Processing Sector: Finance, Author: GEPL Capital
# Group Size: 1
#
# Processing Sector: Finance, Author: Karvy
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Ajcon Global
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Chola Wealth Direct
# Group Size: 11
# Correlation: 0.499441238059027
# Mean Performance: -0.005190814281202364
#
# Processing Sector: Healthcare, Author: GEPL Capital
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Reliance Securities
# Group Size: 5
# Correlation: 0.28945979128778815
# Mean Performance: -0.0017465553262486194
#
# Processing Sector: Manufacturing, Author: Ashika Research
# Group Size: 4
# Correlation: 0.07382179741729578
# Mean Performance: -0.0044578681604869755
#
# Processing Sector: Manufacturing, Author: Chola Wealth Direct
# Group Size: 21
# Correlation: -0.12828340635102112
# Mean Performance: -0.0035617073506699942
#
# Processing Sector: Real Estate, Author: Chola Wealth Direct
# Group Size: 3
# Correlation: -0.25253032792416713
# Mean Performance: -0.002984495483090066
#
# Processing Sector: Technology, Author: Ajcon Global
# Group Size: 1
#
# Processing Sector: Technology, Author: Ashika Research
# Group Size: 2
# Correlation: -1.0
# Mean Performance: 0.028126989376214197
#
# Processing Sector: Technology, Author: Chola Wealth Direct
# Group Size: 19
# Correlation: 0.15206223787404877
# Mean Performance: -0.00043071082354597946
#
# Processing Sector: Technology, Author: Karvy
# Group Size: 2
# Correlation: 1.0
# Mean Performance: -0.0063540677429566005
#
# Processing Sector: Technology, Author: Reliance Securities
# Group Size: 1
#
# Processing Sector: Unknown, Author: Chola Wealth Direct
# Group Size: 5
# Correlation: 0.4809266955004953
# Mean Performance: 0.00588344369467544
# Thresholds met. Adding to results.
#
# Performance DataFrame Shape: (3, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (3, 4)
# Top Authors DataFrame Sample:
#     Sector               author  correlation  mean_performance
# 0  Unknown  Chola Wealth Direct     0.480927          0.005883
# 1  Finance  Chola Wealth Direct     0.098959          0.002231
# 2  Finance      Ashika Research     0.032910          0.010253
# Best Authors DataFrame Shape: (3, 4)
#
# Calculating monthly performance for: 2014-10
# Month Start: 2014-10-01 00:00:00, Month End: 2014-10-31 00:00:00
# Filtered Data for Month: 17 rows
# Best Authors DataFrame Shape: (3, 4)
# Data After Merging with Best Authors: 8 rows
# Performance Column Calculated. Sample Data:
#     Sector               author  performance
# 0  Unknown  Chola Wealth Direct    -0.005961
# 1  Finance  Chola Wealth Direct    -0.013336
# 2  Finance  Chola Wealth Direct     0.010910
# 3  Finance  Chola Wealth Direct     0.005181
# 4  Finance  Chola Wealth Direct    -0.008281
# Performance Summary for 2014-10:
#     Sector               author  mean_performance  count      month
# 0  Finance  Chola Wealth Direct         -0.004784      7 2014-10-01
# 1  Unknown  Chola Wealth Direct         -0.005961      1 2014-10-01
# Monthly Performance for 2014-10:
#      Sector               author  mean_performance  count      month
# 0  Finance  Chola Wealth Direct         -0.004784      7 2014-10-01
# 1  Unknown  Chola Wealth Direct         -0.005961      1 2014-10-01
#
# Processing Month: 2014-11
# Training Period: Start 2013-10-31 00:00:00, End 2014-10-31 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2013-10-31 00:00:00, End Date: 2014-10-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (142, 7)
# Number of Sector-Author Groups: 21
#
# Processing Sector: Agriculture, Author: Chola Wealth Direct
# Group Size: 3
# Correlation: 0.41424413951820466
# Mean Performance: -0.0026001814366627663
#
# Processing Sector: Consumer Goods, Author: Chola Wealth Direct
# Group Size: 8
# Correlation: -0.23171986081513352
# Mean Performance: 0.008822374403161963
#
# Processing Sector: Consumer Goods, Author: Reliance Securities
# Group Size: 1
#
# Processing Sector: Energy, Author: Chola Wealth Direct
# Group Size: 3
# Correlation: 0.038952701913287195
# Mean Performance: -0.0009751494169563668
#
# Processing Sector: Finance, Author: Ashika Research
# Group Size: 3
# Correlation: 0.032910380914346414
# Mean Performance: 0.010253322906227802
# Thresholds met. Adding to results.
#
# Processing Sector: Finance, Author: Chola Wealth Direct
# Group Size: 41
# Correlation: 0.02679763654927285
# Mean Performance: 0.00020377215118229798
# Thresholds met. Adding to results.
#
# Processing Sector: Finance, Author: GEPL Capital
# Group Size: 1
#
# Processing Sector: Finance, Author: Karvy
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Ajcon Global
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Chola Wealth Direct
# Group Size: 11
# Correlation: 0.499441238059027
# Mean Performance: -0.005190814281202364
#
# Processing Sector: Healthcare, Author: GEPL Capital
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Reliance Securities
# Group Size: 5
# Correlation: 0.28945979128778815
# Mean Performance: -0.0017465553262486194
#
# Processing Sector: Manufacturing, Author: Ashika Research
# Group Size: 4
# Correlation: -0.961109455864253
# Mean Performance: -0.00639707352557705
#
# Processing Sector: Manufacturing, Author: Chola Wealth Direct
# Group Size: 23
# Correlation: -0.2697964126872635
# Mean Performance: -0.004824263180776083
#
# Processing Sector: Real Estate, Author: Chola Wealth Direct
# Group Size: 3
# Correlation: -0.25253032792416713
# Mean Performance: -0.002984495483090066
#
# Processing Sector: Technology, Author: Ajcon Global
# Group Size: 1
#
# Processing Sector: Technology, Author: Ashika Research
# Group Size: 2
# Correlation: -1.0
# Mean Performance: 0.028126989376214197
#
# Processing Sector: Technology, Author: Chola Wealth Direct
# Group Size: 21
# Correlation: 0.16220269439267027
# Mean Performance: 0.001115644913531676
# Thresholds met. Adding to results.
#
# Processing Sector: Technology, Author: Karvy
# Group Size: 2
# Correlation: 1.0
# Mean Performance: -0.0063540677429566005
#
# Processing Sector: Technology, Author: Reliance Securities
# Group Size: 1
#
# Processing Sector: Unknown, Author: Chola Wealth Direct
# Group Size: 6
# Correlation: 0.39982312340849663
# Mean Performance: 0.003909384403543333
# Thresholds met. Adding to results.
#
# Performance DataFrame Shape: (4, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (4, 4)
# Top Authors DataFrame Sample:
#        Sector               author  correlation  mean_performance
# 0     Unknown  Chola Wealth Direct     0.399823          0.003909
# 1  Technology  Chola Wealth Direct     0.162203          0.001116
# 2     Finance      Ashika Research     0.032910          0.010253
# 3     Finance  Chola Wealth Direct     0.026798          0.000204
# Best Authors DataFrame Shape: (4, 4)
#
# Calculating monthly performance for: 2014-11
# Month Start: 2014-11-01 00:00:00, Month End: 2014-11-30 00:00:00
# Filtered Data for Month: 26 rows
# Best Authors DataFrame Shape: (4, 4)
# Data After Merging with Best Authors: 9 rows
# Performance Column Calculated. Sample Data:
#        Sector               author  performance
# 0  Technology  Chola Wealth Direct    -0.000693
# 1     Finance  Chola Wealth Direct     0.047290
# 2  Technology  Chola Wealth Direct     0.037298
# 3     Finance  Chola Wealth Direct     0.044306
# 4     Unknown  Chola Wealth Direct     0.008488
# Performance Summary for 2014-11:
#        Sector               author  mean_performance  count      month
# 0     Finance  Chola Wealth Direct          0.029920      3 2014-11-01
# 1  Technology  Chola Wealth Direct         -0.002974      5 2014-11-01
# 2     Unknown  Chola Wealth Direct          0.008488      1 2014-11-01
# Monthly Performance for 2014-11:
#         Sector               author  mean_performance  count      month
# 0     Finance  Chola Wealth Direct          0.029920      3 2014-11-01
# 1  Technology  Chola Wealth Direct         -0.002974      5 2014-11-01
# 2     Unknown  Chola Wealth Direct          0.008488      1 2014-11-01
#
# Processing Month: 2014-12
# Training Period: Start 2013-11-30 00:00:00, End 2014-11-30 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2013-11-30 00:00:00, End Date: 2014-11-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (151, 7)
# Number of Sector-Author Groups: 24
#
# Processing Sector: Agriculture, Author: Chola Wealth Direct
# Group Size: 2
# Correlation: 1.0
# Mean Performance: 0.01189449645667585
# Thresholds met. Adding to results.
#
# Processing Sector: Agriculture, Author: Karvy
# Group Size: 2
# Correlation: 1.0
# Mean Performance: -0.0023183455987045498
#
# Processing Sector: Consumer Goods, Author: Chola Wealth Direct
# Group Size: 9
# Correlation: -0.15631863094745618
# Mean Performance: 0.0067477534708318895
#
# Processing Sector: Consumer Goods, Author: Reliance Securities
# Group Size: 1
#
# Processing Sector: Energy, Author: Ashika Research
# Group Size: 1
#
# Processing Sector: Energy, Author: Chola Wealth Direct
# Group Size: 4
# Correlation: 0.1045904967398673
# Mean Performance: 0.0033311764082909253
# Thresholds met. Adding to results.
#
# Processing Sector: Finance, Author: Ashika Research
# Group Size: 3
# Correlation: 0.032910380914346414
# Mean Performance: 0.010253322906227802
# Thresholds met. Adding to results.
#
# Processing Sector: Finance, Author: Chola Wealth Direct
# Group Size: 40
# Correlation: -0.049361362762375335
# Mean Performance: 0.003775638192511292
#
# Processing Sector: Finance, Author: GEPL Capital
# Group Size: 1
#
# Processing Sector: Finance, Author: Karvy
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Ajcon Global
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Chola Wealth Direct
# Group Size: 11
# Correlation: 0.07734237876152385
# Mean Performance: -0.012857317244166517
#
# Processing Sector: Healthcare, Author: GEPL Capital
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Reliance Securities
# Group Size: 5
# Correlation: 0.28945979128778815
# Mean Performance: -0.0017465553262486194
#
# Processing Sector: Manufacturing, Author: Ajcon Global
# Group Size: 1
#
# Processing Sector: Manufacturing, Author: Ashika Research
# Group Size: 4
# Correlation: -0.961109455864253
# Mean Performance: -0.00639707352557705
#
# Processing Sector: Manufacturing, Author: Chola Wealth Direct
# Group Size: 24
# Correlation: -0.28630631590705813
# Mean Performance: -0.0031462642972631704
#
# Processing Sector: Real Estate, Author: Chola Wealth Direct
# Group Size: 4
# Correlation: -0.2264439358513771
# Mean Performance: -0.004014728304741376
#
# Processing Sector: Technology, Author: Ajcon Global
# Group Size: 1
#
# Processing Sector: Technology, Author: Ashika Research
# Group Size: 2
# Correlation: -1.0
# Mean Performance: 0.028126989376214197
#
# Processing Sector: Technology, Author: Chola Wealth Direct
# Group Size: 22
# Correlation: 0.09149163404230116
# Mean Performance: 0.0004939865320333501
# Thresholds met. Adding to results.
#
# Processing Sector: Technology, Author: Karvy
# Group Size: 4
# Correlation: 0.3676510012987332
# Mean Performance: -0.0027840543485026757
#
# Processing Sector: Technology, Author: Reliance Securities
# Group Size: 1
#
# Processing Sector: Unknown, Author: Chola Wealth Direct
# Group Size: 6
# Correlation: 0.22931822430281135
# Mean Performance: 0.002933402703200217
# Thresholds met. Adding to results.
#
# Performance DataFrame Shape: (5, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (5, 4)
# Top Authors DataFrame Sample:
#         Sector               author  correlation  mean_performance
# 0  Agriculture  Chola Wealth Direct     1.000000          0.011894
# 1      Unknown  Chola Wealth Direct     0.229318          0.002933
# 2       Energy  Chola Wealth Direct     0.104590          0.003331
# 3   Technology  Chola Wealth Direct     0.091492          0.000494
# 4      Finance      Ashika Research     0.032910          0.010253
# Best Authors DataFrame Shape: (5, 4)
#
# Calculating monthly performance for: 2014-12
# Month Start: 2014-12-01 00:00:00, Month End: 2014-12-31 00:00:00
# Filtered Data for Month: 7 rows
# Best Authors DataFrame Shape: (5, 4)
# Data After Merging with Best Authors: 2 rows
# Performance Column Calculated. Sample Data:
#     Sector           author  performance
# 0  Finance  Ashika Research     0.018222
# 1  Finance  Ashika Research     0.023580
# Performance Summary for 2014-12:
#     Sector           author  mean_performance  count      month
# 0  Finance  Ashika Research          0.020901      2 2014-12-01
# Monthly Performance for 2014-12:
#      Sector           author  mean_performance  count      month
# 0  Finance  Ashika Research          0.020901      2 2014-12-01
#
# Processing Month: 2015-01
# Training Period: Start 2013-12-31 00:00:00, End 2014-12-31 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2013-12-31 00:00:00, End Date: 2014-12-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (156, 7)
# Number of Sector-Author Groups: 25
#
# Processing Sector: Agriculture, Author: Chola Wealth Direct
# Group Size: 2
# Correlation: 1.0
# Mean Performance: 0.01189449645667585
# Thresholds met. Adding to results.
#
# Processing Sector: Agriculture, Author: Karvy
# Group Size: 2
# Correlation: 1.0
# Mean Performance: -0.0023183455987045498
#
# Processing Sector: Consumer Goods, Author: Chola Wealth Direct
# Group Size: 9
# Correlation: -0.15631863094745618
# Mean Performance: 0.0067477534708318895
#
# Processing Sector: Consumer Goods, Author: Reliance Securities
# Group Size: 1
#
# Processing Sector: Energy, Author: Ashika Research
# Group Size: 1
#
# Processing Sector: Energy, Author: Chola Wealth Direct
# Group Size: 4
# Correlation: 0.1045904967398673
# Mean Performance: 0.0033311764082909253
# Thresholds met. Adding to results.
#
# Processing Sector: Finance, Author: Ashika Research
# Group Size: 5
# Correlation: 0.007699523459349963
# Mean Performance: 0.01451237425401434
# Thresholds met. Adding to results.
#
# Processing Sector: Finance, Author: Chola Wealth Direct
# Group Size: 39
# Correlation: -0.04545822284079879
# Mean Performance: 0.003026476861898505
#
# Processing Sector: Finance, Author: GEPL Capital
# Group Size: 1
#
# Processing Sector: Finance, Author: Karvy
# Group Size: 2
# Correlation: -1.0
# Mean Performance: 0.0017643390642648003
#
# Processing Sector: Healthcare, Author: Ajcon Global
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Ashika Research
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Chola Wealth Direct
# Group Size: 11
# Correlation: 0.07734237876152385
# Mean Performance: -0.012857317244166517
#
# Processing Sector: Healthcare, Author: GEPL Capital
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Reliance Securities
# Group Size: 5
# Correlation: 0.28945979128778815
# Mean Performance: -0.0017465553262486194
#
# Processing Sector: Manufacturing, Author: Ajcon Global
# Group Size: 1
#
# Processing Sector: Manufacturing, Author: Ashika Research
# Group Size: 4
# Correlation: -0.961109455864253
# Mean Performance: -0.00639707352557705
#
# Processing Sector: Manufacturing, Author: Chola Wealth Direct
# Group Size: 24
# Correlation: -0.28630631590705813
# Mean Performance: -0.0031462642972631704
#
# Processing Sector: Manufacturing, Author: Reliance Securities
# Group Size: 1
#
# Processing Sector: Real Estate, Author: Chola Wealth Direct
# Group Size: 4
# Correlation: -0.2264439358513771
# Mean Performance: -0.004014728304741376
#
# Processing Sector: Technology, Author: Ashika Research
# Group Size: 2
# Correlation: -1.0
# Mean Performance: 0.028126989376214197
#
# Processing Sector: Technology, Author: Chola Wealth Direct
# Group Size: 22
# Correlation: 0.09149163404230116
# Mean Performance: 0.0004939865320333501
# Thresholds met. Adding to results.
#
# Processing Sector: Technology, Author: Karvy
# Group Size: 5
# Correlation: 0.40414837292267985
# Mean Performance: -0.00436225132809568
#
# Processing Sector: Technology, Author: Reliance Securities
# Group Size: 2
# Correlation: -1.0
# Mean Performance: -0.01838246885596085
#
# Processing Sector: Unknown, Author: Chola Wealth Direct
# Group Size: 6
# Correlation: 0.22931822430281135
# Mean Performance: 0.002933402703200217
# Thresholds met. Adding to results.
#
# Performance DataFrame Shape: (5, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (5, 4)
# Top Authors DataFrame Sample:
#         Sector               author  correlation  mean_performance
# 0  Agriculture  Chola Wealth Direct     1.000000          0.011894
# 1      Unknown  Chola Wealth Direct     0.229318          0.002933
# 2       Energy  Chola Wealth Direct     0.104590          0.003331
# 3   Technology  Chola Wealth Direct     0.091492          0.000494
# 4      Finance      Ashika Research     0.007700          0.014512
# Best Authors DataFrame Shape: (5, 4)
#
# Calculating monthly performance for: 2015-01
# Month Start: 2015-01-01 00:00:00, Month End: 2015-01-31 00:00:00
# Filtered Data for Month: 23 rows
# Best Authors DataFrame Shape: (5, 4)
# Data After Merging with Best Authors: 2 rows
# Performance Column Calculated. Sample Data:
#        Sector               author  performance
# 0     Unknown  Chola Wealth Direct     0.011518
# 1  Technology  Chola Wealth Direct    -0.004546
# Performance Summary for 2015-01:
#        Sector               author  mean_performance  count      month
# 0  Technology  Chola Wealth Direct         -0.004546      1 2015-01-01
# 1     Unknown  Chola Wealth Direct          0.011518      1 2015-01-01
# Monthly Performance for 2015-01:
#         Sector               author  mean_performance  count      month
# 0  Technology  Chola Wealth Direct         -0.004546      1 2015-01-01
# 1     Unknown  Chola Wealth Direct          0.011518      1 2015-01-01
#
# Processing Month: 2015-02
# Training Period: Start 2014-01-31 00:00:00, End 2015-01-31 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2014-01-31 00:00:00, End Date: 2015-01-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (169, 7)
# Number of Sector-Author Groups: 29
#
# Processing Sector: Agriculture, Author: Chola Wealth Direct
# Group Size: 2
# Correlation: 1.0
# Mean Performance: 0.01189449645667585
# Thresholds met. Adding to results.
#
# Processing Sector: Agriculture, Author: Karvy
# Group Size: 2
# Correlation: 1.0
# Mean Performance: -0.0023183455987045498
#
# Processing Sector: Consumer Goods, Author: BOB Capital Markets Ltd.
# Group Size: 1
#
# Processing Sector: Consumer Goods, Author: Chola Wealth Direct
# Group Size: 9
# Correlation: -0.15631863094745618
# Mean Performance: 0.0067477534708318895
#
# Processing Sector: Consumer Goods, Author: Reliance Securities
# Group Size: 1
#
# Processing Sector: Energy, Author: Ashika Research
# Group Size: 1
#
# Processing Sector: Energy, Author: Chola Wealth Direct
# Group Size: 4
# Correlation: 0.1045904967398673
# Mean Performance: 0.0033311764082909253
# Thresholds met. Adding to results.
#
# Processing Sector: Finance, Author: Ashika Research
# Group Size: 3
# Correlation: -0.3530754710806554
# Mean Performance: 0.007430267135878
#
# Processing Sector: Finance, Author: Chola Wealth Direct
# Group Size: 45
# Correlation: -0.011091302825185804
# Mean Performance: 0.002598692129890802
#
# Processing Sector: Finance, Author: GEPL Capital
# Group Size: 1
#
# Processing Sector: Finance, Author: Karvy
# Group Size: 2
# Correlation: -1.0
# Mean Performance: 0.0017643390642648003
#
# Processing Sector: Finance, Author: Systematix Group
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Ajcon Global
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Ashika Research
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Chola Wealth Direct
# Group Size: 12
# Correlation: -0.044376590753195395
# Mean Performance: -0.012061248432121833
#
# Processing Sector: Healthcare, Author: GEPL Capital
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Reliance Securities
# Group Size: 6
# Correlation: 0.2806078521150608
# Mean Performance: -0.003422336477877983
#
# Processing Sector: Manufacturing, Author: Ajcon Global
# Group Size: 1
#
# Processing Sector: Manufacturing, Author: Ashika Research
# Group Size: 4
# Correlation: -0.961109455864253
# Mean Performance: -0.00639707352557705
#
# Processing Sector: Manufacturing, Author: Chola Wealth Direct
# Group Size: 24
# Correlation: -0.2478256325407666
# Mean Performance: -0.004760630515714975
#
# Processing Sector: Manufacturing, Author: Karvy
# Group Size: 1
#
# Processing Sector: Manufacturing, Author: Reliance Securities
# Group Size: 1
#
# Processing Sector: Real Estate, Author: Chola Wealth Direct
# Group Size: 4
# Correlation: -0.2264439358513771
# Mean Performance: -0.004014728304741376
#
# Processing Sector: Technology, Author: Ashika Research
# Group Size: 2
# Correlation: -1.0
# Mean Performance: 0.028126989376214197
#
# Processing Sector: Technology, Author: Chola Wealth Direct
# Group Size: 23
# Correlation: 0.09361548333532925
# Mean Performance: 0.00027486243037259066
# Thresholds met. Adding to results.
#
# Processing Sector: Technology, Author: Karvy
# Group Size: 7
# Correlation: 0.367260924168475
# Mean Performance: -0.005120754363104057
#
# Processing Sector: Technology, Author: Reliance Securities
# Group Size: 2
# Correlation: -1.0
# Mean Performance: -0.01838246885596085
#
# Processing Sector: Telecommunications, Author: Karvy
# Group Size: 1
#
# Processing Sector: Unknown, Author: Chola Wealth Direct
# Group Size: 6
# Correlation: 0.15766196187796017
# Mean Performance: 0.004075592902550651
# Thresholds met. Adding to results.
#
# Performance DataFrame Shape: (4, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (4, 4)
# Top Authors DataFrame Sample:
#         Sector               author  correlation  mean_performance
# 0  Agriculture  Chola Wealth Direct     1.000000          0.011894
# 1      Unknown  Chola Wealth Direct     0.157662          0.004076
# 2       Energy  Chola Wealth Direct     0.104590          0.003331
# 3   Technology  Chola Wealth Direct     0.093615          0.000275
# Best Authors DataFrame Shape: (4, 4)
#
# Calculating monthly performance for: 2015-02
# Month Start: 2015-02-01 00:00:00, Month End: 2015-02-28 00:00:00
# Filtered Data for Month: 89 rows
# Best Authors DataFrame Shape: (4, 4)
# Data After Merging with Best Authors: 6 rows
# Performance Column Calculated. Sample Data:
#         Sector               author  performance
# 0  Agriculture  Chola Wealth Direct     0.002385
# 1   Technology  Chola Wealth Direct     0.021794
# 2   Technology  Chola Wealth Direct     0.025615
# 3   Technology  Chola Wealth Direct     0.001760
# 4       Energy  Chola Wealth Direct    -0.004274
# Performance Summary for 2015-02:
#         Sector               author  mean_performance  count      month
# 0  Agriculture  Chola Wealth Direct          0.002385      1 2015-02-01
# 1       Energy  Chola Wealth Direct         -0.004274      1 2015-02-01
# 2   Technology  Chola Wealth Direct          0.002316      4 2015-02-01
# Monthly Performance for 2015-02:
#          Sector               author  mean_performance  count      month
# 0  Agriculture  Chola Wealth Direct          0.002385      1 2015-02-01
# 1       Energy  Chola Wealth Direct         -0.004274      1 2015-02-01
# 2   Technology  Chola Wealth Direct          0.002316      4 2015-02-01
#
# Processing Month: 2015-03
# Training Period: Start 2014-02-28 00:00:00, End 2015-02-28 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2014-02-28 00:00:00, End Date: 2015-02-28 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (241, 7)
# Number of Sector-Author Groups: 45
#
# Processing Sector: Agriculture, Author: Chola Wealth Direct
# Group Size: 2
# Correlation: -1.0
# Mean Performance: 0.0041171633539004
#
# Processing Sector: Agriculture, Author: Karvy
# Group Size: 4
# Correlation: 0.16841687620361767
# Mean Performance: -0.001053005667174325
#
# Processing Sector: Consumer Goods, Author: BOB Capital Markets Ltd.
# Group Size: 2
# Correlation: -0.9999999999999998
# Mean Performance: 0.0005069625761531995
#
# Processing Sector: Consumer Goods, Author: Chola Wealth Direct
# Group Size: 11
# Correlation: -0.35620713760784706
# Mean Performance: 0.003965756100234382
#
# Processing Sector: Consumer Goods, Author: HDFC Securities
# Group Size: 3
# Correlation: -0.29130584018121763
# Mean Performance: -0.0066772344800098
#
# Processing Sector: Consumer Goods, Author: Karvy
# Group Size: 1
#
# Processing Sector: Consumer Goods, Author: Reliance Securities
# Group Size: 1
#
# Processing Sector: Energy, Author: Ashika Research
# Group Size: 1
#
# Processing Sector: Energy, Author: Chola Wealth Direct
# Group Size: 4
# Correlation: 0.9365575915989903
# Mean Performance: 0.0037045373932177504
# Thresholds met. Adding to results.
#
# Processing Sector: Energy, Author: HDFC Securities
# Group Size: 3
# Correlation: -0.16301512357849746
# Mean Performance: 0.007262739147972302
#
# Processing Sector: Finance, Author: Ashika Research
# Group Size: 3
# Correlation: -0.3530754710806554
# Mean Performance: 0.007430267135878
#
# Processing Sector: Finance, Author: BOB Capital Markets Ltd.
# Group Size: 1
#
# Processing Sector: Finance, Author: Chola Wealth Direct
# Group Size: 47
# Correlation: -0.008465262998088249
# Mean Performance: 0.0015226455765114488
#
# Processing Sector: Finance, Author: GEPL Capital
# Group Size: 1
#
# Processing Sector: Finance, Author: HDFC Securities
# Group Size: 15
# Correlation: 0.2915622551178322
# Mean Performance: -0.008571098542645431
#
# Processing Sector: Finance, Author: Karvy
# Group Size: 5
# Correlation: 0.6967970807735812
# Mean Performance: 0.0005395478016250004
# Thresholds met. Adding to results.
#
# Processing Sector: Finance, Author: Reliance Securities
# Group Size: 1
#
# Processing Sector: Finance, Author: Systematix Group
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Ajcon Global
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Ashika Research
# Group Size: 1
#
# Processing Sector: Healthcare, Author: Chola Wealth Direct
# Group Size: 12
# Correlation: -0.030526222821773873
# Mean Performance: -0.011565084106921466
#
# Processing Sector: Healthcare, Author: GEPL Capital
# Group Size: 1
#
# Processing Sector: Healthcare, Author: HDFC Securities
# Group Size: 3
# Correlation: -0.36294571836937456
# Mean Performance: -0.0014761791745433333
#
# Processing Sector: Healthcare, Author: Karvy
# Group Size: 2
# Correlation: -0.9999999999999999
# Mean Performance: -0.0119796222807983
#
# Processing Sector: Healthcare, Author: Reliance Securities
# Group Size: 6
# Correlation: 0.2806078521150608
# Mean Performance: -0.003422336477877983
#
# Processing Sector: Manufacturing, Author: Ajcon Global
# Group Size: 1
#
# Processing Sector: Manufacturing, Author: Ashika Research
# Group Size: 5
# Correlation: -0.13277295529359792
# Mean Performance: -0.00411921888286414
#
# Processing Sector: Manufacturing, Author: BOB Capital Markets Ltd.
# Group Size: 1
#
# Processing Sector: Manufacturing, Author: Chola Wealth Direct
# Group Size: 31
# Correlation: -0.1974234302968323
# Mean Performance: -0.005793937048128318
#
# Processing Sector: Manufacturing, Author: HDFC Securities
# Group Size: 10
# Correlation: -0.2656039440020998
# Mean Performance: -0.010761467149949048
#
# Processing Sector: Manufacturing, Author: ICICI Securities Limited
# Group Size: 1
#
# Processing Sector: Manufacturing, Author: Karvy
# Group Size: 4
# Correlation: 0.319984701917215
# Mean Performance: -0.0023065994998526995
#
# Processing Sector: Manufacturing, Author: Reliance Securities
# Group Size: 1
#
# Processing Sector: Real Estate, Author: Chola Wealth Direct
# Group Size: 4
# Correlation: 0.33396150823314824
# Mean Performance: -0.0084428740891221
#
# Processing Sector: Technology, Author: Ashika Research
# Group Size: 2
# Correlation: -1.0
# Mean Performance: 0.028126989376214197
#
# Processing Sector: Technology, Author: BOB Capital Markets Ltd.
# Group Size: 1
#
# Processing Sector: Technology, Author: Chola Wealth Direct
# Group Size: 22
# Correlation: 0.04263776174949515
# Mean Performance: 0.0007649833612186358
# Thresholds met. Adding to results.
#
# Processing Sector: Technology, Author: HDFC Securities
# Group Size: 3
# Correlation: -0.39049436448435265
# Mean Performance: 0.03662674539732743
#
# Processing Sector: Technology, Author: Karvy
# Group Size: 8
# Correlation: 0.43298323197399985
# Mean Performance: -0.0036264459447092126
#
# Processing Sector: Technology, Author: Reliance Securities
# Group Size: 2
# Correlation: -1.0
# Mean Performance: -0.01838246885596085
#
# Processing Sector: Telecommunications, Author: Karvy
# Group Size: 3
# Correlation: 0.7670964920946699
# Mean Performance: 0.001485705507543767
# Thresholds met. Adding to results.
#
# Processing Sector: Unknown, Author: Chola Wealth Direct
# Group Size: 6
# Correlation: 0.15766196187796017
# Mean Performance: 0.004075592902550651
# Thresholds met. Adding to results.
#
# Processing Sector: Unknown, Author: Karvy
# Group Size: 2
# Correlation: 0.9999999999999999
# Mean Performance: -0.02854829288434385
#
# Processing Sector: Utilities, Author: HDFC Securities
# Group Size: 1
#
# Processing Sector: Utilities, Author: Karvy
# Group Size: 1
#
# Performance DataFrame Shape: (5, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (5, 4)
# Top Authors DataFrame Sample:
#                Sector               author  correlation  mean_performance
# ...
#
# Processing Sector: Technology, Author: Ventura
# Group Size: 2
# Correlation: 1.0
# Mean Performance: 0.019889358375206452
# Thresholds met. Adding to results.
#
# Processing Sector: Technology, Author: Way2Wealth
# Group Size: 4
# Correlation: -0.6024573980820493
# Mean Performance: -0.0016596484154545997
#
# Processing Sector: Technology, Author: Yes Securities
# Group Size: 1
#
# Processing Sector: Telecommunications, Author: Arihant Capital
# Group Size: 1
#
# Processing Sector: Telecommunications, Author: Ashika Research
# Group Size: 1
#
# Processing Sector: Telecommunications, Author: Axis Direct
# Group Size: 5
# Correlation: -0.3820467015191778
# Mean Performance: -0.00984452323791862
#
# Processing Sector: Telecommunications, Author: BOB Capital Markets Ltd.
# Group Size: 4
# Correlation: -0.8635567884557567
# Mean Performance: -0.026829498755165375
#
# Processing Sector: Telecommunications, Author: Dolat Capital
# Group Size: 2
# Correlation: 1.0
# Mean Performance: -0.042822818558562306
#
# Processing Sector: Telecommunications, Author: East India Securities Ltd
# Group Size: 1
#
# Processing Sector: Telecommunications, Author: Edelweiss
# Group Size: 1
#
# Processing Sector: Telecommunications, Author: Geojit BNP Paribas
# Group Size: 6
# Correlation: -0.20753322369058916
# Mean Performance: 0.0024840375580152505
#
# Processing Sector: Telecommunications, Author: ICICI Securities Limited
# Group Size: 12
# Correlation: 0.0842694446511425
# Mean Performance: -0.008860019403256833
#
# Processing Sector: Telecommunications, Author: IDBI Capital
# Group Size: 4
# Correlation: -0.35025705318854405
# Mean Performance: 0.010952142080142552
#
# Processing Sector: Telecommunications, Author: KRChoksey
# Group Size: 1
#
# Processing Sector: Telecommunications, Author: LKP Securities
# Group Size: 4
# Correlation: -0.33972740110080113
# Mean Performance: -0.03512736729511522
#
# Processing Sector: Telecommunications, Author: Motilal Oswal
# Group Size: 8
# Correlation: -0.7416482176283179
# Mean Performance: -0.015504359003142273
#
# Processing Sector: Telecommunications, Author: Prabhudas Lilladhar
# Group Size: 7
# Correlation: -0.6084812497560557
# Mean Performance: -0.012883105801275972
#
# Processing Sector: Telecommunications, Author: Sharekhan
# Group Size: 1
#
# Processing Sector: Transportation, Author: BOB Capital Markets Ltd.
# Group Size: 6
# Correlation: -0.11954911150095879
# Mean Performance: -0.0019880035038655672
#
# Processing Sector: Transportation, Author: Dolat Capital
# Group Size: 1
#
# Processing Sector: Transportation, Author: Geojit BNP Paribas
# Group Size: 2
# Correlation: -1.0
# Mean Performance: -0.016022321228530652
#
# Processing Sector: Transportation, Author: Motilal Oswal
# Group Size: 3
# Correlation: -0.675269796852824
# Mean Performance: -0.0047267965805122
#
# Processing Sector: Transportation, Author: Prabhudas Lilladhar
# Group Size: 1
#
# Processing Sector: Transportation, Author: Way2Wealth
# Group Size: 1
#
# Processing Sector: Unknown, Author: Ashika Research
# Group Size: 1
#
# Processing Sector: Unknown, Author: Axis Direct
# Group Size: 16
# Correlation: 0.40219576286277875
# Mean Performance: 0.004854935433182807
# Thresholds met. Adding to results.
#
# Processing Sector: Unknown, Author: BOB Capital Markets Ltd.
# Group Size: 9
# Correlation: 0.3004482596674012
# Mean Performance: -0.009259381476909556
#
# Processing Sector: Unknown, Author: CD Equisearch
# Group Size: 2
# Correlation: 1.0
# Mean Performance: 0.01093633809799215
# Thresholds met. Adding to results.
#
# Processing Sector: Unknown, Author: Chola Wealth Direct
# Group Size: 4
# Correlation: -0.7396077326341265
# Mean Performance: 0.0013621076152017
#
# Processing Sector: Unknown, Author: Dolat Capital
# Group Size: 5
# Correlation: -0.7253174083947237
# Mean Performance: -0.01011857298963008
#
# Processing Sector: Unknown, Author: East India Securities Ltd
# Group Size: 1
#
# Processing Sector: Unknown, Author: Edelweiss
# Group Size: 5
# Correlation: -0.5735056864913072
# Mean Performance: 0.024206952121404796
#
# Processing Sector: Unknown, Author: Geojit BNP Paribas
# Group Size: 12
# Correlation: 0.34980262717417054
# Mean Performance: 0.0004335143839165583
# Thresholds met. Adding to results.
#
# Processing Sector: Unknown, Author: ICICI Securities Limited
# Group Size: 31
# Correlation: 0.0176597380838514
# Mean Performance: -0.0015363910336705278
#
# Processing Sector: Unknown, Author: IDBI Capital
# Group Size: 6
# Correlation: -0.21838140078941473
# Mean Performance: -0.008813619956226733
#
# Processing Sector: Unknown, Author: Karvy
# Group Size: 2
# Correlation: 0.9999999999999999
# Mean Performance: -0.0016846552028968501
#
# Processing Sector: Unknown, Author: Khambatta Securities
# Group Size: 2
# Correlation: nan
# Mean Performance: -0.0436946902654867
#
# Processing Sector: Unknown, Author: Monarch Networth Capital Limited
# Group Size: 5
# Correlation: 0.647281860961131
# Mean Performance: 0.00438400512834126
# Thresholds met. Adding to results.
#
# Processing Sector: Unknown, Author: Motilal Oswal
# Group Size: 8
# Correlation: -0.1980437830375297
# Mean Performance: -0.009842275843097324
#
# Processing Sector: Unknown, Author: Prabhudas Lilladhar
# Group Size: 17
# Correlation: -0.5851791445695306
# Mean Performance: -0.00861736594476553
#
# Processing Sector: Unknown, Author: Sharekhan
# Group Size: 2
# Correlation: -1.0
# Mean Performance: 0.04020906542533225
#
# Processing Sector: Unknown, Author: Way2Wealth
# Group Size: 1
#
# Processing Sector: Utilities, Author: Ashika Research
# Group Size: 1
#
# Processing Sector: Utilities, Author: Axis Direct
# Group Size: 5
# Correlation: -0.7569458555537701
# Mean Performance: -0.0023438097629764803
#
# Processing Sector: Utilities, Author: BOB Capital Markets Ltd.
# Group Size: 7
# Correlation: -0.284117912349826
# Mean Performance: -1.6381204501421585e-06
#
# Processing Sector: Utilities, Author: Dolat Capital
# Group Size: 2
# Correlation: -0.9999999999999999
# Mean Performance: -0.0203138657913489
#
# Processing Sector: Utilities, Author: Edelweiss
# Group Size: 1
#
# Processing Sector: Utilities, Author: Geojit BNP Paribas
# Group Size: 6
# Correlation: 0.2501420592041976
# Mean Performance: -0.013166300501458299
#
# Processing Sector: Utilities, Author: ICICI Securities Limited
# Group Size: 8
# Correlation: -0.2335712343339109
# Mean Performance: -0.01286051513749085
#
# Processing Sector: Utilities, Author: IDBI Capital
# Group Size: 3
# Correlation: 0.3597896730943263
# Mean Performance: 0.003263528991895467
# Thresholds met. Adding to results.
#
# Processing Sector: Utilities, Author: LKP Securities
# Group Size: 5
# Correlation: -0.7553955026823371
# Mean Performance: -0.008503591409431221
#
# Processing Sector: Utilities, Author: Motilal Oswal
# Group Size: 1
#
# Processing Sector: Utilities, Author: Prabhudas Lilladhar
# Group Size: 4
# Correlation: -0.521954139193034
# Mean Performance: -0.00046382869350637484
#
# Processing Sector: Utilities, Author: Sharekhan
# Group Size: 3
# Correlation: -0.36721533884887847
# Mean Performance: -0.011882463607513534
#
# Performance DataFrame Shape: (27, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (27, 4)
# Top Authors DataFrame Sample:
#             Sector                            author  correlation  \
# 0       Technology                   HDFC Securities     1.000000
# 1       Technology                           Ventura     1.000000
# 2          Unknown                     CD Equisearch     1.000000
# 3   Consumer Goods                         KRChoksey     1.000000
# 4           Energy  Monarch Networth Capital Limited     1.000000
# 5    Manufacturing                       Anand Rathi     1.000000
# 6           Energy                           Ventura     0.915060
# 7       Technology                   Ashika Research     0.822049
# 8      Agriculture               Chola Wealth Direct     0.691939
# 9          Unknown  Monarch Networth Capital Limited     0.647282
# 10         Finance                           Ventura     0.601594
# 11         Finance                   HDFC Securities     0.554236
# 12     Real Estate                     Motilal Oswal     0.472061
# 13  Consumer Goods                         Edelweiss     0.445075
# 14  Consumer Goods                         Sharekhan     0.421293
# 15         Unknown                       Axis Direct     0.402196
# 16       Utilities                      IDBI Capital     0.359790
# 17         Unknown                Geojit BNP Paribas     0.349803
# 18      Healthcare                     CD Equisearch     0.294361
# 19      Healthcare                   Ashika Research     0.283342
# 20  Consumer Goods          BOB Capital Markets Ltd.     0.152846
# 21   Manufacturing  Monarch Networth Capital Limited     0.152703
# 22          Energy                         Edelweiss     0.148443
# 23      Technology                     Dolat Capital     0.112122
# 24         Finance                             Karvy     0.085009
# 25         Finance                     Dolat Capital     0.014128
# 26   Manufacturing                         Edelweiss     0.012706
#
#     mean_performance
# 0           0.037344
# 1           0.019889
# 2           0.010936
# 3           0.006191
# 4           0.002611
# 5           0.001530
# 6           0.009331
# 7           0.003474
# 8           0.002362
# 9           0.004384
# 10          0.002035
# 11          0.008926
# 12          0.073255
# 13          0.008168
# 14          0.000350
# 15          0.004855
# 16          0.003264
# 17          0.000434
# 18          0.012570
# 19          0.006522
# 20          0.002956
# 21          0.004763
# 22          0.002180
# 23          0.000499
# 24          0.005321
# 25          0.004623
# 26          0.004323
# Best Authors DataFrame Shape: (27, 4)
#
# Calculating monthly performance for: 2021-09
# Month Start: 2021-09-01 00:00:00, Month End: 2021-09-30 00:00:00
# Filtered Data for Month: 102 rows
# Best Authors DataFrame Shape: (27, 4)
# Data After Merging with Best Authors: 4 rows
# Performance Column Calculated. Sample Data:
#           Sector           author  performance
# 0     Healthcare  Ashika Research    -0.008803
# 1  Manufacturing        Edelweiss     0.009754
# 2  Manufacturing        Edelweiss    -0.054801
# 3     Healthcare    CD Equisearch    -0.012690
# Performance Summary for 2021-09:
#           Sector           author  mean_performance  count      month
# 0     Healthcare  Ashika Research         -0.008803      1 2021-09-01
# 1     Healthcare    CD Equisearch         -0.012690      1 2021-09-01
# 2  Manufacturing        Edelweiss         -0.022523      2 2021-09-01
# Monthly Performance for 2021-09:
#            Sector           author  mean_performance  count      month
# 0     Healthcare  Ashika Research         -0.008803      1 2021-09-01
# 1     Healthcare    CD Equisearch         -0.012690      1 2021-09-01
# 2  Manufacturing        Edelweiss         -0.022523      2 2021-09-01
#
# Processing Month: 2021-10
# Training Period: Start 2020-09-30 00:00:00, End 2021-09-30 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2020-09-30 00:00:00, End Date: 2021-09-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (3770, 7)
# Number of Sector-Author Groups: 200
#
# Processing Sector: Agriculture, Author: Axis Direct
# Group Size: 3
# Correlation: -0.982380659913324
# Mean Performance: -0.0008279290789038659
#
# Processing Sector: Agriculture, Author: Chola Wealth Direct
# Group Size: 2
# Correlation: 0.9999999999999999
# Mean Performance: 0.003977424740615
# Thresholds met. Adding to results.
#
# Processing Sector: Agriculture, Author: Dolat Capital
# Group Size: 1
#
# Processing Sector: Agriculture, Author: Geojit BNP Paribas
# Group Size: 3
# Correlation: -0.9373244078314579
# Mean Performance: -0.007159024383069733
#
# Processing Sector: Agriculture, Author: ICICI Securities Limited
# Group Size: 4
# Correlation: -0.7416396404345018
# Mean Performance: -0.0193295496410667
#
# Processing Sector: Agriculture, Author: Motilal Oswal
# Group Size: 1
#
# Processing Sector: Consumer Goods, Author: Arihant Capital
# Group Size: 1
#
# Processing Sector: Consumer Goods, Author: Ashika Research
# Group Size: 5
# Correlation: 0.32699880586786334
# Mean Performance: -0.0011037975150922994
#
# Processing Sector: Consumer Goods, Author: Axis Direct
# Group Size: 20
# Correlation: 0.06683968880629976
# Mean Performance: -0.00022443722413832004
#
# Processing Sector: Consumer Goods, Author: BOB Capital Markets Ltd.
# Group Size: 10
# Correlation: 0.23124362852191951
# Mean Performance: 0.01014834815488502
# Thresholds met. Adding to results.
#
# Processing Sector: Consumer Goods, Author: Chola Wealth Direct
# Group Size: 3
# Correlation: -0.484536826697544
# Mean Performance: -0.005493574735080667
#
# Processing Sector: Consumer Goods, Author: Dolat Capital
# Group Size: 9
# Correlation: -0.22461831501673388
# Mean Performance: 0.01475381199818918
#
# Processing Sector: Consumer Goods, Author: Edelweiss
# Group Size: 14
# Correlation: 0.4450748814251026
# Mean Performance: 0.008167718990094842
# Thresholds met. Adding to results.
#
# Processing Sector: Consumer Goods, Author: Geojit BNP Paribas
# Group Size: 21
# Correlation: -0.11433933605369066
# Mean Performance: -0.0011102094268404525
#
# Processing Sector: Consumer Goods, Author: HDFC Securities
# Group Size: 1
#
# Processing Sector: Consumer Goods, Author: ICICI Securities Limited
# Group Size: 53
# Correlation: -0.04217426792313268
# Mean Performance: -0.010068562126561029
#
# Processing Sector: Consumer Goods, Author: IDBI Capital
# Group Size: 21
# Correlation: -0.2940797753674087
# Mean Performance: -0.0049864027053570965
#
# Processing Sector: Consumer Goods, Author: KRChoksey
# Group Size: 2
# Correlation: 1.0
# Mean Performance: 0.00619148363157585
# Thresholds met. Adding to results.
#
# Processing Sector: Consumer Goods, Author: Karvy
# Group Size: 1
#
# Processing Sector: Consumer Goods, Author: Khambatta Securities
# Group Size: 1
#
# Processing Sector: Consumer Goods, Author: LKP Securities
# Group Size: 1
#
# Processing Sector: Consumer Goods, Author: Motilal Oswal
# Group Size: 48
# Correlation: -0.32068632816620324
# Mean Performance: -0.007013438680540649
#
# Processing Sector: Consumer Goods, Author: Prabhudas Lilladhar
# Group Size: 17
# Correlation: -0.15718546181013196
# Mean Performance: 0.003121137751087865
#
# Processing Sector: Consumer Goods, Author: Sharekhan
# Group Size: 7
# Correlation: 0.45925494681431284
# Mean Performance: -0.0022162216946483427
#
# Processing Sector: Consumer Goods, Author: Ventura
# Group Size: 3
# Correlation: -0.5829919371315984
# Mean Performance: -0.009211372453858667
#
# Processing Sector: Energy, Author: AUM Capital
# Group Size: 2
# Correlation: -1.0
# Mean Performance: -0.0059114814604087
#
# Processing Sector: Energy, Author: Arihant Capital
# Group Size: 1
#
# Processing Sector: Energy, Author: Ashika Research
# Group Size: 4
# Correlation: 0.38774144277493505
# Mean Performance: -0.00014462098740562583
#
# Processing Sector: Energy, Author: Axis Direct
# Group Size: 28
# Correlation: 0.21750283102344056
# Mean Performance: -0.00337168940429186
#
# Processing Sector: Energy, Author: BOB Capital Markets Ltd.
# Group Size: 6
# Correlation: -0.5706002298273314
# Mean Performance: -0.008307288027322201
#
# Processing Sector: Energy, Author: CD Equisearch
# Group Size: 1
#
# Processing Sector: Energy, Author: Dolat Capital
# Group Size: 11
# Correlation: 0.11502758278250802
# Mean Performance: 0.001203675778773554
# Thresholds met. Adding to results.
#
# Processing Sector: Energy, Author: Edelweiss
# Group Size: 17
# Correlation: 0.14844303632745143
# Mean Performance: 0.002179949527793529
# Thresholds met. Adding to results.
#
# Processing Sector: Energy, Author: Geojit BNP Paribas
# Group Size: 24
# Correlation: 0.22465756945834164
# Mean Performance: -0.002563905430154225
#
# Processing Sector: Energy, Author: ICICI Securities Limited
# Group Size: 43
# Correlation: -0.1398979632551569
# Mean Performance: 0.002953766224831552
#
# Processing Sector: Energy, Author: IDBI Capital
# Group Size: 16
# Correlation: -0.4395691797559794
# Mean Performance: -0.0014020592583922748
#
# Processing Sector: Energy, Author: KRChoksey
# Group Size: 1
#
# Processing Sector: Energy, Author: Karvy
# Group Size: 1
#
# Processing Sector: Energy, Author: LKP Securities
# Group Size: 1
#
# Processing Sector: Energy, Author: Monarch Networth Capital Limited
# Group Size: 2

# %%
grid_performance_df

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_heatmap(grid_performance_df):
    # Pivot the data to prepare for the heatmap
    heatmap_data = grid_performance_df.pivot(
        index='correlation_threshold', 
        columns='performance_threshold', 
        values='mean_of_mean_performance'
    )
    
    # Plot the heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(
        heatmap_data, 
        annot=True, 
        fmt=".4f", 
        cmap="coolwarm", 
        cbar_kws={'label': 'Average Performance'}
    )
    plt.title('Grid Search Heatmap of Performance')
    plt.xlabel('Performance Threshold')
    plt.ylabel('Correlation Threshold')
    plt.savefig("performance_heatmap.png")
    plt.show()

# Assuming grid_performance_df is already created
plot_heatmap(grid_performance_df)

# %%
grid_performance_df.to_csv("grid_performance_n1.csv")

# %%
grid_performance_df.describe()

# %%
all_results
