# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import tqdm


def get_best_authors_per_sector(df, start_date, end_date, max_authors=10):
    """
    Find the best performing authors per sector based on correlation between
    expected and actual returns within the specified date range.
    """
    # Filter data for the specified period
    mask = (df['date'] >= start_date) & (df['date'] <= end_date)
    period_df = df[mask].copy()
    
    # Calculate correlation for each author-sector pair
    author_sector_performance = []
    
    for (sector, author), group in period_df.groupby(['Sector', 'author']):
        if len(group) < 2:  # Skip if not enough data points
            continue
            
        correlation = np.corrcoef(group['expected_return'], group['actual_return'])[0, 1]
        
        if not np.isnan(correlation) and correlation > 0:
            author_sector_performance.append({
                'Sector': sector,
                'author': author,
                'correlation': correlation
            })
    
    # Convert to DataFrame and get top authors per sector
    performance_df = pd.DataFrame(author_sector_performance)
    if len(performance_df) == 0:
        return pd.DataFrame(columns=['Sector', 'author', 'correlation'])
        
    return (performance_df.sort_values('correlation', ascending=False)
            .groupby('Sector')
            .head(max_authors)
            .reset_index(drop=True))

def calculate_monthly_performance(df, best_authors_df, target_month):
    """
    Calculate performance for each author-sector pair for a specific month
    using sign(expected_return) * actual_return
    """
    # Filter data for the target month and best authors
    month_start = target_month.replace(day=1)
    month_end = (month_start + pd.offsets.MonthEnd(1))
    
    mask = (df['date'] >= month_start) & (df['date'] <= month_end)
    month_df = df[mask].copy()
    
    # Filter for only the best author-sector pairs
    month_df = month_df.merge(
        best_authors_df[['Sector', 'author']],
        on=['Sector', 'author'],
        how='inner'
    )
    
    # Calculate performance
    month_df['performance'] = np.sign(month_df['expected_return']) * month_df['actual_return']
    
    # Calculate average performance per author-sector
    performance_summary = (month_df.groupby(['Sector', 'author'])
                         ['performance']
                         .agg(['sum', 'count'])
                         .reset_index())
    
    performance_summary['month'] = month_start
    return performance_summary

def run_rolling_analysis(df, start_date, end_date, lookback_period=12):
    """
    Run the rolling analysis month by month
    """
    # Convert dates if they're strings
    start_date = pd.to_datetime(start_date)
    end_date = pd.to_datetime(end_date)
    
    all_monthly_performance = []
    
    current_date = start_date
    while current_date <= end_date:
        # Calculate training period
        training_end = current_date - timedelta(days=1)
        training_start = training_end - pd.DateOffset(months=lookback_period)
        
        # Get best authors based on the training period
        best_authors = get_best_authors_per_sector(
            df,
            training_start,
            training_end
        )
        
        # Calculate performance for the current month
        if not best_authors.empty:
            monthly_perf = calculate_monthly_performance(
                df,
                best_authors,
                current_date
            )
            all_monthly_performance.append(monthly_perf)
        
        # Move to next month
        current_date = current_date + pd.DateOffset(months=1)
    
    # Combine all results
    if all_monthly_performance:
        return pd.concat(all_monthly_performance, ignore_index=True)
    return pd.DataFrame()

def print_monthly_sector_author_performance(results_df):
    """
    Print formatted results showing performance by month, sector, and author
    """
    # Sort by month, sector, and mean performance
    sorted_results = results_df.sort_values(
        ['month', 'Sector', 'sum'],
        ascending=[True, True, False]
    )
    
    # Format and print results
    current_month = None
    current_sector = None
    
    for _, row in sorted_results.iterrows():
        month_str = row['month'].strftime('%Y-%m')
        
        if month_str != current_month:
            print(f"\n=== Month: {month_str} ===")
            current_month = month_str
            current_sector = None
        
        if row['Sector'] != current_sector:
            print(f"\nSector: {row['Sector']}")
            current_sector = row['Sector']
        
        print(f"  Author: {row['author']:<30} "
              f"Cumulative Performance: {row['sum']:6.3f} "
              f"Number of Predictions: {row['count']:3d}")

# Example usage
def main(df):
    # Convert date column to datetime if it's not already
    df['date'] = pd.to_datetime(df['date'])
    
    # Run the analysis
    results = run_rolling_analysis(
        df,
        start_date='2014-06-01',
        end_date='2024-05-31',
        lookback_period=12
    )
    
    # Print results
    print_monthly_sector_author_performance(results)
    
    return results

# %%
# Load the filtered DataFrame from the CSV file
df = pd.read_csv('data/filtered_data_2.csv')
df = df.dropna(subset=['expected_return', 'actual_return'])


# Display the first few rows of the DataFrame to verify it loaded correctly
print(df.head())
# Out:
#           date                    Company Name      Symbol  \
# 0   2015-11-16  speciality restaurants limited  SPECIALITY
# 1   2015-08-13  speciality restaurants limited  SPECIALITY
# 8   2024-05-17           eicher motors limited   EICHERMOT
# 9   2024-05-13           eicher motors limited   EICHERMOT
# 11  2024-05-13           eicher motors limited   EICHERMOT
#
#                       author         Sector  expected_return  actual_return
# 0                      Karvy     Technology         9.432421      -0.018033
# 1        Reliance Securities     Technology         7.189542       0.018065
# 8   BOB Capital Markets Ltd.  Manufacturing        -1.297429       0.030817
# 9               ICICI Direct  Manufacturing        18.090371       0.001189
# 11               Axis Direct  Manufacturing        10.253465       0.001189

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35107 entries, 0 to 41819
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             35107 non-null  object
#  1   Company Name     35107 non-null  object
#  2   Symbol           35107 non-null  object
#  3   author           35107 non-null  object
#  4   Sector           35107 non-null  object
#  5   expected_return  35107 non-null  float64
#  6   actual_return    35107 non-null  float64
# dtypes: float64(2), object(5)
# memory usage: 2.1+ MB

# %%
df2 = main(df)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# === Month: 2014-06 ===
#
# Sector: Consumer Goods
#   Author: Chola Wealth Direct            Cumulative Performance: -0.004 Number of Predictions:   1
#
# Sector: Energy
#   Author: Chola Wealth Direct            Cumulative Performance:  0.085 Number of Predictions:   1
#
# Sector: Finance
#   Author: Chola Wealth Direct            Cumulative Performance:  0.139 Number of Predictions:   1
#
# Sector: Healthcare
#   Author: Chola Wealth Direct            Cumulative Performance:  0.012 Number of Predictions:   1
#
# === Month: 2014-07 ===
#
# Sector: Finance
#   Author: Chola Wealth Direct            Cumulative Performance:  0.074 Number of Predictions:   7
#
# Sector: Manufacturing
#   Author: Chola Wealth Direct            Cumulative Performance: -0.104 Number of Predictions:   3
#
# Sector: Technology
#   Author: Chola Wealth Direct            Cumulative Performance:  0.037 Number of Predictions:   1
#
# === Month: 2014-08 ===
#
# Sector: Consumer Goods
#   Author: Chola Wealth Direct            Cumulative Performance:  0.054 Number of Predictions:   2
#
# Sector: Finance
#   Author: Chola Wealth Direct            Cumulative Performance: -0.011 Number of Predictions:   4
#
# Sector: Healthcare
#   Author: Chola Wealth Direct            Cumulative Performance:  0.110 Number of Predictions:   2
#   Author: Reliance Securities            Cumulative Performance: -0.068 Number of Predictions:   1
#
# Sector: Manufacturing
#   Author: Chola Wealth Direct            Cumulative Performance: -0.063 Number of Predictions:   3
#
# Sector: Technology
#   Author: Chola Wealth Direct            Cumulative Performance:  0.194 Number of Predictions:   4
#
# === Month: 2014-10 ===
#
# Sector: Finance
#   Author: Chola Wealth Direct            Cumulative Performance:  0.252 Number of Predictions:   7
#
# Sector: Manufacturing
#   Author: Ashika Research                Cumulative Performance:  0.087 Number of Predictions:   1
#
# Sector: Technology
#   Author: Chola Wealth Direct            Cumulative Performance:  0.092 Number of Predictions:   3
#
# === Month: 2014-11 ===
#
# Sector: Finance
#   Author: Chola Wealth Direct            Cumulative Performance:  0.090 Number of Predictions:   3
#
# Sector: Healthcare
#   Author: Chola Wealth Direct            Cumulative Performance: -0.071 Number of Predictions:   3
#
# Sector: Technology
#   Author: Chola Wealth Direct            Cumulative Performance:  0.206 Number of Predictions:   5
#
# === Month: 2014-12 ===
#
# Sector: Finance
#   Author: Ashika Research                Cumulative Performance:  0.012 Number of Predictions:   2
#
# === Month: 2015-01 ===
#
# Sector: Finance
#   Author: Chola Wealth Direct            Cumulative Performance:  0.014 Number of Predictions:  11
#
# Sector: Healthcare
#   Author: Chola Wealth Direct            Cumulative Performance:  0.026 Number of Predictions:   1
#
# Sector: Technology
#   Author: Chola Wealth Direct            Cumulative Performance: -0.004 Number of Predictions:   1
#   Author: Karvy                          Cumulative Performance: -0.015 Number of Predictions:   2
#
# === Month: 2015-02 ===
#
# Sector: Agriculture
#   Author: Chola Wealth Direct            Cumulative Performance:  0.015 Number of Predictions:   1
#   Author: Karvy                          Cumulative Performance: -0.020 Number of Predictions:   2
#
# Sector: Finance
#   Author: Karvy                          Cumulative Performance:  0.106 Number of Predictions:   3
#
# Sector: Healthcare
#   Author: Chola Wealth Direct            Cumulative Performance:  0.049 Number of Predictions:   3
#
# Sector: Technology
#   Author: Chola Wealth Direct            Cumulative Performance:  0.162 Number of Predictions:   4
#   Author: Karvy                          Cumulative Performance: -0.016 Number of Predictions:   1
#
# === Month: 2015-03 ===
#
# Sector: Finance
#   Author: Karvy                          Cumulative Performance: -0.033 Number of Predictions:   1
#   Author: Ashika Research                Cumulative Performance: -0.105 Number of Predictions:   1
#
# Sector: Technology
#   Author: Karvy                          Cumulative Performance: -0.013 Number of Predictions:   1
#
# === Month: 2015-04 ===
#
# Sector: Consumer Goods
#   Author: BOB Capital Markets Ltd.       Cumulative Performance:  0.017 Number of Predictions:   1
#
# Sector: Finance
#   Author: Karvy                          Cumulative Performance: -0.147 Number of Predictions:   5
#
# Sector: Technology
#   Author: Karvy                          Cumulative Performance:  0.020 Number of Predictions:   1
#   Author: Chola Wealth Direct            Cumulative Performance: -0.005 Number of Predictions:   1
#
# Sector: Unknown
#   Author: Karvy                          Cumulative Performance: -0.013 Number of Predictions:   2
#
# === Month: 2015-05 ===
#
# Sector: Consumer Goods
#   Author: BOB Capital Markets Ltd.       Cumulative Performance: -0.047 Number of Predictions:   1
#
# Sector: Energy
#   Author: Phillip Capital                Cumulative Performance:  0.028 Number of Predictions:   1
#
# Sector: Healthcare
#   Author: HDFC Securities                Cumulative Performance:  0.015 Number of Predictions:   3
#   Author: Chola Wealth Direct            Cumulative Performance: -0.024 Number of Predictions:   3
#   Author: Karvy                          Cumulative Performance: -0.040 Number of Predictions:   1
#
# Sector: Manufacturing
#   Author: BOB Capital Markets Ltd.       Cumulative Performance: -0.027 Number of Predictions:   2
#
# Sector: Technology
#   Author: HDFC Securities                Cumulative Performance:  0.029 Number of Predictions:   7
#   Author: Chola Wealth Direct            Cumulative Performance: -0.075 Number of Predictions:   3
#   Author: Karvy                          Cumulative Performance: -0.092 Number of Predictions:   3
#
# Sector: Telecommunications
#   Author: Karvy                          Cumulative Performance:  0.007 Number of Predictions:   1
#
# Sector: Unknown
#   Author: Karvy                          Cumulative Performance: -0.034 Number of Predictions:   1
#
# === Month: 2015-06 ===
#
# Sector: Consumer Goods
#   Author: BOB Capital Markets Ltd.       Cumulative Performance: -0.083 Number of Predictions:   1
#
# Sector: Energy
#   Author: Phillip Capital                Cumulative Performance:  0.012 Number of Predictions:   2
#
# Sector: Finance
#   Author: HDFC Securities                Cumulative Performance:  0.108 Number of Predictions:   5
#
# Sector: Healthcare
#   Author: Karvy                          Cumulative Performance:  0.377 Number of Predictions:   1
#   Author: Chola Wealth Direct            Cumulative Performance: -0.014 Number of Predictions:   1
#   Author: HDFC Securities                Cumulative Performance: -0.108 Number of Predictions:   3
#
# Sector: Technology
#   Author: Phillip Capital                Cumulative Performance:  0.004 Number of Predictions:   1
#
# === Month: 2015-07 ===
#
# Sector: Consumer Goods
#   Author: HDFC Securities                Cumulative Performance:  0.026 Number of Predictions:   2
#
# Sector: Energy
#   Author: Phillip Capital                Cumulative Performance:  0.059 Number of Predictions:   5
#
# Sector: Healthcare
#   Author: Chola Wealth Direct            Cumulative Performance:  0.018 Number of Predictions:   1
#   Author: HDFC Securities                Cumulative Performance:  0.014 Number of Predictions:   1
#   Author: Phillip Capital                Cumulative Performance: -0.047 Number of Predictions:   5
#   Author: Karvy                          Cumulative Performance: -0.051 Number of Predictions:   2
#
# Sector: Manufacturing
#   Author: BOB Capital Markets Ltd.       Cumulative Performance: -0.118 Number of Predictions:   2
#
# Sector: Technology
#   Author: Ashika Research                Cumulative Performance:  0.172 Number of Predictions:   2
#   Author: Phillip Capital                Cumulative Performance:  0.167 Number of Predictions:   8
#   Author: Chola Wealth Direct            Cumulative Performance:  0.133 Number of Predictions:   4
#   Author: HDFC Securities                Cumulative Performance:  0.127 Number of Predictions:   6
#   Author: BOB Capital Markets Ltd.       Cumulative Performance:  0.041 Number of Predictions:   1
#
# Sector: Telecommunications
#   Author: HDFC Securities                Cumulative Performance:  0.013 Number of Predictions:   1
#
# Sector: Unknown
#   Author: Karvy                          Cumulative Performance: -0.126 Number of Predictions:   3
#
# === Month: 2015-08 ===
#
# Sector: Agriculture
#   Author: Chola Wealth Direct            Cumulative Performance:  0.000 Number of Predictions:   1
#
# Sector: Consumer Goods
#   Author: Karvy                          Cumulative Performance:  0.085 Number of Predictions:   1
#   Author: BOB Capital Markets Ltd.       Cumulative Performance: -0.238 Number of Predictions:   2
#
# Sector: Energy
#   Author: Chola Wealth Direct            Cumulative Performance: -0.051 Number of Predictions:   1
#   Author: Phillip Capital                Cumulative Performance: -0.058 Number of Predictions:   2
#
# Sector: Finance
#   Author: Reliance Securities            Cumulative Performance:  0.034 Number of Predictions:   1
#   Author: Phillip Capital                Cumulative Performance: -0.222 Number of Predictions:   7
#
# Sector: Healthcare
#   Author: Karvy                          Cumulative Performance:  0.088 Number of Predictions:   4
#   Author: Phillip Capital                Cumulative Performance:  0.055 Number of Predictions:  11
#   Author: Chola Wealth Direct            Cumulative Performance:  0.053 Number of Predictions:   3
#   Author: HDFC Securities                Cumulative Performance: -0.002 Number of Predictions:   1
#
# Sector: Manufacturing
#   Author: BOB Capital Markets Ltd.       Cumulative Performance:  0.029 Number of Predictions:   2
#
# Sector: Technology
#   Author: HDFC Securities                Cumulative Performance:  0.080 Number of Predictions:   3
#   Author: Chola Wealth Direct            Cumulative Performance:  0.010 Number of Predictions:   2
#   Author: Phillip Capital                Cumulative Performance: -0.353 Number of Predictions:  12
#
# Sector: Utilities
#   Author: HDFC Securities                Cumulative Performance: -0.018 Number of Predictions:   1
#
# === Month: 2015-09 ===
#
# Sector: Consumer Goods
#   Author: Karvy                          Cumulative Performance:  0.039 Number of Predictions:   2
#
# Sector: Healthcare
#   Author: Phillip Capital                Cumulative Performance:  0.019 Number of Predictions:   1
#   Author: Karvy                          Cumulative Performance:  0.014 Number of Predictions:   1
#   Author: Reliance Securities            Cumulative Performance: -0.004 Number of Predictions:   1
#
# Sector: Technology
#   Author: Phillip Capital                Cumulative Performance:  0.079 Number of Predictions:   2
#   Author: HDFC Securities                Cumulative Performance:  0.033 Number of Predictions:   2
#
# === Month: 2015-10 ===
#
# Sector: Consumer Goods
#   Author: HDFC Securities                Cumulative Performance:  0.047 Number of Predictions:   2
#
# Sector: Finance
#   Author: Phillip Capital                Cumulative Performance:  0.224 Number of Predictions:  16
#   Author: Reliance Securities            Cumulative Performance: -0.109 Number of Predictions:  14
#
# Sector: Healthcare
#   Author: Phillip Capital                Cumulative Performance:  0.029 Number of Predictions:   6
#   Author: Karvy                          Cumulative Performance:  0.012 Number of Predictions:   4
#   Author: HDFC Securities                Cumulative Performance: -0.034 Number of Predictions:   1
#   Author: BOB Capital Markets Ltd.       Cumulative Performance: -0.055 Number of Predictions:   1
#   Author: Reliance Securities            Cumulative Performance: -0.183 Number of Predictions:   6
#
# Sector: Manufacturing
#   Author: BOB Capital Markets Ltd.       Cumulative Performance:  0.023 Number of Predictions:   2
#
# Sector: Technology
#   Author: HDFC Securities                Cumulative Performance:  0.065 Number of Predictions:   3
#   Author: Reliance Securities            Cumulative Performance:  0.010 Number of Predictions:   3
#   Author: BOB Capital Markets Ltd.       Cumulative Performance: -0.004 Number of Predictions:   1
#   Author: Phillip Capital                Cumulative Performance: -0.543 Number of Predictions:  12
#
# Sector: Unknown
#   Author: Phillip Capital                Cumulative Performance: -0.003 Number of Predictions:   1
#
# === Month: 2015-11 ===
#
# Sector: Agriculture
#   Author: Chola Wealth Direct            Cumulative Performance: -0.068 Number of Predictions:   1
#
# Sector: Consumer Goods
#   Author: HDFC Securities                Cumulative Performance: -0.014 Number of Predictions:   2
#   Author: Karvy                          Cumulative Performance: -0.033 Number of Predictions:   1
#
# Sector: Finance
#   Author: Phillip Capital                Cumulative Performance:  0.097 Number of Predictions:  10
#   Author: Reliance Securities            Cumulative Performance: -0.046 Number of Predictions:   6
#
# Sector: Healthcare
#   Author: Karvy                          Cumulative Performance:  0.063 Number of Predictions:   4
#   Author: Chola Wealth Direct            Cumulative Performance:  0.003 Number of Predictions:   2
#   Author: HDFC Securities                Cumulative Performance: -0.050 Number of Predictions:   3
#   Author: Phillip Capital                Cumulative Performance: -0.159 Number of Predictions:   9
#   Author: Reliance Securities            Cumulative Performance: -0.225 Number of Predictions:   6
#
# Sector: Real Estate
#   Author: Chola Wealth Direct            Cumulative Performance:  0.072 Number of Predictions:   1
#
# Sector: Technology
#   Author: Chola Wealth Direct            Cumulative Performance:  0.063 Number of Predictions:   4
#   Author: Reliance Securities            Cumulative Performance:  0.036 Number of Predictions:   2
#   Author: BOB Capital Markets Ltd.       Cumulative Performance:  0.025 Number of Predictions:   2
#   Author: HDFC Securities                Cumulative Performance: -0.003 Number of Predictions:   4
#
# Sector: Transportation
#   Author: Karvy                          Cumulative Performance: -0.011 Number of Predictions:   1
#
# Sector: Unknown
#   Author: Phillip Capital                Cumulative Performance:  0.102 Number of Predictions:   2
#
# === Month: 2015-12 ===
#
# Sector: Consumer Goods
#   Author: Karvy                          Cumulative Performance:  0.051 Number of Predictions:   1
#
# Sector: Finance
#   Author: Phillip Capital                Cumulative Performance:  0.022 Number of Predictions:   1
#
# Sector: Healthcare
#   Author: Phillip Capital                Cumulative Performance:  0.082 Number of Predictions:   4
#   Author: ICICI Securities Limited       Cumulative Performance:  0.075 Number of Predictions:   2
#   Author: Karvy                          Cumulative Performance:  0.001 Number of Predictions:   2
#
# Sector: Manufacturing
#   Author: Karvy                          Cumulative Performance: -0.027 Number of Predictions:   4
#   Author: BOB Capital Markets Ltd.       Cumulative Performance: -0.054 Number of Predictions:   2
#
# Sector: Technology
#   Author: Angel Broking                  Cumulative Performance:  0.093 Number of Predictions:   1
#   Author: HDFC Securities                Cumulative Performance: -0.017 Number of Predictions:   2
#
# === Month: 2016-01 ===
#
# Sector: Consumer Goods
#   Author: HDFC Securities                Cumulative Performance:  0.029 Number of Predictions:   2
#   Author: Karvy                          Cumulative Performance: -0.028 Number of Predictions:   1
#
# Sector: Energy
#   Author: Reliance Securities            Cumulative Performance: -0.004 Number of Predictions:   4
#
# Sector: Finance
#   Author: Angel Broking                  Cumulative Performance:  0.009 Number of Predictions:   6
#   Author: Phillip Capital                Cumulative Performance: -0.231 Number of Predictions:  13
#
# Sector: Healthcare
#   Author: Chola Wealth Direct            Cumulative Performance:  0.008 Number of Predictions:   1
#   Author: Reliance Securities            Cumulative Performance:  0.008 Number of Predictions:   1
#   Author: Phillip Capital                Cumulative Performance: -0.149 Number of Predictions:   5
#   Author: Karvy                          Cumulative Performance: -0.155 Number of Predictions:   3
#   Author: ICICI Securities Limited       Cumulative Performance: -0.214 Number of Predictions:   4
#
# Sector: Manufacturing
#   Author: Ajcon Global                   Cumulative Performance:  0.012 Number of Predictions:   1
#
# Sector: Technology
#   Author: Reliance Securities            Cumulative Performance:  0.028 Number of Predictions:   1
#   Author: HDFC Securities                Cumulative Performance:  0.015 Number of Predictions:   4
#   Author: Chola Wealth Direct            Cumulative Performance: -0.016 Number of Predictions:   1
#
# Sector: Telecommunications
#   Author: ICICI Securities Limited       Cumulative Performance: -0.009 Number of Predictions:   1
#
# Sector: Unknown
#   Author: Phillip Capital                Cumulative Performance: -0.014 Number of Predictions:   1
#
# === Month: 2016-02 ===
#
# Sector: Agriculture
#   Author: Chola Wealth Direct            Cumulative Performance: -0.023 Number of Predictions:   1
#
# Sector: Consumer Goods
#   Author: HDFC Securities                Cumulative Performance:  0.039 Number of Predictions:   1
#   Author: Karvy                          Cumulative Performance: -0.060 Number of Predictions:   1
#
# Sector: Energy
#   Author: Reliance Securities            Cumulative Performance:  0.045 Number of Predictions:   1
#   Author: ICICI Securities Limited       Cumulative Performance:  0.010 Number of Predictions:   5
#
# Sector: Finance
#   Author: Angel Broking                  Cumulative Performance:  0.095 Number of Predictions:   5
#   Author: Reliance Securities            Cumulative Performance:  0.052 Number of Predictions:   8
#   Author: Phillip Capital                Cumulative Performance:  0.003 Number of Predictions:  13
#
# Sector: Healthcare
#   Author: Phillip Capital                Cumulative Performance:  0.137 Number of Predictions:  15
#   Author: Reliance Securities            Cumulative Performance:  0.121 Number of Predictions:   2
#   Author: HDFC Securities                Cumulative Performance: -0.059 Number of Predictions:   9
#   Author: Chola Wealth Direct            Cumulative Performance: -0.075 Number of Predictions:   3
#   Author: Karvy                          Cumulative Performance: -0.080 Number of Predictions:   2
#   Author: ICICI Securities Limited       Cumulative Performance: -0.278 Number of Predictions:   9
#
# Sector: Technology
#   Author: HDFC Securities                Cumulative Performance:  0.341 Number of Predictions:  10
#   Author: Reliance Securities            Cumulative Performance:  0.105 Number of Predictions:   3
#   Author: BOB Capital Markets Ltd.       Cumulative Performance:  0.027 Number of Predictions:   1
#   Author: Chola Wealth Direct            Cumulative Performance: -0.004 Number of Predictions:   5
#   Author: ICICI Securities Limited       Cumulative Performance: -0.407 Number of Predictions:   9
#
# Sector: Telecommunications
#   Author: Karvy                          Cumulative Performance:  0.014 Number of Predictions:   1
#
# Sector: Transportation
#   Author: Phillip Capital                Cumulative Performance: -0.062 Number of Predictions:   1
#
# Sector: Unknown
#   Author: HDFC Securities                Cumulative Performance: -0.077 Number of Predictions:   4
#   Author: Phillip Capital                Cumulative Performance: -0.237 Number of Predictions:   4
#
# Sector: Utilities
#   Author: HDFC Securities                Cumulative Performance:  0.077 Number of Predictions:   1
#   Author: Phillip Capital                Cumulative Performance:  0.048 Number of Predictions:   2
#
# === Month: 2016-03 ===
#
# Sector: Consumer Goods
#   Author: HDFC Securities                Cumulative Performance:  0.015 Number of Predictions:   1
#
# Sector: Finance
#   Author: Motilal Oswal                  Cumulative Performance:  0.198 Number of Predictions:   7
#   Author: Phillip Capital                Cumulative Performance: -0.002 Number of Predictions:   5
#
# Sector: Healthcare
#   Author: BOB Capital Markets Ltd.       Cumulative Performance:  0.111 Number of Predictions:   1
#   Author: Karvy                          Cumulative Performance: -0.002 Number of Predictions:   1
#
# Sector: Manufacturing
#   Author: HDFC Securities                Cumulative Performance:  0.134 Number of Predictions:   1
#   Author: Motilal Oswal                  Cumulative Performance: -0.012 Number of Predictions:   2
#
# Sector: Technology
#   Author: ICICI Securities Limited       Cumulative Performance:  0.049 Number of Predictions:   3
#   Author: Reliance Securities            Cumulative Performance:  0.025 Number of Predictions:   1
#   Author: HDFC Securities                Cumulative Performance: -0.025 Number of Predictions:   1
#
# Sector: Utilities
#   Author: HDFC Securities                Cumulative Performance: -0.002 Number of Predictions:   1
#
# === Month: 2016-04 ===
#
# Sector: Consumer Goods
#   Author: Karvy                          Cumulative Performance: -0.058 Number of Predictions:   2
#
# Sector: Energy
#   Author: Reliance Securities            Cumulative Performance:  0.077 Number of Predictions:   4
#   Author: ICICI Securities Limited       Cumulative Performance:  0.043 Number of Predictions:   2
#
# Sector: Finance
#   Author: Phillip Capital                Cumulative Performance:  0.099 Number of Predictions:  10
#   Author: Reliance Securities            Cumulative Performance:  0.037 Number of Predictions:   8
#   Author: LKP Securities                 Cumulative Performance: -0.002 Number of Predictions:   1
#   Author: Motilal Oswal                  Cumulative Performance: -0.006 Number of Predictions:  13
#   Author: Angel Broking                  Cumulative Performance: -0.021 Number of Predictions:   2
#   Author: ICICI Securities Limited       Cumulative Performance: -0.033 Number of Predictions:   7
#
# Sector: Healthcare
#   Author: Phillip Capital                Cumulative Performance:  0.075 Number of Predictions:   2
#   Author: HDFC Securities                Cumulative Performance: -0.005 Number of Predictions:   1
#
# Sector: Technology
#   Author: HDFC Securities                Cumulative Performance:  0.010 Number of Predictions:   2
#   Author: ICICI Securities Limited       Cumulative Performance: -0.101 Number of Predictions:   6
#
# === Month: 2016-05 ===
#
# Sector: Agriculture
#   Author: Chola Wealth Direct            Cumulative Performance: -0.074 Number of Predictions:   1
#
# Sector: Consumer Goods
#   Author: HDFC Securities                Cumulative Performance:  0.024 Number of Predictions:   2
#   Author: BOB Capital Markets Ltd.       Cumulative Performance:  0.014 Number of Predictions:   1
#   Author: Reliance Securities            Cumulative Performance: -0.174 Number of Predictions:   2
#
# Sector: Energy
#   Author: Ajcon Global                   Cumulative Performance:  0.007 Number of Predictions:   1
#   Author: Reliance Securities            Cumulative Performance: -0.011 Number of Predictions:   3
#
# Sector: Finance
#   Author: ICICI Securities Limited       Cumulative Performance:  0.275 Number of Predictions:  38
#   Author: Reliance Securities            Cumulative Performance:  0.146 Number of Predictions:  10
#   Author: Motilal Oswal                  Cumulative Performance:  0.137 Number of Predictions:  11
#   Author: Angel Broking                  Cumulative Performance:  0.061 Number of Predictions:   3
#   Author: Phillip Capital                Cumulative Performance: -0.018 Number of Predictions:  16
#
# Sector: Healthcare
#   Author: Reliance Securities            Cumulative Performance:  0.191 Number of Predictions:   3
#   Author: HDFC Securities                Cumulative Performance:  0.065 Number of Predictions:   3
#   Author: Karvy                          Cumulative Performance:  0.019 Number of Predictions:   1
#   Author: BOB Capital Markets Ltd.       Cumulative Performance: -0.006 Number of Predictions:   3
#   Author: Motilal Oswal                  Cumulative Performance: -0.016 Number of Predictions:  16
#   Author: Chola Wealth Direct            Cumulative Performance: -0.066 Number of Predictions:   2
#   Author: Phillip Capital                Cumulative Performance: -0.288 Number of Predictions:  15
#
# Sector: Manufacturing
#   Author: BOB Capital Markets Ltd.       Cumulative Performance:  0.090 Number of Predictions:   6
#
# Sector: Real Estate
#   Author: Phillip Capital                Cumulative Performance: -0.001 Number of Predictions:   1
#
# Sector: Technology
#   Author: HDFC Securities                Cumulative Performance:  0.013 Number of Predictions:   2
#   Author: Reliance Securities            Cumulative Performance:  0.010 Number of Predictions:   2
#   Author: Angel Broking                  Cumulative Performance:  0.004 Number of Predictions:   2
#   Author: BOB Capital Markets Ltd.       Cumulative Performance:  0.002 Number of Predictions:   1
#
# Sector: Telecommunications
#   Author: Motilal Oswal                  Cumulative Performance: -0.027 Number of Predictions:   1
#
# Sector: Utilities
#   Author: Phillip Capital                Cumulative Performance:  0.008 Number of Predictions:   1
#   Author: ICICI Securities Limited       Cumulative Performance: -0.021 Number of Predictions:   2
#
# === Month: 2016-06 ===
#
# Sector: Finance
#   Author: Motilal Oswal                  Cumulative Performance:  0.263 Number of Predictions:   4
#   Author: ICICI Securities Limited       Cumulative Performance: -0.007 Number of Predictions:   2
#   Author: Phillip Capital                Cumulative Performance: -0.045 Number of Predictions:   1
#
# Sector: Healthcare
#   Author: Phillip Capital                Cumulative Performance:  0.029 Number of Predictions:   3
#   Author: Angel Broking                  Cumulative Performance:  0.021 Number of Predictions:   3
#   Author: Motilal Oswal                  Cumulative Performance:  0.010 Number of Predictions:   1
#   Author: HDFC Securities                Cumulative Performance:  0.004 Number of Predictions:   1
#   Author: Karvy                          Cumulative Performance: -0.036 Number of Predictions:   3
#   Author: Ashika Research                Cumulative Performance: -0.082 Number of Predictions:   1
#
# Sector: Manufacturing
#   Author: Motilal Oswal                  Cumulative Performance:  0.243 Number of Predictions:   4
#   Author: Phillip Capital                Cumulative Performance:  0.088 Number of Predictions:   5
#   Author: BOB Capital Markets Ltd.       Cumulative Performance: -0.003 Number of Predictions:   2
#   Author: Karvy                          Cumulative Performance: -0.004 Number of Predictions:   4
#   Author: Systematix Group               Cumulative Performance: -0.093 Number of Predictions:   2
#
# Sector: Technology
#   Author: ICICI Securities Limited       Cumulative Performance:  0.201 Number of Predictions:   4
#   Author: Karvy                          Cumulative Performance:  0.050 Number of Predictions:   1
#   Author: Angel Broking                  Cumulative Performance:  0.022 Number of Predictions:   1
#   Author: HDFC Securities                Cumulative Performance:  0.015 Number of Predictions:   2
#   Author: Reliance Securities            Cumulative Performance:  0.000 Number of Predictions:   1
#   Author: BOB Capital Markets Ltd.       Cumulative Performance: -0.003 Number of Predictions:   1
#
# === Month: 2016-07 ===
#
# Sector: Energy
#   Author: HDFC Securities                Cumulative Performance:  0.039 Number of Predictions:   4
#   Author: Reliance Securities            Cumulative Performance: -0.028 Number of Predictions:   3
#
# Sector: Finance
#   Author: Phillip Capital                Cumulative Performance:  0.297 Number of Predictions:  15
#   Author: Motilal Oswal                  Cumulative Performance:  0.254 Number of Predictions:  21
#   Author: ICICI Securities Limited       Cumulative Performance:  0.042 Number of Predictions:  17
#   Author: Reliance Securities            Cumulative Performance: -0.102 Number of Predictions:  15
#
# Sector: Healthcare
#   Author: Karvy                          Cumulative Performance:  0.108 Number of Predictions:   1
#   Author: Motilal Oswal                  Cumulative Performance:  0.087 Number of Predictions:   3
#   Author: Phillip Capital                Cumulative Performance:  0.019 Number of Predictions:   1
#   Author: Ashika Research                Cumulative Performance:  0.015 Number of Predictions:   1
#
# Sector: Manufacturing
#   Author: BOB Capital Markets Ltd.       Cumulative Performance:  0.044 Number of Predictions:   3
#   Author: Ashika Research                Cumulative Performance:  0.033 Number of Predictions:   2
#   Author: Phillip Capital                Cumulative Performance:  0.027 Number of Predictions:   7
#   Author: Religare                       Cumulative Performance:  0.021 Number of Predictions:   1
#   Author: Motilal Oswal                  Cumulative Performance: -0.007 Number of Predictions:  11
#   Author: Karvy                          Cumulative Performance: -0.037 Number of Predictions:   8
#
# Sector: Technology
#   Author: HDFC Securities                Cumulative Performance:  0.056 Number of Predictions:   7
#   Author: Reliance Securities            Cumulative Performance:  0.035 Number of Predictions:   2
#   Author: Karvy                          Cumulative Performance:  0.022 Number of Predictions:   2
#   Author: Systematix Group               Cumulative Performance: -0.021 Number of Predictions:   1
#   Author: ICICI Securities Limited       Cumulative Performance: -0.061 Number of Predictions:   9
#
# Sector: Telecommunications
#   Author: ICICI Securities Limited       Cumulative Performance:  0.067 Number of Predictions:   2
#   Author: Motilal Oswal                  Cumulative Performance:  0.042 Number of Predictions:   2
#   Author: Reliance Securities            Cumulative Performance:  0.032 Number of Predictions:   1
#
# Sector: Unknown
#   Author: ICICI Securities Limited       Cumulative Performance: -0.045 Number of Predictions:   1
#
# Sector: Utilities
#   Author: Motilal Oswal                  Cumulative Performance:  0.074 Number of Predictions:   2
#   Author: ICICI Securities Limited       Cumulative Performance:  0.062 Number of Predictions:   1
#   Author: HDFC Securities                Cumulative Performance:  0.053 Number of Predictions:   1
#
# === Month: 2016-08 ===
#
# Sector: Consumer Goods
#   Author: Karvy                          Cumulative Performance:  0.015 Number of Predictions:   1
#
# Sector: Energy
#   Author: Reliance Securities            Cumulative Performance:  0.042 Number of Predictions:   5
#   Author: HDFC Securities                Cumulative Performance:  0.030 Number of Predictions:   1
#   Author: Ajcon Global                   Cumulative Performance: -0.018 Number of Predictions:   1
#   Author: ICICI Securities Limited       Cumulative Performance: -0.382 Number of Predictions:  10
#
# Sector: Finance
#   Author: ICICI Securities Limited       Cumulative Performance:  0.655 Number of Predictions:  23
#   Author: HDFC Securities                Cumulative Performance:  0.585 Number of Predictions:  15
#   Author: Phillip Capital                Cumulative Performance:  0.242 Number of Predictions:  11
#   Author: Motilal Oswal                  Cumulative Performance:  0.047 Number of Predictions:   6
#   Author: IDBI Capital                   Cumulative Performance:  0.022 Number of Predictions:   3
#   Author: Reliance Securities            Cumulative Performance: -0.115 Number of Predictions:   4
#
# Sector: Healthcare
#   Author: Motilal Oswal                  Cumulative Performance:  0.083 Number of Predictions:  11
#   Author: Reliance Securities            Cumulative Performance:  0.054 Number of Predictions:   8
#   Author: Ashika Research                Cumulative Performance: -0.009 Number of Predictions:   1
#   Author: Phillip Capital                Cumulative Performance: -0.033 Number of Predictions:  14
#   Author: Angel Broking                  Cumulative Performance: -0.048 Number of Predictions:   2
#   Author: BOB Capital Markets Ltd.       Cumulative Performance: -0.050 Number of Predictions:   2
#
# Sector: Manufacturing
#   Author: Phillip Capital                Cumulative Performance:  0.103 Number of Predictions:  12
#   Author: Karvy                          Cumulative Performance:  0.091 Number of Predictions:   5
#   Author: IDBI Capital                   Cumulative Performance:  0.041 Number of Predictions:   5
#   Author: Religare                       Cumulative Performance:  0.020 Number of Predictions:   1
#   Author: Motilal Oswal                  Cumulative Performance:  0.019 Number of Predictions:  12
#   Author: BOB Capital Markets Ltd.       Cumulative Performance: -0.006 Number of Predictions:   2
#
# Sector: Technology
#   Author: HDFC Securities                Cumulative Performance:  0.347 Number of Predictions:  10
#   Author: Karvy                          Cumulative Performance:  0.150 Number of Predictions:   4
#   Author: Reliance Securities            Cumulative Performance:  0.119 Number of Predictions:   3
#   Author: ICICI Securities Limited       Cumulative Performance:  0.115 Number of Predictions:  13
#   Author: LKP Securities                 Cumulative Performance:  0.114 Number of Predictions:   1
#   Author: Religare                       Cumulative Performance:  0.016 Number of Predictions:   1
#   Author: BOB Capital Markets Ltd.       Cumulative Performance: -0.029 Number of Predictions:   1
#   Author: Systematix Group               Cumulative Performance: -0.068 Number of Predictions:   1
#
# Sector: Telecommunications
#   Author: ICICI Securities Limited       Cumulative Performance: -0.031 Number of Predictions:   2
#
# Sector: Unknown
#   Author: ICICI Securities Limited       Cumulative Performance:  0.180 Number of Predictions:   3
#   Author: Reliance Securities            Cumulative Performance:  0.015 Number of Predictions:   1
#
# Sector: Utilities
#   Author: ICICI Securities Limited       Cumulative Performance: -0.021 Number of Predictions:   1
#   Author: LKP Securities                 Cumulative Performance: -0.023 Number of Predictions:   1
#   Author: Phillip Capital                Cumulative Performance: -0.023 Number of Predictions:   1
#
# === Month: 2016-09 ===
#
# Sector: Consumer Goods
#   Author: Karvy                          Cumulative Performance:  0.017 Number of Predictions:   2
#
# Sector: Energy
#   Author: HDFC Securities                Cumulative Performance:  0.044 Number of Predictions:   4
#   Author: Karvy                          Cumulative Performance: -0.022 Number of Predictions:   1
#
# Sector: Finance
#   Author: Motilal Oswal                  Cumulative Performance:  1.849 Number of Predictions:   8
#   Author: HDFC Securities                Cumulative Performance:  0.034 Number of Predictions:   2
#   Author: Phillip Capital                Cumulative Performance:  0.014 Number of Predictions:   1
#   Author: IDBI Capital                   Cumulative Performance: -0.052 Number of Predictions:   1
#   Author: ICICI Securities Limited       Cumulative Performance: -0.099 Number of Predictions:   5
#
# Sector: Healthcare
#   Author: HDFC Securities                Cumulative Performance:  0.196 Number of Predictions:   2
#   Author: Motilal Oswal                  Cumulative Performance:  0.157 Number of Predictions:   3
# ...
#   Author: Motilal Oswal                  Cumulative Performance: -0.097 Number of Predictions:   9
#
# Sector: Healthcare
#   Author: Prabhudas Lilladhar            Cumulative Performance:  0.044 Number of Predictions:  13
#   Author: BOB Capital Markets Ltd.       Cumulative Performance:  0.029 Number of Predictions:  17
#   Author: Keynote Capitals Ltd           Cumulative Performance: -0.002 Number of Predictions:   2
#   Author: Geojit BNP Paribas             Cumulative Performance: -0.009 Number of Predictions:   2
#   Author: Edelweiss                      Cumulative Performance: -0.050 Number of Predictions:   7
#
# Sector: Manufacturing
#   Author: Axis Direct                    Cumulative Performance:  0.396 Number of Predictions:  18
#   Author: Keynote Capitals Ltd           Cumulative Performance:  0.056 Number of Predictions:   4
#   Author: ICICI Direct                   Cumulative Performance:  0.041 Number of Predictions:   6
#   Author: Geojit BNP Paribas             Cumulative Performance:  0.032 Number of Predictions:   8
#   Author: Ventura                        Cumulative Performance: -0.012 Number of Predictions:   1
#   Author: BOB Capital Markets Ltd.       Cumulative Performance: -0.018 Number of Predictions:  25
#   Author: Prabhudas Lilladhar            Cumulative Performance: -0.041 Number of Predictions:   7
#
# Sector: Real Estate
#   Author: Motilal Oswal                  Cumulative Performance: -0.009 Number of Predictions:   1
#
# Sector: Technology
#   Author: Axis Direct                    Cumulative Performance:  0.245 Number of Predictions:  17
#   Author: IDBI Capital                   Cumulative Performance:  0.147 Number of Predictions:   6
#   Author: Edelweiss                      Cumulative Performance:  0.047 Number of Predictions:   1
#   Author: Sharekhan                      Cumulative Performance:  0.009 Number of Predictions:   2
#   Author: Prabhudas Lilladhar            Cumulative Performance: -0.019 Number of Predictions:   5
#   Author: BOB Capital Markets Ltd.       Cumulative Performance: -0.043 Number of Predictions:   6
#   Author: Motilal Oswal                  Cumulative Performance: -0.127 Number of Predictions:   5
#
# Sector: Unknown
#   Author: SBI Securities                 Cumulative Performance:  0.020 Number of Predictions:   1
#   Author: ICICI Direct                   Cumulative Performance: -0.071 Number of Predictions:   1
#   Author: BOB Capital Markets Ltd.       Cumulative Performance: -0.106 Number of Predictions:   2
#   Author: CD Equisearch                  Cumulative Performance: -0.145 Number of Predictions:   1
#
# Sector: Utilities
#   Author: Prabhudas Lilladhar            Cumulative Performance:  0.032 Number of Predictions:   2
#   Author: Axis Direct                    Cumulative Performance:  0.026 Number of Predictions:   1
#   Author: BOB Capital Markets Ltd.       Cumulative Performance:  0.017 Number of Predictions:   4
#
# === Month: 2024-03 ===
#
# Sector: Consumer Goods
#   Author: Edelweiss                      Cumulative Performance:  0.041 Number of Predictions:   1
#   Author: Prabhudas Lilladhar            Cumulative Performance:  0.028 Number of Predictions:   1
#
# Sector: Energy
#   Author: KRChoksey                      Cumulative Performance: -0.025 Number of Predictions:   1
#   Author: Hem Securities                 Cumulative Performance: -0.043 Number of Predictions:   1
#   Author: Axis Direct                    Cumulative Performance: -0.057 Number of Predictions:   2
#
# Sector: Finance
#   Author: Hem Securities                 Cumulative Performance:  0.070 Number of Predictions:   2
#   Author: IDBI Capital                   Cumulative Performance:  0.051 Number of Predictions:   2
#   Author: ICICI Securities Limited       Cumulative Performance:  0.022 Number of Predictions:   1
#   Author: Edelweiss                      Cumulative Performance:  0.018 Number of Predictions:   1
#   Author: Axis Direct                    Cumulative Performance: -0.001 Number of Predictions:   1
#   Author: BP Wealth                      Cumulative Performance: -0.051 Number of Predictions:   3
#
# Sector: Healthcare
#   Author: KRChoksey                      Cumulative Performance:  0.108 Number of Predictions:   3
#   Author: ICICI Direct                   Cumulative Performance:  0.104 Number of Predictions:   4
#   Author: Prabhudas Lilladhar            Cumulative Performance:  0.033 Number of Predictions:   1
#   Author: CD Equisearch                  Cumulative Performance: -0.015 Number of Predictions:   1
#
# Sector: Manufacturing
#   Author: BOB Capital Markets Ltd.       Cumulative Performance:  0.275 Number of Predictions:   5
#   Author: Geojit BNP Paribas             Cumulative Performance:  0.126 Number of Predictions:   4
#   Author: Ventura                        Cumulative Performance:  0.071 Number of Predictions:   1
#   Author: Axis Direct                    Cumulative Performance:  0.010 Number of Predictions:   1
#   Author: ICICI Direct                   Cumulative Performance:  0.002 Number of Predictions:   2
#
# Sector: Technology
#   Author: Edelweiss                      Cumulative Performance:  0.158 Number of Predictions:   2
#   Author: SBI Securities                 Cumulative Performance:  0.140 Number of Predictions:   2
#   Author: BP Wealth                      Cumulative Performance:  0.068 Number of Predictions:   1
#   Author: Axis Direct                    Cumulative Performance:  0.043 Number of Predictions:   1
#   Author: Prabhudas Lilladhar            Cumulative Performance: -0.032 Number of Predictions:   2
#   Author: KRChoksey                      Cumulative Performance: -0.051 Number of Predictions:   1
#   Author: Sharekhan                      Cumulative Performance: -0.051 Number of Predictions:   1
#
# Sector: Telecommunications
#   Author: KRChoksey                      Cumulative Performance: -0.029 Number of Predictions:   1
#   Author: Prabhudas Lilladhar            Cumulative Performance: -0.066 Number of Predictions:   1
#
# Sector: Transportation
#   Author: Prabhudas Lilladhar            Cumulative Performance: -0.017 Number of Predictions:   1
#
# Sector: Utilities
#   Author: Prabhudas Lilladhar            Cumulative Performance:  0.017 Number of Predictions:   1
#
# === Month: 2024-04 ===
#
# Sector: Consumer Goods
#   Author: Edelweiss                      Cumulative Performance:  0.045 Number of Predictions:   1
#   Author: Motilal Oswal                  Cumulative Performance:  0.024 Number of Predictions:   3
#   Author: BOB Capital Markets Ltd.       Cumulative Performance:  0.023 Number of Predictions:   3
#   Author: IDBI Capital                   Cumulative Performance: -0.024 Number of Predictions:   1
#   Author: Prabhudas Lilladhar            Cumulative Performance: -0.051 Number of Predictions:   2
#   Author: ICICI Securities Limited       Cumulative Performance: -0.125 Number of Predictions:   5
#
# Sector: Energy
#   Author: Hem Securities                 Cumulative Performance:  0.067 Number of Predictions:   1
#   Author: Ashika Research                Cumulative Performance:  0.010 Number of Predictions:   1
#   Author: ICICI Securities Limited       Cumulative Performance: -0.009 Number of Predictions:   1
#   Author: Axis Direct                    Cumulative Performance: -0.034 Number of Predictions:   1
#
# Sector: Finance
#   Author: Edelweiss                      Cumulative Performance:  0.013 Number of Predictions:   3
#   Author: Keynote Capitals Ltd           Cumulative Performance: -0.046 Number of Predictions:   2
#   Author: KRChoksey                      Cumulative Performance: -0.057 Number of Predictions:  14
#   Author: ICICI Securities Limited       Cumulative Performance: -0.093 Number of Predictions:  24
#   Author: IDBI Capital                   Cumulative Performance: -0.106 Number of Predictions:  16
#   Author: Axis Direct                    Cumulative Performance: -0.333 Number of Predictions:  17
#   Author: Sharekhan                      Cumulative Performance: -0.491 Number of Predictions:  21
#   Author: Motilal Oswal                  Cumulative Performance: -0.617 Number of Predictions:  30
#
# Sector: Healthcare
#   Author: Prabhudas Lilladhar            Cumulative Performance:  0.157 Number of Predictions:   1
#   Author: ICICI Direct                   Cumulative Performance:  0.041 Number of Predictions:   5
#   Author: KRChoksey                      Cumulative Performance:  0.035 Number of Predictions:   2
#   Author: BOB Capital Markets Ltd.       Cumulative Performance: -0.000 Number of Predictions:   1
#   Author: ICICI Securities Limited       Cumulative Performance: -0.034 Number of Predictions:   1
#
# Sector: Manufacturing
#   Author: BOB Capital Markets Ltd.       Cumulative Performance:  0.177 Number of Predictions:   3
#   Author: Geojit BNP Paribas             Cumulative Performance:  0.090 Number of Predictions:   2
#   Author: SBI Securities                 Cumulative Performance:  0.057 Number of Predictions:   1
#   Author: ICICI Direct                   Cumulative Performance:  0.039 Number of Predictions:   3
#   Author: BP Wealth                      Cumulative Performance:  0.031 Number of Predictions:   1
#   Author: IDBI Capital                   Cumulative Performance: -0.012 Number of Predictions:   3
#   Author: Axis Direct                    Cumulative Performance: -0.028 Number of Predictions:   2
#   Author: Keynote Capitals Ltd           Cumulative Performance: -0.031 Number of Predictions:   2
#   Author: Hem Securities                 Cumulative Performance: -0.133 Number of Predictions:   4
#
# Sector: Technology
#   Author: Anand Rathi                    Cumulative Performance:  0.119 Number of Predictions:   2
#   Author: Sharekhan                      Cumulative Performance:  0.013 Number of Predictions:   5
#   Author: KRChoksey                      Cumulative Performance: -0.037 Number of Predictions:   1
#   Author: BOB Capital Markets Ltd.       Cumulative Performance: -0.045 Number of Predictions:   1
#   Author: Prabhudas Lilladhar            Cumulative Performance: -0.045 Number of Predictions:   1
#   Author: Axis Direct                    Cumulative Performance: -0.067 Number of Predictions:   2
#   Author: IDBI Capital                   Cumulative Performance: -0.122 Number of Predictions:   2
#
# Sector: Telecommunications
#   Author: KRChoksey                      Cumulative Performance: -0.010 Number of Predictions:   1
#   Author: Prabhudas Lilladhar            Cumulative Performance: -0.010 Number of Predictions:   1
#   Author: ICICI Securities Limited       Cumulative Performance: -0.020 Number of Predictions:   2
#
# Sector: Utilities
#   Author: Axis Direct                    Cumulative Performance: -0.004 Number of Predictions:   1
#
# === Month: 2024-05 ===
#
# Sector: Agriculture
#   Author: Axis Direct                    Cumulative Performance:  0.013 Number of Predictions:   1
#
# Sector: Consumer Goods
#   Author: BOB Capital Markets Ltd.       Cumulative Performance:  0.042 Number of Predictions:   5
#   Author: Prabhudas Lilladhar            Cumulative Performance:  0.019 Number of Predictions:   2
#   Author: Keynote Capitals Ltd           Cumulative Performance:  0.015 Number of Predictions:   1
#   Author: IDBI Capital                   Cumulative Performance:  0.011 Number of Predictions:   1
#   Author: ICICI Securities Limited       Cumulative Performance: -0.005 Number of Predictions:   4
#   Author: Edelweiss                      Cumulative Performance: -0.016 Number of Predictions:   2
#   Author: Motilal Oswal                  Cumulative Performance: -0.026 Number of Predictions:   7
#   Author: Sharekhan                      Cumulative Performance: -0.111 Number of Predictions:   4
#
# Sector: Energy
#   Author: Geojit BNP Paribas             Cumulative Performance:  0.106 Number of Predictions:   7
#   Author: Emkay                          Cumulative Performance:  0.021 Number of Predictions:   3
#   Author: ICICI Securities Limited       Cumulative Performance:  0.011 Number of Predictions:   4
#
# Sector: Finance
#   Author: KRChoksey                      Cumulative Performance: -0.011 Number of Predictions:  12
#   Author: ICICI Securities Limited       Cumulative Performance: -0.058 Number of Predictions:   6
#   Author: Edelweiss                      Cumulative Performance: -0.117 Number of Predictions:   4
#   Author: Axis Direct                    Cumulative Performance: -0.137 Number of Predictions:  18
#   Author: IDBI Capital                   Cumulative Performance: -0.178 Number of Predictions:  12
#   Author: Keynote Capitals Ltd           Cumulative Performance: -0.246 Number of Predictions:   4
#
# Sector: Healthcare
#   Author: Prabhudas Lilladhar            Cumulative Performance:  0.025 Number of Predictions:   1
#   Author: BOB Capital Markets Ltd.       Cumulative Performance:  0.005 Number of Predictions:   8
#   Author: ICICI Direct                   Cumulative Performance: -0.029 Number of Predictions:   9
#   Author: Hem Securities                 Cumulative Performance: -0.062 Number of Predictions:   3
#   Author: Edelweiss                      Cumulative Performance: -0.101 Number of Predictions:   5
#   Author: ICICI Securities Limited       Cumulative Performance: -0.118 Number of Predictions:   9
#   Author: KRChoksey                      Cumulative Performance: -0.172 Number of Predictions:  16
#
# Sector: Manufacturing
#   Author: BOB Capital Markets Ltd.       Cumulative Performance:  0.059 Number of Predictions:  22
#   Author: Geojit BNP Paribas             Cumulative Performance:  0.057 Number of Predictions:  16
#   Author: Keynote Capitals Ltd           Cumulative Performance:  0.046 Number of Predictions:   6
#   Author: CD Equisearch                  Cumulative Performance:  0.005 Number of Predictions:   1
#   Author: Prabhudas Lilladhar            Cumulative Performance: -0.039 Number of Predictions:  10
#   Author: ICICI Direct                   Cumulative Performance: -0.210 Number of Predictions:  12
#   Author: IDBI Capital                   Cumulative Performance: -0.338 Number of Predictions:  20
#   Author: Axis Direct                    Cumulative Performance: -0.526 Number of Predictions:  28
#
# Sector: Retail
#   Author: Keynote Capitals Ltd           Cumulative Performance:  0.055 Number of Predictions:   1
#
# Sector: Technology
#   Author: BOB Capital Markets Ltd.       Cumulative Performance:  0.256 Number of Predictions:   5
#   Author: Prabhudas Lilladhar            Cumulative Performance:  0.118 Number of Predictions:   4
#   Author: IDBI Capital                   Cumulative Performance:  0.085 Number of Predictions:   8
#   Author: BP Wealth                      Cumulative Performance:  0.033 Number of Predictions:   1
#   Author: Keynote Capitals Ltd           Cumulative Performance: -0.002 Number of Predictions:   2
#   Author: Axis Direct                    Cumulative Performance: -0.050 Number of Predictions:  14
#   Author: Sharekhan                      Cumulative Performance: -0.074 Number of Predictions:   5
#
# Sector: Telecommunications
#   Author: Keynote Capitals Ltd           Cumulative Performance:  0.011 Number of Predictions:   1
#
# Sector: Unknown
#   Author: ICICI Direct                   Cumulative Performance:  0.076 Number of Predictions:   1
#   Author: ICICI Securities Limited       Cumulative Performance:  0.021 Number of Predictions:   1
#   Author: BOB Capital Markets Ltd.       Cumulative Performance: -0.004 Number of Predictions:   3
#   Author: Motilal Oswal                  Cumulative Performance: -0.036 Number of Predictions:   5
#   Author: Sharekhan                      Cumulative Performance: -0.101 Number of Predictions:   3
#
# Sector: Utilities
#   Author: BOB Capital Markets Ltd.       Cumulative Performance:  0.110 Number of Predictions:   3
#   Author: Axis Direct                    Cumulative Performance:  0.074 Number of Predictions:   1
#   Author: ICICI Direct                   Cumulative Performance:  0.074 Number of Predictions:   1
#   Author: Prabhudas Lilladhar            Cumulative Performance:  0.074 Number of Predictions:   1

# %%
df2.to_csv("data/cumulative_performance_summary.csv")

# %%
df2
# Out:
#               Sector                    author       sum  count      month
# 0     Consumer Goods       Chola Wealth Direct -0.003993      1 2014-06-01
# 1             Energy       Chola Wealth Direct  0.085451      1 2014-06-01
# 2            Finance       Chola Wealth Direct  0.138710      1 2014-06-01
# 3         Healthcare       Chola Wealth Direct  0.011628      1 2014-06-01
# 4            Finance       Chola Wealth Direct  0.074175      7 2014-07-01
# ...              ...                       ...       ...    ...        ...
# 3024         Unknown                 Sharekhan -0.101278      3 2024-05-01
# 3025       Utilities               Axis Direct  0.073665      1 2024-05-01
# 3026       Utilities  BOB Capital Markets Ltd.  0.109692      3 2024-05-01
# 3027       Utilities              ICICI Direct  0.073665      1 2024-05-01
# 3028       Utilities       Prabhudas Lilladhar  0.073665      1 2024-05-01
#
# [3029 rows x 5 columns]

# %%
cum_df = pd.read_csv('data/cumulative_performance_summary.csv')

# %%
cum_df['sum'].mean()
# Out:
# 0.0076756364890543235

# %%
cum_df.describe()
# Out:
#         Unnamed: 0          sum        count
# count  3029.000000  3029.000000  3029.000000
# mean   1514.000000     0.007676     3.725982
# std     874.541308     0.247874     5.012882
# min       0.000000   -10.032209     1.000000
# 25%     757.000000    -0.038762     1.000000
# 50%    1514.000000     0.003709     2.000000
# 75%    2271.000000     0.047160     4.000000
# max    3028.000000     4.856564    42.000000

# %%
cum_df.info()
