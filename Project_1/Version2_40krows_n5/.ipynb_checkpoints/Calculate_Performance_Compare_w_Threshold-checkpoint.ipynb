# %%
from datetime import timedelta
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
# Load the filtered DataFrame from the CSV file
# Define the file path
file_path = r'C:\Users\disch\Desktop\CiteSert\Project_1\Version2_40krows_n5\input_data\filtered_data_2.csv'

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

df = df.dropna(subset=['expected_return', 'actual_return'])


# Display the first few rows of the DataFrame to verify it loaded correctly
print(df.head())
# Out:
#           date                    Company Name      Symbol  \
# 0   2015-11-16  speciality restaurants limited  SPECIALITY
# 1   2015-08-13  speciality restaurants limited  SPECIALITY
# 8   2024-05-17           eicher motors limited   EICHERMOT
# 9   2024-05-13           eicher motors limited   EICHERMOT
# 11  2024-05-13           eicher motors limited   EICHERMOT
#
#                       author         Sector  expected_return  actual_return
# 0                      Karvy     Technology         9.432421      -0.018033
# 1        Reliance Securities     Technology         7.189542       0.018065
# 8   BOB Capital Markets Ltd.  Manufacturing        -1.297429       0.030817
# 9               ICICI Direct  Manufacturing        18.090371       0.001189
# 11               Axis Direct  Manufacturing        10.253465       0.001189

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35107 entries, 0 to 41819
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             35107 non-null  object
#  1   Company Name     35107 non-null  object
#  2   Symbol           35107 non-null  object
#  3   author           35107 non-null  object
#  4   Sector           35107 non-null  object
#  5   expected_return  35107 non-null  float64
#  6   actual_return    35107 non-null  float64
# dtypes: float64(2), object(5)
# memory usage: 2.1+ MB

# %%
def calculate_correlation(expected_returns, actual_returns):
    """
    Calculate the correlation between expected and actual returns,
    ensuring no division by zero occurs.
    
    Args:
        expected_returns (pd.Series): Expected returns.
        actual_returns (pd.Series): Actual returns.

    Returns:
        float: Correlation coefficient, or NaN if not calculable.
    """
    # Check standard deviation to avoid division by zero
    if np.std(expected_returns) == 0 or np.std(actual_returns) == 0:
        return np.nan
    
    # Calculate correlation
    return np.corrcoef(expected_returns, actual_returns)[0, 1]

# %%
def get_best_authors_by_sector(df, start_date, end_date, corr_threshold, perf_threshold, max_authors=10):
    """
    Identify the best-performing authors per sector within a specific date range based on 
    correlation and mean performance thresholds.
    """
    print("\n### get_best_authors_by_sector ###")
    print(f"Start Date: {start_date}, End Date: {end_date}")
    print(f"Max Authors per Sector: {max_authors}, Correlation Threshold: {corr_threshold}, Performance Threshold: {perf_threshold}")
    
    # Convert date column to datetime if necessary
    df['date'] = pd.to_datetime(df['date'])
    
    # Filter data for the specified date range
    period_df = df[(df['date'] >= start_date) & (df['date'] <= end_date)].copy()
    print(f"Filtered Data Shape: {period_df.shape}")

    if period_df.empty:
        print("No data available for the specified date range.")
        return pd.DataFrame(columns=['Sector', 'author', 'correlation', 'mean_performance'])

    # Calculate performance metrics for each sector-author pair
    author_sector_performance = []
    grouped = period_df.groupby(['Sector', 'author'])
    print(f"Number of Sector-Author Groups: {len(grouped)}")

    for (sector, author), group in grouped:
        # print(f"\nProcessing Sector: {sector}, Author: {author}")
        # print(f"Group Size: {len(group)}")

        if len(group) < 2:  # Ensure enough data points for correlation calculation
            print("Not enough data points for correlation calculation. Skipping.")
            continue

        # Compute correlation between expected and actual returns
        correlation = calculate_correlation(group['expected_return'], group['actual_return'])
        # print(f"Correlation: {correlation}")

        # Compute mean performance
        group['performance'] = np.sign(group['expected_return']) * group['actual_return']
        mean_performance = group['performance'].mean()
        # print(f"Mean Performance: {mean_performance}")

        # Store results if thresholds are met
        if not np.isnan(correlation) and correlation > corr_threshold and mean_performance > perf_threshold:
            print("Thresholds met. Adding to results.")
            author_sector_performance.append({
                'Sector': sector,
                'author': author,
                'correlation': correlation,
                'mean_performance': mean_performance
            })
        else:
            print("Thresholds not met. Skipping.")

    # Create a DataFrame from the results
    performance_df = pd.DataFrame(author_sector_performance)
    print(f"\nPerformance DataFrame Shape: {performance_df.shape}")

    if performance_df.empty:
        print("No authors met the thresholds.")
        return pd.DataFrame(columns=['Sector', 'author', 'correlation', 'mean_performance'])

    # Sort authors by correlation and mean performance, and retain top authors per sector
    print("Sorting and selecting top authors by sector.")
    top_authors_df = (performance_df
                      .sort_values(['correlation', 'mean_performance'], ascending=[False, False])
                      .groupby('Sector')
                      .head(max_authors)
                      .reset_index(drop=True))
    print(f"Top Authors DataFrame Shape: {top_authors_df.shape}")
    print(f"Top Authors DataFrame Sample:\n{top_authors_df.head()}")

    return top_authors_df

# %%
def calculate_monthly_performance(df, best_authors_df, target_month):
    """
    Calculate performance for each author-sector pair for a specific month
    using sign(expected_return) * actual_return
    """
    print(f"\nCalculating monthly performance for: {target_month.strftime('%Y-%m')}")

    # Define month range
    month_start = target_month.replace(day=1)
    month_end = (month_start + pd.offsets.MonthEnd(1))
    print(f"Month Start: {month_start}, Month End: {month_end}")

    # Filter data for the target month
    mask = (df['date'] >= month_start) & (df['date'] <= month_end)
    month_df = df[mask].copy()
    print(f"Filtered Data for Month: {month_df.shape[0]} rows")

    # Merge with best authors
    print(f"Best Authors DataFrame Shape: {best_authors_df.shape}")
    month_df = month_df.merge(
        best_authors_df[['Sector', 'author']],
        on=['Sector', 'author'],
        how='inner'
    )
    print(f"Data After Merging with Best Authors: {month_df.shape[0]} rows")

    # Calculate performance
    month_df['performance'] = np.sign(month_df['expected_return']) * month_df['actual_return']
    print(f"Performance Column Calculated. Sample Data:\n{month_df[['Sector', 'author', 'performance']].head()}")

    # Group and summarize performance
    performance_summary = (month_df.groupby(['Sector', 'author'])
                           ['performance']
                           .agg(mean='mean', count='count')
                           .reset_index())
    performance_summary['month'] = month_start
    print(f"Performance Summary for {target_month.strftime('%Y-%m')}:\n{performance_summary.head()}")

    return performance_summary

def run_rolling_analysis(df, start_date, end_date, lookback_period=12, a=0.5, b=0.5):
    """
    Run the rolling analysis month by month
    """
    print("\nStarting Rolling Analysis")
    print(f"Start Date: {start_date}, End Date: {end_date}, Lookback Period: {lookback_period} months")
    print(f"Thresholds: Correlation (a={a}), Performance (b={b})")

    # Convert dates if they're strings
    start_date = pd.to_datetime(start_date)
    end_date = pd.to_datetime(end_date)

    all_monthly_performance = []
    current_date = start_date

    while current_date <= end_date:
        print(f"\nProcessing Month: {current_date.strftime('%Y-%m')}")
        
        # Define training period
        training_end = current_date - timedelta(days=1)
        training_start = training_end - pd.DateOffset(months=lookback_period)
        print(f"Training Period: Start {training_start}, End {training_end}")

        # Get best authors
        best_authors = get_best_authors_by_sector(df, training_start, training_end, a, b)
        print(f"Best Authors DataFrame Shape: {best_authors.shape}")

        # Calculate performance for the current month
        if not best_authors.empty:
            monthly_perf = calculate_monthly_performance(df, best_authors, current_date)
            all_monthly_performance.append(monthly_perf)

            print(f"Monthly Performance for {current_date.strftime('%Y-%m')}:\n", monthly_perf.head())
        else:
            print(f"No Best Authors Found for {current_date.strftime('%Y-%m')}")

        # Move to next month
        current_date = current_date + pd.DateOffset(months=1)

    # Combine all results
    if all_monthly_performance:
        combined_results = pd.concat(all_monthly_performance, ignore_index=True)
        print(f"\nCombined Performance DataFrame Shape: {combined_results.shape}")
        return combined_results
    else:
        print("No performance data collected.")
        return pd.DataFrame()

# %%
def main(df):
    # Convert date column to datetime if it's not already
    df['date'] = pd.to_datetime(df['date'])
    
    # Define the grid for correlation and performance thresholds
    correlation_thresholds = np.arange(0, 1.0, 0.1)
    performance_thresholds = np.arange(0, 1.0, 0.1)
    
    # Initialize a dictionary to store results for each iteration
    all_results = {}
    iteration_results = []
    iteration = 0

    # Iterate over the grid of thresholds
    for a in tqdm(correlation_thresholds, desc="Correlation Thresholds"):
        for b in tqdm(performance_thresholds, desc="Performance Thresholds", leave=False):
            mean_performance_values = []
            
            # Run the rolling analysis
            results_df = run_rolling_analysis(
                df,
                start_date='2014-06-01',
                end_date='2022-12-31',
                lookback_period=12,
                a=a,
                b=b
            )
                
            # Calculate mean performance for the iteration
            mean_of_mean_performance = results_df['mean'].mean()
            
            # Save the mean performance value
            mean_performance_values.append(mean_of_mean_performance)
            
            # Save the results dataframe for the iteration
            iteration_key = f"iter_{iteration}_a_{a}_b_{b}"
            all_results[iteration_key] = results_df
            
            # Increment iteration counter
            iteration += 1

            
            print(f"Iteration {iteration}: Current Mean of Mean Performance = {mean_of_mean_performance:.4f}")
        
        # Store mean performance across all iterations for this grid combination
        avg_performance = np.nanmean(mean_performance_values)
        iteration_results.append({
            'correlation_threshold': a,
            'performance_threshold': b,
            'average_performance': avg_performance
        })

    # Convert iteration results to a DataFrame for analysis
    grid_performance_df = pd.DataFrame(iteration_results)
    
    return all_results, grid_performance_df

# %%
all_results, grid_performance_df = main(df)
# Out:
# Correlation Thresholds:   0%|                                                                   | 0/10 [00:00<?, ?it/s]
# Performance Thresholds:   0%|                                                                   | 0/10 [00:00<?, ?it/s]
# Starting Rolling Analysis
# Start Date: 2014-06-01, End Date: 2022-12-31, Lookback Period: 12 months
# Thresholds: Correlation (a=0.0), Performance (b=0.0)
#
# Processing Month: 2014-06
# Training Period: Start 2013-05-31 00:00:00, End 2014-05-31 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2013-05-31 00:00:00, End Date: 2014-05-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (129, 7)
# Number of Sector-Author Groups: 24
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
#
# Performance DataFrame Shape: (5, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (5, 4)
# Top Authors DataFrame Sample:
#            Sector               author  correlation  mean_performance
# 0   Manufacturing      Ashika Research     1.000000          0.061157
# 1  Consumer Goods  Chola Wealth Direct     0.780648          0.030162
# 2         Finance      Ashika Research     0.636525          0.057608
# 3      Technology  Chola Wealth Direct     0.471610          0.010378
# 4   Manufacturing  Chola Wealth Direct     0.009512          0.004274
# Best Authors DataFrame Shape: (5, 4)
#
# Calculating monthly performance for: 2014-06
# Month Start: 2014-06-01 00:00:00, Month End: 2014-06-30 00:00:00
# Filtered Data for Month: 5 rows
# Best Authors DataFrame Shape: (5, 4)
# Data After Merging with Best Authors: 1 rows
# Performance Column Calculated. Sample Data:
#            Sector               author  performance
# 0  Consumer Goods  Chola Wealth Direct    -0.003993
# Performance Summary for 2014-06:
#            Sector               author      mean  count      month
# 0  Consumer Goods  Chola Wealth Direct -0.003993      1 2014-06-01
# Monthly Performance for 2014-06:
#             Sector               author      mean  count      month
# 0  Consumer Goods  Chola Wealth Direct -0.003993      1 2014-06-01
#
# Processing Month: 2014-07
# Training Period: Start 2013-06-30 00:00:00, End 2014-06-30 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2013-06-30 00:00:00, End Date: 2014-06-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (126, 7)
# Number of Sector-Author Groups: 23
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
#
# Performance DataFrame Shape: (7, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (7, 4)
# Top Authors DataFrame Sample:
#           Sector               author  correlation  mean_performance
# 0  Manufacturing      Ashika Research     1.000000          0.061157
# 1     Healthcare  Chola Wealth Direct     0.944133          0.001494
# 2        Finance      Ashika Research     0.636525          0.057608
# 3     Technology  Chola Wealth Direct     0.481588          0.018680
# 4    Agriculture  Chola Wealth Direct     0.380841          0.029773
# Best Authors DataFrame Shape: (7, 4)
#
# Calculating monthly performance for: 2014-07
# Month Start: 2014-07-01 00:00:00, Month End: 2014-07-31 00:00:00
# Filtered Data for Month: 15 rows
# Best Authors DataFrame Shape: (7, 4)
# Data After Merging with Best Authors: 4 rows
# Performance Column Calculated. Sample Data:
#           Sector               author  performance
# 0     Technology  Chola Wealth Direct     0.036590
# 1  Manufacturing  Chola Wealth Direct     0.017699
# 2  Manufacturing  Chola Wealth Direct    -0.114576
# 3  Manufacturing  Chola Wealth Direct    -0.006933
# Performance Summary for 2014-07:
#           Sector               author      mean  count      month
# 0  Manufacturing  Chola Wealth Direct -0.034603      3 2014-07-01
# 1     Technology  Chola Wealth Direct  0.036590      1 2014-07-01
# Monthly Performance for 2014-07:
#            Sector               author      mean  count      month
# 0  Manufacturing  Chola Wealth Direct -0.034603      3 2014-07-01
# 1     Technology  Chola Wealth Direct  0.036590      1 2014-07-01
#
# Processing Month: 2014-08
# Training Period: Start 2013-07-31 00:00:00, End 2014-07-31 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2013-07-31 00:00:00, End Date: 2014-07-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (134, 7)
# Number of Sector-Author Groups: 24
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
#
# Performance DataFrame Shape: (9, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (9, 4)
# Top Authors DataFrame Sample:
#           Sector               author  correlation  mean_performance
# 0  Manufacturing      Ashika Research     1.000000          0.061157
# 1     Healthcare  Reliance Securities     0.949573          0.016258
# 2     Healthcare  Chola Wealth Direct     0.944133          0.001494
# 3        Finance      Ashika Research     0.636525          0.057608
# 4     Technology  Chola Wealth Direct     0.464662          0.019576
# Best Authors DataFrame Shape: (9, 4)
#
# Calculating monthly performance for: 2014-08
# Month Start: 2014-08-01 00:00:00, Month End: 2014-08-31 00:00:00
# Filtered Data for Month: 20 rows
# Best Authors DataFrame Shape: (9, 4)
# Data After Merging with Best Authors: 16 rows
# Performance Column Calculated. Sample Data:
#            Sector               author  performance
# 0   Manufacturing  Chola Wealth Direct     0.050710
# 1  Consumer Goods  Chola Wealth Direct     0.029454
# 2         Finance  Chola Wealth Direct    -0.111011
# 3         Finance  Chola Wealth Direct    -0.040643
# 4  Consumer Goods  Chola Wealth Direct     0.025031
# Performance Summary for 2014-08:
#            Sector               author      mean  count      month
# 0  Consumer Goods  Chola Wealth Direct  0.027243      2 2014-08-01
# 1         Finance  Chola Wealth Direct -0.002865      4 2014-08-01
# 2      Healthcare  Chola Wealth Direct  0.054960      2 2014-08-01
# 3      Healthcare  Reliance Securities -0.068325      1 2014-08-01
# 4   Manufacturing  Chola Wealth Direct -0.021035      3 2014-08-01
# Monthly Performance for 2014-08:
#             Sector               author      mean  count      month
# 0  Consumer Goods  Chola Wealth Direct  0.027243      2 2014-08-01
# 1         Finance  Chola Wealth Direct -0.002865      4 2014-08-01
# 2      Healthcare  Chola Wealth Direct  0.054960      2 2014-08-01
# 3      Healthcare  Reliance Securities -0.068325      1 2014-08-01
# 4   Manufacturing  Chola Wealth Direct -0.021035      3 2014-08-01
#
# Processing Month: 2014-09
# Training Period: Start 2013-08-31 00:00:00, End 2014-08-31 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2013-08-31 00:00:00, End Date: 2014-08-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (131, 7)
# Number of Sector-Author Groups: 22
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
#
# Performance DataFrame Shape: (5, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (5, 4)
# Top Authors DataFrame Sample:
#         Sector               author  correlation  mean_performance
# 0      Finance      Ashika Research     0.991712          0.031137
# 1   Healthcare  Chola Wealth Direct     0.693802          0.004287
# 2   Technology  Chola Wealth Direct     0.598948          0.029131
# 3  Agriculture  Chola Wealth Direct     0.380841          0.029773
# 4      Finance  Chola Wealth Direct     0.051034          0.006171
# Best Authors DataFrame Shape: (5, 4)
#
# Calculating monthly performance for: 2014-09
# Month Start: 2014-09-01 00:00:00, Month End: 2014-09-30 00:00:00
# Filtered Data for Month: 4 rows
# Best Authors DataFrame Shape: (5, 4)
# Data After Merging with Best Authors: 0 rows
# Performance Column Calculated. Sample Data:
# Empty DataFrame
# Columns: [Sector, author, performance]
# Index: []
# Performance Summary for 2014-09:
# Empty DataFrame
# Columns: [Sector, author, mean, count, month]
# Index: []
# Monthly Performance for 2014-09:
#  Empty DataFrame
# Columns: [Sector, author, mean, count, month]
# Index: []
#
# Processing Month: 2014-10
# Training Period: Start 2013-09-30 00:00:00, End 2014-09-30 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2013-09-30 00:00:00, End Date: 2014-09-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (133, 7)
# Number of Sector-Author Groups: 21
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
#
# Performance DataFrame Shape: (6, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (6, 4)
# Top Authors DataFrame Sample:
#           Sector               author  correlation  mean_performance
# 0        Finance      Ashika Research     0.991712          0.031137
# 1  Manufacturing      Ashika Research     0.754486          0.015246
# 2     Healthcare  Chola Wealth Direct     0.693802          0.004287
# 3     Technology  Chola Wealth Direct     0.598948          0.029131
# 4    Agriculture  Chola Wealth Direct     0.380841          0.029773
# Best Authors DataFrame Shape: (6, 4)
#
# Calculating monthly performance for: 2014-10
# Month Start: 2014-10-01 00:00:00, Month End: 2014-10-31 00:00:00
# Filtered Data for Month: 17 rows
# Best Authors DataFrame Shape: (6, 4)
# Data After Merging with Best Authors: 11 rows
# Performance Column Calculated. Sample Data:
#        Sector               author  performance
# 0  Technology  Chola Wealth Direct     0.035114
# 1     Finance  Chola Wealth Direct     0.037505
# 2     Finance  Chola Wealth Direct     0.091167
# 3     Finance  Chola Wealth Direct     0.034856
# 4     Finance  Chola Wealth Direct     0.030125
# Performance Summary for 2014-10:
#           Sector               author      mean  count      month
# 0        Finance  Chola Wealth Direct  0.035991      7 2014-10-01
# 1  Manufacturing      Ashika Research  0.086828      1 2014-10-01
# 2     Technology  Chola Wealth Direct  0.030832      3 2014-10-01
# Monthly Performance for 2014-10:
#            Sector               author      mean  count      month
# 0        Finance  Chola Wealth Direct  0.035991      7 2014-10-01
# 1  Manufacturing      Ashika Research  0.086828      1 2014-10-01
# 2     Technology  Chola Wealth Direct  0.030832      3 2014-10-01
#
# Processing Month: 2014-11
# Training Period: Start 2013-10-31 00:00:00, End 2014-10-31 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2013-10-31 00:00:00, End Date: 2014-10-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (142, 7)
# Number of Sector-Author Groups: 21
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
#
# Performance DataFrame Shape: (5, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (5, 4)
# Top Authors DataFrame Sample:
#         Sector               author  correlation  mean_performance
# 0      Finance      Ashika Research     0.991712          0.031137
# 1   Healthcare  Chola Wealth Direct     0.693802          0.004287
# 2   Technology  Chola Wealth Direct     0.597194          0.029857
# 3  Agriculture  Chola Wealth Direct     0.380841          0.029773
# 4      Finance  Chola Wealth Direct     0.084963          0.010232
# Best Authors DataFrame Shape: (5, 4)
#
# Calculating monthly performance for: 2014-11
# Month Start: 2014-11-01 00:00:00, Month End: 2014-11-30 00:00:00
# Filtered Data for Month: 26 rows
# Best Authors DataFrame Shape: (5, 4)
# Data After Merging with Best Authors: 11 rows
# Performance Column Calculated. Sample Data:
#        Sector               author  performance
# 0  Technology  Chola Wealth Direct     0.069276
# 1     Finance  Chola Wealth Direct    -0.005178
# 2  Technology  Chola Wealth Direct     0.059008
# 3     Finance  Chola Wealth Direct     0.075773
# 4  Technology  Chola Wealth Direct     0.029917
# Performance Summary for 2014-11:
#        Sector               author      mean  count      month
# 0     Finance  Chola Wealth Direct  0.030082      3 2014-11-01
# 1  Healthcare  Chola Wealth Direct -0.023794      3 2014-11-01
# 2  Technology  Chola Wealth Direct  0.041265      5 2014-11-01
# Monthly Performance for 2014-11:
#         Sector               author      mean  count      month
# 0     Finance  Chola Wealth Direct  0.030082      3 2014-11-01
# 1  Healthcare  Chola Wealth Direct -0.023794      3 2014-11-01
# 2  Technology  Chola Wealth Direct  0.041265      5 2014-11-01
#
# Processing Month: 2014-12
# Training Period: Start 2013-11-30 00:00:00, End 2014-11-30 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2013-11-30 00:00:00, End Date: 2014-11-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (151, 7)
# Number of Sector-Author Groups: 24
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
#
# Performance DataFrame Shape: (5, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (5, 4)
# Top Authors DataFrame Sample:
#         Sector               author  correlation  mean_performance
# 0  Agriculture  Chola Wealth Direct     1.000000          0.013391
# 1  Agriculture                Karvy     1.000000          0.051687
# 2      Finance      Ashika Research     0.991712          0.031137
# 3   Technology  Chola Wealth Direct     0.483749          0.038991
# 4      Finance  Chola Wealth Direct     0.039325          0.013661
# Best Authors DataFrame Shape: (5, 4)
#
# Calculating monthly performance for: 2014-12
# Month Start: 2014-12-01 00:00:00, Month End: 2014-12-31 00:00:00
# Filtered Data for Month: 7 rows
# Best Authors DataFrame Shape: (5, 4)
# Data After Merging with Best Authors: 2 rows
# Performance Column Calculated. Sample Data:
#     Sector           author  performance
# 0  Finance  Ashika Research     0.001387
# 1  Finance  Ashika Research     0.011078
# Performance Summary for 2014-12:
#     Sector           author      mean  count      month
# 0  Finance  Ashika Research  0.006232      2 2014-12-01
# Monthly Performance for 2014-12:
#      Sector           author      mean  count      month
# 0  Finance  Ashika Research  0.006232      2 2014-12-01
#
# Processing Month: 2015-01
# Training Period: Start 2013-12-31 00:00:00, End 2014-12-31 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2013-12-31 00:00:00, End Date: 2014-12-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (156, 7)
# Number of Sector-Author Groups: 25
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
#
# Performance DataFrame Shape: (7, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (7, 4)
# Top Authors DataFrame Sample:
#         Sector               author  correlation  mean_performance
# 0  Agriculture  Chola Wealth Direct     1.000000          0.013391
# 1      Finance                Karvy     1.000000          0.001488
# 2  Agriculture                Karvy     1.000000          0.051687
# 3      Finance      Ashika Research     0.929636          0.021175
# 4   Technology  Chola Wealth Direct     0.483749          0.038991
# Best Authors DataFrame Shape: (7, 4)
#
# Calculating monthly performance for: 2015-01
# Month Start: 2015-01-01 00:00:00, Month End: 2015-01-31 00:00:00
# Filtered Data for Month: 23 rows
# Best Authors DataFrame Shape: (7, 4)
# Data After Merging with Best Authors: 14 rows
# Performance Column Calculated. Sample Data:
#     Sector               author  performance
# 0  Finance  Chola Wealth Direct     0.014909
# 1  Finance  Chola Wealth Direct     0.005869
# 2  Finance  Chola Wealth Direct     0.067993
# 3  Finance  Chola Wealth Direct    -0.014464
# 4  Finance  Chola Wealth Direct    -0.003081
# Performance Summary for 2015-01:
#        Sector               author      mean  count      month
# 0     Finance  Chola Wealth Direct  0.001251     11 2015-01-01
# 1  Technology  Chola Wealth Direct -0.004273      1 2015-01-01
# 2  Technology                Karvy -0.007308      2 2015-01-01
# Monthly Performance for 2015-01:
#         Sector               author      mean  count      month
# 0     Finance  Chola Wealth Direct  0.001251     11 2015-01-01
# 1  Technology  Chola Wealth Direct -0.004273      1 2015-01-01
# 2  Technology                Karvy -0.007308      2 2015-01-01
#
# Processing Month: 2015-02
# Training Period: Start 2014-01-31 00:00:00, End 2015-01-31 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2014-01-31 00:00:00, End Date: 2015-01-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (169, 7)
# Number of Sector-Author Groups: 29
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
#
# Performance DataFrame Shape: (6, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (6, 4)
# Top Authors DataFrame Sample:
#         Sector               author  correlation  mean_performance
# 0  Agriculture  Chola Wealth Direct     1.000000          0.013391
# 1      Finance                Karvy     1.000000          0.001488
# 2  Agriculture                Karvy     1.000000          0.051687
# 3      Finance      Ashika Research     0.731099          0.014022
# 4   Technology  Chola Wealth Direct     0.486676          0.037110
# Best Authors DataFrame Shape: (6, 4)
#
# Calculating monthly performance for: 2015-02
# Month Start: 2015-02-01 00:00:00, Month End: 2015-02-28 00:00:00
# Filtered Data for Month: 89 rows
# Best Authors DataFrame Shape: (6, 4)
# Data After Merging with Best Authors: 11 rows
# Performance Column Calculated. Sample Data:
#         Sector               author  performance
# 0      Finance                Karvy     0.030556
# 1      Finance                Karvy     0.047865
# 2  Agriculture                Karvy    -0.015070
# 3  Agriculture  Chola Wealth Direct     0.015070
# 4  Agriculture                Karvy    -0.004682
# Performance Summary for 2015-02:
#         Sector               author      mean  count      month
# 0  Agriculture  Chola Wealth Direct  0.015070      1 2015-02-01
# 1  Agriculture                Karvy -0.009876      2 2015-02-01
# 2      Finance                Karvy  0.035348      3 2015-02-01
# 3   Technology  Chola Wealth Direct  0.040556      4 2015-02-01
# 4   Technology                Karvy -0.015945      1 2015-02-01
# Monthly Performance for 2015-02:
#          Sector               author      mean  count      month
# 0  Agriculture  Chola Wealth Direct  0.015070      1 2015-02-01
# 1  Agriculture                Karvy -0.009876      2 2015-02-01
# 2      Finance                Karvy  0.035348      3 2015-02-01
# 3   Technology  Chola Wealth Direct  0.040556      4 2015-02-01
# 4   Technology                Karvy -0.015945      1 2015-02-01
#
# Processing Month: 2015-03
# Training Period: Start 2014-02-28 00:00:00, End 2015-02-28 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2014-02-28 00:00:00, End Date: 2015-02-28 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (241, 7)
# Number of Sector-Author Groups: 45
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
#
# Performance DataFrame Shape: (8, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (8, 4)
# Top Authors DataFrame Sample:
#                Sector                    author  correlation  mean_performance
# 0      Consumer Goods  BOB Capital Markets Ltd.     1.000000          0.027897
# 1  Telecommunications                     Karvy     0.976584          0.008799
# 2             Finance           Ashika Research     0.731099          0.014022
# 3         Agriculture                     Karvy     0.685294          0.020905
# 4          Technology       Chola Wealth Direct     0.362312          0.034497
# Best Authors DataFrame Shape: (8, 4)
#
# Calculating monthly performance for: 2015-03
# Month Start: 2015-03-01 00:00:00, Month End: 2015-03-31 00:00:00
# Filtered Data for Month: 9 rows
# Best Authors DataFrame Shape: (8, 4)
# Data After Merging with Best Authors: 3 rows
# Performance Column Calculated. Sample Data:
#        Sector           author  performance
# 0     Finance            Karvy    -0.032693
# 1  Technology            Karvy    -0.012609
# 2     Finance  Ashika Research    -0.104545
# Performance Summary for 2015-03:
#        Sector           author      mean  count      month
# 0     Finance  Ashika Research -0.104545      1 2015-03-01
# 1     Finance            Karvy -0.032693      1 2015-03-01
# 2  Technology            Karvy -0.012609      1 2015-03-01
# Monthly Performance for 2015-03:
#         Sector           author      mean  count      month
# 0     Finance  Ashika Research -0.104545      1 2015-03-01
# 1     Finance            Karvy -0.032693      1 2015-03-01
# 2  Technology            Karvy -0.012609      1 2015-03-01
#
# Processing Month: 2015-04
# Training Period: Start 2014-03-31 00:00:00, End 2015-03-31 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2014-03-31 00:00:00, End Date: 2015-03-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (245, 7)
# Number of Sector-Author Groups: 42
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
#
# Performance DataFrame Shape: (7, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (7, 4)
# Top Authors DataFrame Sample:
#                Sector                    author  correlation  mean_performance
# 0      Consumer Goods  BOB Capital Markets Ltd.     1.000000          0.027897
# 1  Telecommunications                     Karvy     0.976584          0.008799
# 2         Agriculture                     Karvy     0.685294          0.020905
# 3          Technology       Chola Wealth Direct     0.362312          0.034497
# 4             Finance                     Karvy     0.223644          0.012721
# Best Authors DataFrame Shape: (7, 4)
#
# Calculating monthly performance for: 2015-04
# Month Start: 2015-04-01 00:00:00, Month End: 2015-04-30 00:00:00
# Filtered Data for Month: 60 rows
# Best Authors DataFrame Shape: (7, 4)
# Data After Merging with Best Authors: 8 rows
# Performance Column Calculated. Sample Data:
#            Sector                    author  performance
# 0         Finance                     Karvy     0.005242
# 1         Finance                     Karvy    -0.004695
# 2      Technology       Chola Wealth Direct    -0.005313
# 3  Consumer Goods  BOB Capital Markets Ltd.     0.016978
# 4      Technology                     Karvy     0.020280
# Performance Summary for 2015-04:
#            Sector                    author      mean  count      month
# 0  Consumer Goods  BOB Capital Markets Ltd.  0.016978      1 2015-04-01
# 1         Finance                     Karvy -0.029453      5 2015-04-01
# 2      Technology       Chola Wealth Direct -0.005313      1 2015-04-01
# 3      Technology                     Karvy  0.020280      1 2015-04-01
# Monthly Performance for 2015-04:
#             Sector                    author      mean  count      month
# 0  Consumer Goods  BOB Capital Markets Ltd.  0.016978      1 2015-04-01
# 1         Finance                     Karvy -0.029453      5 2015-04-01
# 2      Technology       Chola Wealth Direct -0.005313      1 2015-04-01
# 3      Technology                     Karvy  0.020280      1 2015-04-01
#
# Processing Month: 2015-05
# Training Period: Start 2014-04-30 00:00:00, End 2015-04-30 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2014-04-30 00:00:00, End Date: 2015-04-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (294, 7)
# Number of Sector-Author Groups: 49
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
#
# Performance DataFrame Shape: (9, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (9, 4)
# Top Authors DataFrame Sample:
#                Sector               author  correlation  mean_performance
# 0              Energy      Phillip Capital     1.000000          0.001307
# 1          Technology      Ashika Research     1.000000          0.006770
# 2  Telecommunications                Karvy     0.976584          0.008799
# 3         Agriculture                Karvy     0.685294          0.020905
# 4          Technology  Chola Wealth Direct     0.375775          0.032766
# Best Authors DataFrame Shape: (9, 4)
#
# Calculating monthly performance for: 2015-05
# Month Start: 2015-05-01 00:00:00, Month End: 2015-05-31 00:00:00
# Filtered Data for Month: 129 rows
# Best Authors DataFrame Shape: (9, 4)
# Data After Merging with Best Authors: 19 rows
# Performance Column Calculated. Sample Data:
#            Sector                    author  performance
# 0      Technology           HDFC Securities    -0.063383
# 1  Consumer Goods  BOB Capital Markets Ltd.    -0.047396
# 2      Technology           HDFC Securities    -0.018046
# 3      Technology       Chola Wealth Direct    -0.008174
# 4      Technology                     Karvy     0.032399
# Performance Summary for 2015-05:
#            Sector                    author      mean  count      month
# 0  Consumer Goods  BOB Capital Markets Ltd. -0.047396      1 2015-05-01
# 1          Energy           Phillip Capital  0.028251      1 2015-05-01
# 2      Healthcare       Chola Wealth Direct -0.007991      3 2015-05-01
# 3      Technology       Chola Wealth Direct -0.024977      3 2015-05-01
# 4      Technology           HDFC Securities  0.004118      7 2015-05-01
# Monthly Performance for 2015-05:
#             Sector                    author      mean  count      month
# 0  Consumer Goods  BOB Capital Markets Ltd. -0.047396      1 2015-05-01
# 1          Energy           Phillip Capital  0.028251      1 2015-05-01
# 2      Healthcare       Chola Wealth Direct -0.007991      3 2015-05-01
# 3      Technology       Chola Wealth Direct -0.024977      3 2015-05-01
# 4      Technology           HDFC Securities  0.004118      7 2015-05-01
#
# Processing Month: 2015-06
# Training Period: Start 2014-05-31 00:00:00, End 2015-05-31 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2014-05-31 00:00:00, End Date: 2015-05-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (404, 7)
# Number of Sector-Author Groups: 56
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
#
# Performance DataFrame Shape: (14, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (14, 4)
# Top Authors DataFrame Sample:
#            Sector                    author  correlation  mean_performance
# 0      Technology           Ashika Research     1.000000          0.006770
# 1          Energy           Phillip Capital     0.969958          0.010288
# 2      Technology           Phillip Capital     0.724892          0.010311
# 3     Agriculture                     Karvy     0.685294          0.020905
# 4  Consumer Goods  BOB Capital Markets Ltd.     0.667389          0.006344
# Best Authors DataFrame Shape: (14, 4)
#
# Calculating monthly performance for: 2015-06
# Month Start: 2015-06-01 00:00:00, Month End: 2015-06-30 00:00:00
# Filtered Data for Month: 44 rows
# Best Authors DataFrame Shape: (14, 4)
# Data After Merging with Best Authors: 13 rows
# Performance Column Calculated. Sample Data:
#            Sector                    author  performance
# 0          Energy           Phillip Capital     0.012020
# 1      Technology           Phillip Capital     0.003617
# 2         Finance           HDFC Securities     0.173853
# 3  Consumer Goods  BOB Capital Markets Ltd.    -0.082841
# 4      Healthcare           HDFC Securities    -0.031842
# Performance Summary for 2015-06:
#            Sector                    author      mean  count      month
# 0  Consumer Goods  BOB Capital Markets Ltd. -0.082841      1 2015-06-01
# 1          Energy           Phillip Capital  0.005827      2 2015-06-01
# 2         Finance           HDFC Securities  0.021515      5 2015-06-01
# 3      Healthcare       Chola Wealth Direct -0.014431      1 2015-06-01
# 4      Healthcare           HDFC Securities -0.035932      3 2015-06-01
# Monthly Performance for 2015-06:
#             Sector                    author      mean  count      month
# 0  Consumer Goods  BOB Capital Markets Ltd. -0.082841      1 2015-06-01
# 1          Energy           Phillip Capital  0.005827      2 2015-06-01
# 2         Finance           HDFC Securities  0.021515      5 2015-06-01
# 3      Healthcare       Chola Wealth Direct -0.014431      1 2015-06-01
# 4      Healthcare           HDFC Securities -0.035932      3 2015-06-01
#
# Processing Month: 2015-07
# Training Period: Start 2014-06-30 00:00:00, End 2015-06-30 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2014-06-30 00:00:00, End Date: 2015-06-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (443, 7)
# Number of Sector-Author Groups: 60
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
#
# Performance DataFrame Shape: (14, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (14, 4)
# Top Authors DataFrame Sample:
#         Sector               author  correlation  mean_performance
# 0  Agriculture  Chola Wealth Direct     1.000000          0.027737
# 1   Technology      Ashika Research     1.000000          0.006770
# 2  Agriculture                Karvy     0.685294          0.020905
# 3   Technology      Phillip Capital     0.674161          0.009702
# 4    Utilities      HDFC Securities     0.616633          0.035204
# Best Authors DataFrame Shape: (14, 4)
#
# Calculating monthly performance for: 2015-07
# ...
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
#
# Performance DataFrame Shape: (50, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (50, 4)
# Top Authors DataFrame Sample:
#         Sector                            author  correlation  \
# 0   Technology  Monarch Networth Capital Limited          1.0
# 1      Finance                        Way2Wealth          1.0
# 2   Technology                           Ventura          1.0
# 3    Utilities                     Dolat Capital          1.0
# 4  Agriculture               Chola Wealth Direct          1.0
#
#    mean_performance
# 0          0.098543
# 1          0.077292
# 2          0.027776
# 3          0.008460
# 4          0.001786
# Best Authors DataFrame Shape: (50, 4)
#
# Calculating monthly performance for: 2021-10
# Month Start: 2021-10-01 00:00:00, Month End: 2021-10-31 00:00:00
# Filtered Data for Month: 376 rows
# Best Authors DataFrame Shape: (50, 4)
# Data After Merging with Best Authors: 146 rows
# Performance Column Calculated. Sample Data:
#           Sector                    author  performance
# 0  Manufacturing  ICICI Securities Limited     0.068975
# 1        Finance             Motilal Oswal     0.024993
# 2        Finance       Prabhudas Lilladhar    -0.024993
# 3        Finance       Prabhudas Lilladhar     0.007683
# 4         Energy             Motilal Oswal    -0.000674
# Performance Summary for 2021-10:
#            Sector                    author      mean  count      month
# 0  Consumer Goods               Axis Direct -0.060164      2 2021-10-01
# 1  Consumer Goods                 Edelweiss  0.036776      2 2021-10-01
# 2  Consumer Goods  ICICI Securities Limited  0.003983      9 2021-10-01
# 3          Energy               Axis Direct  0.065889      2 2021-10-01
# 4          Energy                 Edelweiss -0.008217      2 2021-10-01
# Monthly Performance for 2021-10:
#             Sector                    author      mean  count      month
# 0  Consumer Goods               Axis Direct -0.060164      2 2021-10-01
# 1  Consumer Goods                 Edelweiss  0.036776      2 2021-10-01
# 2  Consumer Goods  ICICI Securities Limited  0.003983      9 2021-10-01
# 3          Energy               Axis Direct  0.065889      2 2021-10-01
# 4          Energy                 Edelweiss -0.008217      2 2021-10-01
#
# Processing Month: 2021-11
# Training Period: Start 2020-10-31 00:00:00, End 2021-10-31 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2020-10-31 00:00:00, End Date: 2021-10-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
# Filtered Data Shape: (3680, 7)
# Number of Sector-Author Groups: 190
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds met. Adding to results.
# Thresholds not met. Skipping.
# Thresholds not met. Skipping.
# Not enough data points for correlation calculation. Skipping.
#
# Performance DataFrame Shape: (52, 4)
# Sorting and selecting top authors by sector.
# Top Authors DataFrame Shape: (52, 4)
# Top Authors DataFrame Sample:
#            Sector           author  correlation  mean_performance
# 0          Energy          Ventura          1.0          0.298557
# 1         Finance       Way2Wealth          1.0          0.077292
# 2  Consumer Goods  Arihant Capital          1.0          0.014768
# 3      Healthcare  Arihant Capital          1.0          0.014437
# 4       Utilities     IDBI Capital          1.0          0.012147
# Best Authors DataFrame Shape: (52, 4)
#
# Calculating monthly performance for: 2021-11
# Month Start: 2021-11-01 00:00:00, Month End: 2021-11-30 00:00:00
# Filtered Data for Month: 371 rows
# Best Authors DataFrame Shape: (52, 4)
# Data After Merging with Best Authors: 163 rows
# Performance Column Calculated. Sample Data:
#                Sector                    author  performance
# 0       Manufacturing               Axis Direct    -0.006238
# 1       Manufacturing             Motilal Oswal    -0.000642
# 2  Telecommunications        Geojit BNP Paribas     0.063807
# 3  Telecommunications  ICICI Securities Limited    -0.047930
# 4          Healthcare  ICICI Securities Limited    -0.014902
# Performance Summary for 2021-11:
#            Sector                    author      mean  count      month
# 0  Consumer Goods       Chola Wealth Direct  0.020689      1 2021-11-01
# 1  Consumer Goods  ICICI Securities Limited -0.004161      5 2021-11-01
# 2          Energy               Axis Direct  0.009076      1 2021-11-01
# 3          Energy  ICICI Securities Limited -0.007969      7 2021-11-01
# 4          Energy             Motilal Oswal -0.012670      2 2021-11-01
# Monthly Performance for 2021-11:
#             Sector                    author      mean  count      month
# 0  Consumer Goods       Chola Wealth Direct  0.020689      1 2021-11-01
# 1  Consumer Goods  ICICI Securities Limited -0.004161      5 2021-11-01
# 2          Energy               Axis Direct  0.009076      1 2021-11-01
# 3          Energy  ICICI Securities Limited -0.007969      7 2021-11-01
# 4          Energy             Motilal Oswal -0.012670      2 2021-11-01
#
# Processing Month: 2021-12
# Training Period: Start 2020-11-30 00:00:00, End 2021-11-30 00:00:00
#
# ### get_best_authors_by_sector ###
# Start Date: 2020-11-30 00:00:00, End Date: 2021-11-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
