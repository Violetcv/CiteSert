# %%
from datetime import timedelta
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
# Load the filtered DataFrame from the CSV file
# Define the file path
file_path = r'C:\Users\disch\Desktop\CiteSert\Project_1\Version2_40krows_n5\input_data\filtered_data_2.csv'

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

df = df.dropna(subset=['expected_return', 'actual_return'])


# Display the first few rows of the DataFrame to verify it loaded correctly
print(df.head())
# Out:
#           date                    Company Name      Symbol  \
# 0   2015-11-16  speciality restaurants limited  SPECIALITY
# 1   2015-08-13  speciality restaurants limited  SPECIALITY
# 8   2024-05-17           eicher motors limited   EICHERMOT
# 9   2024-05-13           eicher motors limited   EICHERMOT
# 11  2024-05-13           eicher motors limited   EICHERMOT
#
#                       author         Sector  expected_return  actual_return
# 0                      Karvy     Technology         9.432421      -0.018033
# 1        Reliance Securities     Technology         7.189542       0.018065
# 8   BOB Capital Markets Ltd.  Manufacturing        -1.297429       0.030817
# 9               ICICI Direct  Manufacturing        18.090371       0.001189
# 11               Axis Direct  Manufacturing        10.253465       0.001189

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35107 entries, 0 to 41819
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             35107 non-null  object
#  1   Company Name     35107 non-null  object
#  2   Symbol           35107 non-null  object
#  3   author           35107 non-null  object
#  4   Sector           35107 non-null  object
#  5   expected_return  35107 non-null  float64
#  6   actual_return    35107 non-null  float64
# dtypes: float64(2), object(5)
# memory usage: 2.1+ MB

# %%
def calculate_correlation(expected_returns, actual_returns):
    """
    Calculate the correlation between expected and actual returns,
    ensuring no division by zero occurs.
    
    Args:
        expected_returns (pd.Series): Expected returns.
        actual_returns (pd.Series): Actual returns.

    Returns:
        float: Correlation coefficient, or NaN if not calculable.
    """
    # Check standard deviation to avoid division by zero
    if np.std(expected_returns) == 0 or np.std(actual_returns) == 0:
        return np.nan
    
    # Calculate correlation
    return np.corrcoef(expected_returns, actual_returns)[0, 1]

# %%
def get_best_authors_by_sector(df, start_date, end_date, corr_threshold, perf_threshold, max_authors=10):
    """
    Identify the best-performing authors per sector within a specific date range based on 
    correlation and mean performance thresholds.
    """
    print("\n### get_best_authors_by_sector ###")
    print(f"Start Date: {start_date}, End Date: {end_date}")
    print(f"Max Authors per Sector: {max_authors}, Correlation Threshold: {corr_threshold}, Performance Threshold: {perf_threshold}")
    
    # Convert date column to datetime if necessary
    df['date'] = pd.to_datetime(df['date'])
    
    # Filter data for the specified date range
    period_df = df[(df['date'] >= start_date) & (df['date'] <= end_date)].copy()
    # print(f"Filtered Data Shape: {period_df.shape}")

    if period_df.empty:
        print("No data available for the specified date range.")
        return pd.DataFrame(columns=['Sector', 'author', 'correlation', 'mean_performance'])

    # Calculate performance metrics for each sector-author pair
    author_sector_performance = []
    grouped = period_df.groupby(['Sector', 'author'])
    # print(f"Number of Sector-Author Groups: {len(grouped)}")

    for (sector, author), group in grouped:
        # print(f"\nProcessing Sector: {sector}, Author: {author}")
        # print(f"Group Size: {len(group)}")

        if len(group) < 2:  # Ensure enough data points for correlation calculation
            # print("Not enough data points for correlation calculation. Skipping.")
            continue

        # Compute correlation between expected and actual returns
        correlation = calculate_correlation(group['expected_return'], group['actual_return'])
        # print(f"Correlation: {correlation}")

        # Compute mean performance
        group['performance'] = np.sign(group['expected_return']) * group['actual_return']
        mean_performance = group['performance'].mean()
        # print(f"Mean Performance: {mean_performance}")

        # Store results if thresholds are met
        if not np.isnan(correlation) and correlation > corr_threshold and mean_performance > perf_threshold:
            # print("Thresholds met. Adding to results.")
            author_sector_performance.append({
                'Sector': sector,
                'author': author,
                'correlation': correlation,
                'mean_performance': mean_performance
            })
        else:
            continue
            # print("Thresholds not met. Skipping.")

    # Create a DataFrame from the results
    performance_df = pd.DataFrame(author_sector_performance)
    # print(f"\nPerformance DataFrame Shape: {performance_df.shape}")

    if performance_df.empty:
        print("No authors met the thresholds.")
        return pd.DataFrame(columns=['Sector', 'author', 'correlation', 'mean_performance'])

    # Sort authors by correlation and mean performance, and retain top authors per sector
    # print("Sorting and selecting top authors by sector.")
    top_authors_df = (performance_df
                      .sort_values(['correlation', 'mean_performance'], ascending=[False, False])
                      .groupby('Sector')
                      .head(max_authors)
                      .reset_index(drop=True))
    # print(f"Top Authors DataFrame Shape: {top_authors_df.shape}")
    # print(f"Top Authors DataFrame Sample:\n{top_authors_df}")

    return top_authors_df

# %%
def calculate_monthly_performance(df, best_authors_df, target_month):
    """
    Calculate performance for each author-sector pair for a specific month
    using sign(expected_return) * actual_return
    """
    print(f"\nCalculating monthly performance for: {target_month.strftime('%Y-%m')}")

    # Define month range
    month_start = target_month.replace(day=1)
    month_end = (month_start + pd.offsets.MonthEnd(1))
    # print(f"Month Start: {month_start}, Month End: {month_end}")

    # Filter data for the target month
    mask = (df['date'] >= month_start) & (df['date'] <= month_end)
    month_df = df[mask].copy()
    # print(f"Filtered Data for Month: {month_df.shape[0]} rows")

    # Merge with best authors
    # print(f"Best Authors DataFrame Shape: {best_authors_df.shape}")
    month_df = month_df.merge(
        best_authors_df[['Sector', 'author']],
        on=['Sector', 'author'],
        how='inner'
    )
    # print(f"Data After Merging with Best Authors: {month_df.shape[0]} rows")

    # Calculate performance
    month_df['performance'] = np.sign(month_df['expected_return']) * month_df['actual_return']
    # print(f"Performance Column Calculated. Sample Data:\n{month_df[['Sector', 'author', 'performance']].head()}")

    # Group and summarize performance
    performance_summary = (month_df.groupby(['Sector', 'author'])
                           ['performance']
                           .agg(mean_performance='mean', count='count')
                           .reset_index())
    performance_summary['month'] = month_start
    # print(f"Performance Summary for {target_month.strftime('%Y-%m')}:\n{performance_summary.head()}")

    return performance_summary

def run_rolling_analysis(df, start_date, end_date, a, b, lookback_period=12):
    """
    Run the rolling analysis month by month
    """
    # print("\nStarting Rolling Analysis")
    # print(f"Start Date: {start_date}, End Date: {end_date}, Lookback Period: {lookback_period} months")
    # print(f"Thresholds: Correlation (a={a}), Performance (b={b})")

    # Convert dates if they're strings
    start_date = pd.to_datetime(start_date)
    end_date = pd.to_datetime(end_date)

    all_monthly_performance = []
    current_date = start_date

    while current_date <= end_date:
        # print(f"\nProcessing Month: {current_date.strftime('%Y-%m')}")
        
        # Define training period
        training_end = current_date - timedelta(days=1)
        training_start = training_end - pd.DateOffset(months=lookback_period)
        # print(f"Training Period: Start {training_start}, End {training_end}")

        # Get best authors
        best_authors = get_best_authors_by_sector(df, training_start, training_end, a, b)
        # print(f"Best Authors DataFrame Shape: {best_authors.shape}")

        # Calculate performance for the current month
        if not best_authors.empty:
            monthly_perf = calculate_monthly_performance(df, best_authors, current_date)
            all_monthly_performance.append(monthly_perf)

            print(f"Monthly Performance for {current_date.strftime('%Y-%m')}:\n", monthly_perf.head())
        else:
            print(f"No Best Authors Found for {current_date.strftime('%Y-%m')}")

        # Move to next month
        current_date = current_date + pd.DateOffset(months=1)

    # Combine all results
    if all_monthly_performance:
        combined_results = pd.concat(all_monthly_performance, ignore_index=True)
        # print(f"\nCombined Performance DataFrame Shape: {combined_results.shape}")
        return combined_results
    else:
        print("No performance data collected.")
        return pd.DataFrame()

# %%
def main(df):
    """
    Main function to analyze performance based on correlation and performance thresholds
    using a grid search approach.
    """
    print("\n### MAIN FUNCTION STARTED ###")

    # Convert date column to datetime if it's not already
    print("\nConverting 'date' column to datetime format.")
    df['date'] = pd.to_datetime(df['date'], errors='coerce')
    
    # Define the grid for correlation and performance thresholds
    print("\nDefining thresholds grid for correlation and performance.")
    correlation_thresholds = np.arange(0, 1.0, 0.05)
    performance_thresholds = np.arange(0, 0.3, 0.05)
    print(f"Correlation Thresholds: {correlation_thresholds}")
    print(f"Performance Thresholds: {performance_thresholds}")
    
    # Initialize a dictionary to store results for each iteration
    all_results = {}
    iteration_results = []
    iteration = 0

    print("\n### Starting grid search ###")
    
    # Iterate over the grid of thresholds
    for a in tqdm(correlation_thresholds, desc="Correlation Thresholds"):
        for b in tqdm(performance_thresholds, desc="Performance Thresholds", leave=False):
            print(f"\nGrid Combination - Correlation Threshold: {a}, Performance Threshold: {b}")
            
            # Run the rolling analysis
            try:
                print("Running rolling analysis for the current thresholds.")
                results_df = run_rolling_analysis(
                    df,
                    start_date='2014-06-01',
                    end_date='2022-12-31',
                    lookback_period=12,
                    a=a,
                    b=b
                )
                print(f"Rolling Analysis Completed. Results Shape: {results_df.shape}")
            except Exception as e:
                print(f"Error during rolling analysis for a={a}, b={b}: {e}")
                results_df = pd.DataFrame()  # Empty DataFrame in case of errors
            
            # Calculate mean performance for the iteration
            if not results_df.empty and 'mean_performance' in results_df.columns:
                mean_of_mean_performance = results_df['mean_performance'].mean()
                print(f"Mean of Mean Performance for Current Thresholds: {mean_of_mean_performance:.4f}")
            else:
                print("Column 'mean_performance' not found or results_df is empty. Assigning NaN.")
                mean_of_mean_performance = np.nan
            
            # Save the results DataFrame for the iteration
            iteration_key = f"iter_{iteration}_a_{a}_b_{b}"
            all_results[iteration_key] = results_df
            print(f"Iteration {iteration_key}: Results Saved.")
            
            # Append the iteration result
            iteration_results.append({
                'correlation_threshold': a,
                'performance_threshold': b,
                'mean_of_mean_performance': mean_of_mean_performance
            })
            
            # Increment iteration counter
            iteration += 1

    # Convert iteration results to a DataFrame for analysis
    print("\nConverting iteration results to a DataFrame for final analysis.")
    grid_performance_df = pd.DataFrame(iteration_results)
    print(f"Grid Performance DataFrame Shape: {grid_performance_df.shape}")
    print(f"Grid Performance DataFrame Head:\n{grid_performance_df.head()}")

    # Handle case where no valid data is available
    if grid_performance_df.empty:
        print("\nNo valid data available. Ensure the input data and thresholds are correct.")
    else:
        print("\nGrid Performance DataFrame successfully created.")

    print("\n### MAIN FUNCTION COMPLETED ###")
    return all_results, grid_performance_df

# %%
all_results, grid_performance_df = main(df)
# Out:
# ### MAIN FUNCTION STARTED ###
#
# Converting 'date' column to datetime format.
#
# Defining thresholds grid for correlation and performance.
# Correlation Thresholds: [0.   0.05 0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65
#  0.7  0.75 0.8  0.85 0.9  0.95]
# Performance Thresholds: [0.   0.05 0.1  0.15 0.2  0.25]
#
# ### Starting grid search ###
# Correlation Thresholds:   0%|                                                                   | 0/20 [00:00<?, ?it/s]
# Performance Thresholds:   0%|                                                                    | 0/6 [00:00<?, ?it/s]
# Grid Combination - Correlation Threshold: 0.0, Performance Threshold: 0.0
# Running rolling analysis for the current thresholds.
#
# ### get_best_authors_by_sector ###
# Start Date: 2013-05-31 00:00:00, End Date: 2014-05-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2014-06
# Monthly Performance for 2014-06:
#             Sector               author  mean_performance  count      month
# 0  Consumer Goods  Chola Wealth Direct         -0.003993      1 2014-06-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2013-06-30 00:00:00, End Date: 2014-06-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2014-07
# Monthly Performance for 2014-07:
#            Sector               author  mean_performance  count      month
# 0  Manufacturing  Chola Wealth Direct         -0.034603      3 2014-07-01
# 1     Technology  Chola Wealth Direct          0.036590      1 2014-07-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2013-07-31 00:00:00, End Date: 2014-07-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2014-08
# Monthly Performance for 2014-08:
#             Sector               author  mean_performance  count      month
# 0  Consumer Goods  Chola Wealth Direct          0.027243      2 2014-08-01
# 1         Finance  Chola Wealth Direct         -0.002865      4 2014-08-01
# 2      Healthcare  Chola Wealth Direct          0.054960      2 2014-08-01
# 3      Healthcare  Reliance Securities         -0.068325      1 2014-08-01
# 4   Manufacturing  Chola Wealth Direct         -0.021035      3 2014-08-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2013-08-31 00:00:00, End Date: 2014-08-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2014-09
# Monthly Performance for 2014-09:
#  Empty DataFrame
# Columns: [Sector, author, mean_performance, count, month]
# Index: []
#
# ### get_best_authors_by_sector ###
# Start Date: 2013-09-30 00:00:00, End Date: 2014-09-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2014-10
# Monthly Performance for 2014-10:
#            Sector               author  mean_performance  count      month
# 0        Finance  Chola Wealth Direct          0.035991      7 2014-10-01
# 1  Manufacturing      Ashika Research          0.086828      1 2014-10-01
# 2     Technology  Chola Wealth Direct          0.030832      3 2014-10-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2013-10-31 00:00:00, End Date: 2014-10-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2014-11
# Monthly Performance for 2014-11:
#         Sector               author  mean_performance  count      month
# 0     Finance  Chola Wealth Direct          0.030082      3 2014-11-01
# 1  Healthcare  Chola Wealth Direct         -0.023794      3 2014-11-01
# 2  Technology  Chola Wealth Direct          0.041265      5 2014-11-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2013-11-30 00:00:00, End Date: 2014-11-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2014-12
# Monthly Performance for 2014-12:
#      Sector           author  mean_performance  count      month
# 0  Finance  Ashika Research          0.006232      2 2014-12-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2013-12-31 00:00:00, End Date: 2014-12-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2015-01
# Monthly Performance for 2015-01:
#         Sector               author  mean_performance  count      month
# 0     Finance  Chola Wealth Direct          0.001251     11 2015-01-01
# 1  Technology  Chola Wealth Direct         -0.004273      1 2015-01-01
# 2  Technology                Karvy         -0.007308      2 2015-01-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2014

#             Sector                    author  mean_performance  count  \
# 0  Consumer Goods             Angel Broking         -0.030846      1
# 1  Consumer Goods               Axis Direct          0.000173      1
# 2          Energy               Axis Direct          0.012838      2
# 3          Energy  ICICI Securities Limited          0.001287      6
# 4         Finance               Axis Direct         -0.005186     15
#
#        month
# 0 2017-07-01
# 1 2017-07-01
# 2 2017-07-01
# 3 2017-07-01
# 4 2017-07-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2016-07-31 00:00:00, End Date: 2017-07-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2017-08
# Monthly Performance for 2017-08:
#             Sector                    author  mean_performance  count  \
# 0  Consumer Goods               Axis Direct          0.005560      3
# 1  Consumer Goods                 Edelweiss         -0.001965      2
# 2          Energy               Axis Direct         -0.003191      9
# 3          Energy       Chola Wealth Direct         -0.003386      1
# 4          Energy  ICICI Securities Limited         -0.004804     11
#
#        month
# 0 2017-08-01
# 1 2017-08-01
# 2 2017-08-01
# 3 2017-08-01
# 4 2017-08-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2016-08-31 00:00:00, End Date: 2017-08-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2017-09
# Monthly Performance for 2017-09:
#            Sector           author  mean_performance  count      month
# 0        Finance      Axis Direct          0.009371      1 2017-09-01
# 1        Finance     Choice India          0.023462      1 2017-09-01
# 2        Finance    Motilal Oswal          0.036029      1 2017-09-01
# 3     Healthcare    CD Equisearch         -0.018972      2 2017-09-01
# 4  Manufacturing  HDFC Securities         -0.022867      5 2017-09-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2016-09-30 00:00:00, End Date: 2017-09-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2017-10
# Monthly Performance for 2017-10:
#             Sector                    author  mean_performance  count  \
# 0  Consumer Goods               Axis Direct         -0.010224      3
# 1          Energy  ICICI Securities Limited          0.012894      2
# 2          Energy              JM Financial          0.058644      2
# 3          Energy       Reliance Securities          0.019527      3
# 4         Finance               Axis Direct          0.003221     14
#
#        month
# 0 2017-10-01
# 1 2017-10-01
# 2 2017-10-01
# 3 2017-10-01
# 4 2017-10-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2016-10-31 00:00:00, End Date: 2017-10-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2017-11
# Monthly Performance for 2017-11:
#             Sector                    author  mean_performance  count  \
# 0  Consumer Goods               Axis Direct         -0.015851      6
# 1  Consumer Goods                 Edelweiss         -0.062738      2
# 2          Energy  ICICI Securities Limited         -0.015034     14
# 3          Energy             Motilal Oswal         -0.018480      6
# 4          Energy       Reliance Securities         -0.007159      6
#
#        month
# 0 2017-11-01
# 1 2017-11-01
# 2 2017-11-01
# 3 2017-11-01
# 4 2017-11-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2016-11-30 00:00:00, End Date: 2017-11-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2017-12
# Monthly Performance for 2017-12:
#             Sector                    author  mean_performance  count  \
# 0  Consumer Goods               Axis Direct          0.002376      1
# 1  Consumer Goods                     Emkay          0.003912      1
# 2  Consumer Goods  ICICI Securities Limited          0.038247      3
# 3         Finance               Axis Direct          0.004054      6
# 4         Finance           Centrum Broking          0.023796      1
#
#        month
# 0 2017-12-01
# 1 2017-12-01
# 2 2017-12-01
# 3 2017-12-01
# 4 2017-12-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2016-12-31 00:00:00, End Date: 2017-12-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2018-01
# Monthly Performance for 2018-01:
#             Sector                    author  mean_performance  count  \
# 0  Consumer Goods               Axis Direct          0.060445      4
# 1  Consumer Goods           HDFC Securities         -0.004632      3
# 2  Consumer Goods  ICICI Securities Limited         -0.038407      4
# 3          Energy  ICICI Securities Limited         -0.050119      1
# 4          Energy              JM Financial         -0.007199      1
#
#        month
# 0 2018-01-01
# 1 2018-01-01
# 2 2018-01-01
# 3 2018-01-01
# 4 2018-01-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2017-01-31 00:00:00, End Date: 2018-01-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2018-02
# Monthly Performance for 2018-02:
#             Sector                    author  mean_performance  count  \
# 0     Agriculture               Axis Direct         -0.003703      1
# 1  Consumer Goods             Angel Broking          0.132568      1
# 2  Consumer Goods               Axis Direct          0.034443      4
# 3  Consumer Goods        Geojit BNP Paribas         -0.010461      1
# 4  Consumer Goods  ICICI Securities Limited         -0.000355      8
#
#        month
# 0 2018-02-01
# 1 2018-02-01
# 2 2018-02-01
# 3 2018-02-01
# 4 2018-02-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2017-02-28 00:00:00, End Date: 2018-02-28 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2018-03
# Monthly Performance for 2018-03:
#             Sector                    author  mean_performance  count  \
# 0  Consumer Goods             Angel Broking         -0.053407      1
# 1  Consumer Goods                     Emkay          0.047231      1
# 2          Energy  ICICI Securities Limited          0.037049      2
# 3         Finance                   Bonanza          0.045965      1
# 4         Finance           Centrum Broking         -0.004340      2
#
#        month
# 0 2018-03-01
# 1 2018-03-01
# 2 2018-03-01
# 3 2018-03-01
# 4 2018-03-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2017-03-31 00:00:00, End Date: 2018-03-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2018-04
# Monthly Performance for 2018-04:
#             Sector                    author  mean_performance  count  \
# 0  Consumer Goods             Angel Broking          0.163780      1
# 1  Consumer Goods           HDFC Securities          0.013723      1
# 2  Consumer Goods  ICICI Securities Limited         -0.004808      1
# 3          Energy  ICICI Securities Limited         -0.035427      2
# 4          Energy              JM Financial          0.016063      1
#
#        month
# 0 2018-04-01
# 1 2018-04-01
# 2 2018-04-01
# 3 2018-04-01
# 4 2018-04-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2017-04-30 00:00:00, End Date: 2018-04-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2018-05
# Monthly Performance for 2018-05:
#             Sector                    author  mean_performance  count  \
# 0     Agriculture  ICICI Securities Limited          0.026023      1
# 1  Consumer Goods             Angel Broking         -0.053651      3
# 2  Consumer Goods        Geojit BNP Paribas          0.016213      1
# 3  Consumer Goods           HDFC Securities         -0.000919      6
# 4  Consumer Goods  ICICI Securities Limited          0.043019      8
#
#        month
# 0 2018-05-01
# 1 2018-05-01
# 2 2018-05-01
# 3 2018-05-01
# 4 2018-05-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2017-05-31 00:00:00, End Date: 2018-05-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2018-06
# Monthly Performance for 2018-06:
#             Sector               author  mean_performance  count      month
# 0  Consumer Goods      HDFC Securities          0.006063      1 2018-06-01
# 1  Consumer Goods        Motilal Oswal          0.029333      1 2018-06-01
# 2          Energy         JM Financial         -0.039599      1 2018-06-01
# 3          Energy  Reliance Securities         -0.025409      1 2018-06-01
# 4         Finance      Centrum Broking          0.028497      1 2018-06-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2017-06-30 00:00:00, End Date: 2018-06-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2018-07
# Monthly Performance for 2018-07:
#             Sector              author  mean_performance  count      month
# 0     Agriculture       Motilal Oswal          0.030231      1 2018-07-01
# 1  Consumer Goods       Angel Broking          0.011694      1 2018-07-01
# 2  Consumer Goods  Geojit BNP Paribas          0.020548      1 2018-07-01
# 3  Consumer Goods     HDFC Securities          0.045482      5 2018-07-01
# 4  Consumer Goods       Motilal Oswal         -0.043775      1 2018-07-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2017-07-31 00:00:00, End Date: 2018-07-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2018-08
# Monthly Performance for 2018-08:
#             Sector              author  mean_performance  count      month
# 0     Agriculture       Motilal Oswal         -0.049761      1 2018-08-01
# 1  Consumer Goods       Angel Broking         -0.021341      2 2018-08-01
# 2  Consumer Goods  Geojit BNP Paribas         -0.040467      2 2018-08-01
# 3  Consumer Goods     HDFC Securities         -0.020501      2 2018-08-01
# 4  Consumer Goods       Motilal Oswal         -0.045617      2 2018-08-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2017-08-31 00:00:00, End Date: 2018-08-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2018-09
# Monthly Performance for 2018-09:
#             Sector              author  mean_performance  count      month
# 0  Consumer Goods  Geojit BNP Paribas         -0.077629      1 2018-09-01
# 1  Consumer Goods       Motilal Oswal          0.005456      1 2018-09-01
# 2         Finance           Edelweiss         -0.134860      1 2018-09-01
# 3         Finance     HDFC Securities         -0.055321      2 2018-09-01
# 4      Healthcare       Angel Broking         -0.017486      1 2018-09-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2017-09-30 00:00:00, End Date: 2018-09-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2018-10
# Monthly Performance for 2018-10:
#             Sector           author  mean_performance  count      month
# 0  Consumer Goods    Angel Broking          0.010962      1 2018-10-01
# 1  Consumer Goods      Axis Direct          0.010647      1 2018-10-01
# 2  Consumer Goods  HDFC Securities          0.001430      6 2018-10-01
# 3  Consumer Goods     JM Financial          0.022714      1 2018-10-01
# 4  Consumer Goods    Motilal Oswal          0.007353      6 2018-10-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2017-10-31 00:00:00, End Date: 2018-10-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2018-11
# Monthly Performance for 2018-11:
#             Sector                    author  mean_performance  count  \
# 0     Agriculture  ICICI Securities Limited          0.065048      1
# 1     Agriculture             Motilal Oswal          0.082233      2
# 2  Consumer Goods             Angel Broking         -0.025764      2
# 3  Consumer Goods           HDFC Securities          0.007906      3
# 4  Consumer Goods             Motilal Oswal          0.021262      6
#
#        month
# 0 2018-11-01
# 1 2018-11-01
# 2 2018-11-01
# 3 2018-11-01
# 4 2018-11-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2017-11-30 00:00:00, End Date: 2018-11-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2018-12
# Monthly Performance for 2018-12:
#             Sector           author  mean_performance  count      month
# 0  Consumer Goods      Axis Direct          0.013105      1 2018-12-01
# 1  Consumer Goods  HDFC Securities         -0.004493      1 2018-12-01
# 2  Consumer Goods    Motilal Oswal         -0.021362      1 2018-12-01
# 3  Consumer Goods         Religare          0.100694      1 2018-12-01
# 4          Energy    Motilal Oswal          0.010151      1 2018-12-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2017-12-31 00:00:00, End Date: 2018-12-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2019-01
# Monthly Performance for 2019-01:
#             Sector           author  mean_performance  count      month
# 0  Consumer Goods  HDFC Securities          0.001356      6 2019-01-01
# 1  Consumer Goods    Motilal Oswal         -0.031224      3 2019-01-01
# 2          Energy    Motilal Oswal         -0.001159      4 2019-01-01
# 3         Finance  HDFC Securities          0.001373     32 2019-01-01
# 4      Healthcare        BP Wealth         -0.039517      1 2019-01-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2018-01-31 00:00:00, End Date: 2019-01-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2019-02
# Monthly Performance for 2019-02:
#             Sector                    author  mean_performance  count  \
# 0     Agriculture  ICICI Securities Limited         -0.013122      1
# 1     Agriculture             Motilal Oswal         -0.135540      1
# 2  Consumer Goods               Axis Direct          0.038944      1
# 3  Consumer Goods           HDFC Securities          0.037196      4
# 4  Consumer Goods             Motilal Oswal         -0.028092      6
#
#        month
# 0 2019-02-01
# 1 2019-02-01
# 2 2019-02-01
# 3 2019-02-01
# 4 2019-02-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2018-02-28 00:00:00, End Date: 2019-02-28 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2019-03
# Monthly Performance for 2019-03:
#             Sector               author  mean_performance  count      month
# 0  Consumer Goods      HDFC Securities          0.059752      1 2019-03-01
# 1  Consumer Goods        Motilal Oswal         -0.008129      1 2019-03-01
# 2         Finance   Geojit BNP Paribas          0.018668      3 2019-03-01
# 3         Finance      HDFC Securities          0.061522      6 2019-03-01
# 4         Finance  Prabhudas Lilladhar          0.022119      2 2019-03-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2018-03-31 00:00:00, End Date: 2019-03-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2019-04
# Monthly Performance for 2019-04:
#             Sector            author  mean_performance  count      month
# 0  Consumer Goods  Kotak Securities         -0.041886      1 2019-04-01
# 1          Energy       Axis Direct         -0.006434      3 2019-04-01
# 2          Energy     Motilal Oswal         -0.013227      2 2019-04-01
# 3         Finance   Arihant Capital         -0.025193      5 2019-04-01
# 4         Finance         Edelweiss         -0.023817      1 2019-04-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2018-04-30 00:00:00, End Date: 2019-04-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2019-05
# Monthly Performance for 2019-05:
#             Sector                    author  mean_performance  count  \
# 0     Agriculture  ICICI Securities Limited         -0.079631      1
# 1     Agriculture             Motilal Oswal          0.000539      1
# 2  Consumer Goods               Axis Direct          0.024582      2
# 3  Consumer Goods  BOB Capital Markets Ltd.          0.071935      1
# 4  Consumer Goods           HDFC Securities          0.000580      8
#
#        month
# 0 2019-05-01
# 1 2019-05-01
# 2 2019-05-01
# 3 2019-05-01
# 4 2019-05-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2018-05-31 00:00:00, End Date: 2019-05-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2019-06
# Monthly Performance for 2019-06:
#             Sector                    author  mean_performance  count  \
# 0     Agriculture             Motilal Oswal         -0.024153      1
# 1  Consumer Goods  ICICI Securities Limited         -0.008923      2
# 2  Consumer Goods                     Karvy          0.006681      1
# 3          Energy  BOB Capital Markets Ltd.          0.007508      3
# 4          Energy       Chola Wealth Direct          0.002338      1
#
#        month
# 0 2019-06-01
# 1 2019-06-01
# 2 2019-06-01
# 3 2019-06-01
# 4 2019-06-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2018-06-30 00:00:00, End Date: 2019-06-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2019-07
# Monthly Performance for 2019-07:
#             Sector                    author  mean_performance  count  \
# 0  Consumer Goods               Axis Direct          0.000116      1
# 1  Consumer Goods  BOB Capital Markets Ltd.         -0.078433      1
# 2  Consumer Goods           HDFC Securities         -0.007474      3
# 3  Consumer Goods  ICICI Securities Limited          0.002604      4
# 4  Consumer Goods                     Karvy          0.006166      1
#
#        month
# 0 2019-07-01
# 1 2019-07-01
# 2 2019-07-01
# 3 2019-07-01
# 4 2019-07-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2018-07-31 00:00:00, End Date: 2019-07-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2019-08
# Monthly Performance for 2019-08:
#             Sector                    author  mean_performance  count  \
# 0     Agriculture       Chola Wealth Direct          0.000623      1
# 1  Consumer Goods               Axis Direct          0.023907      1
# 2  Consumer Goods  BOB Capital Markets Ltd.          0.033507      2
# 3  Consumer Goods           HDFC Securities         -0.028672      3
# 4  Consumer Goods  ICICI Securities Limited          0.037159      8
#
#        month
# 0 2019-08-01
# 1 2019-08-01
# 2 2019-08-01
# 3 2019-08-01
# 4 2019-08-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2018-08-31 00:00:00, End Date: 2019-08-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2019-09
# Monthly Performance for 2019-09:
#             Sector                    author  mean_performance  count  \
# 0  Consumer Goods               Axis Direct          0.134371      1
# 1  Consumer Goods  BOB Capital Markets Ltd.         -0.040229      2
# 2          Energy           HDFC Securities          0.015460      2
# 3          Energy  ICICI Securities Limited         -0.094928      2
# 4          Energy       Prabhudas Lilladhar          0.022206      3
#
#        month
# 0 2019-09-01
# 1 2019-09-01
# 2 2019-09-01
# 3 2019-09-01
# 4 2019-09-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2018-09-30 00:00:00, End Date: 2019-09-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2019-10
# Monthly Performance for 2019-10:
#             Sector           author  mean_performance  count      month
# 0  Consumer Goods      Axis Direct          0.039474      2 2019-10-01
# 1  Consumer Goods  HDFC Securities          0.001876      3 2019-10-01
# 2  Consumer Goods            Karvy          0.032473      1 2019-10-01
# 3          Energy        Edelweiss         -0.015284      1 2019-10-01
# 4          Energy  HDFC Securities          0.003619      4 2019-10-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2018-10-31 00:00:00, End Date: 2019-10-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2019-11
# Monthly Performance for 2019-11:
#             Sector                    author  mean_performance  count  \
# 0  Consumer Goods               Axis Direct         -0.031934      1
# 1  Consumer Goods  BOB Capital Markets Ltd.         -0.101886      1
# 2  Consumer Goods           HDFC Securities         -0.061236      3
# 3  Consumer Goods                     Karvy          0.012580      1
# 4          Energy  BOB Capital Markets Ltd.          0.005251      1
#
#        month
# 0 2019-11-01
# 1 2019-11-01
# 2 2019-11-01
# 3 2019-11-01
# 4 2019-11-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2018-11-30 00:00:00, End Date: 2019-11-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.0
#
# Calculating monthly performance for: 2019-12
# Monthly Performance for 2019-12:
#             Sector                    author  mean_performance  count  \
# 0  Consumer Goods              IDBI Capital          0.011879      1
# ...
# No authors met the thresholds.
# No Best Authors Found for 2017-07
#
# ### get_best_authors_by_sector ###
# Start Date: 2016-07-31 00:00:00, End Date: 2017-07-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2017-08
# Monthly Performance for 2017-08:
#  Empty DataFrame
# Columns: [Sector, author, mean_performance, count, month]
# Index: []
#
# ### get_best_authors_by_sector ###
# Start Date: 2016-08-31 00:00:00, End Date: 2017-08-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2017-09
# Monthly Performance for 2017-09:
#      Sector         author  mean_performance  count      month
# 0  Finance  Motilal Oswal          0.036029      1 2017-09-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2016-09-30 00:00:00, End Date: 2017-09-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
# No authors met the thresholds.
# No Best Authors Found for 2017-10
#
# ### get_best_authors_by_sector ###
# Start Date: 2016-10-31 00:00:00, End Date: 2017-10-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
# No authors met the thresholds.
# No Best Authors Found for 2017-11
#
# ### get_best_authors_by_sector ###
# Start Date: 2016-11-30 00:00:00, End Date: 2017-11-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
# No authors met the thresholds.
# No Best Authors Found for 2017-12
#
# ### get_best_authors_by_sector ###
# Start Date: 2016-12-31 00:00:00, End Date: 2017-12-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
# No authors met the thresholds.
# No Best Authors Found for 2018-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2017-01-31 00:00:00, End Date: 2018-01-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
# No authors met the thresholds.
# No Best Authors Found for 2018-02
#
# ### get_best_authors_by_sector ###
# Start Date: 2017-02-28 00:00:00, End Date: 2018-02-28 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2018-03
# Monthly Performance for 2018-03:
#  Empty DataFrame
# Columns: [Sector, author, mean_performance, count, month]
# Index: []
#
# ### get_best_authors_by_sector ###
# Start Date: 2017-03-31 00:00:00, End Date: 2018-03-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2018-04
# Monthly Performance for 2018-04:
#  Empty DataFrame
# Columns: [Sector, author, mean_performance, count, month]
# Index: []
#
# ### get_best_authors_by_sector ###
# Start Date: 2017-04-30 00:00:00, End Date: 2018-04-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2018-05
# Monthly Performance for 2018-05:
#  Empty DataFrame
# Columns: [Sector, author, mean_performance, count, month]
# Index: []
#
# ### get_best_authors_by_sector ###
# Start Date: 2017-05-31 00:00:00, End Date: 2018-05-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2018-06
# Monthly Performance for 2018-06:
#  Empty DataFrame
# Columns: [Sector, author, mean_performance, count, month]
# Index: []
#
# ### get_best_authors_by_sector ###
# Start Date: 2017-06-30 00:00:00, End Date: 2018-06-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2018-07
# Monthly Performance for 2018-07:
#  Empty DataFrame
# Columns: [Sector, author, mean_performance, count, month]
# Index: []
#
# ### get_best_authors_by_sector ###
# Start Date: 2017-07-31 00:00:00, End Date: 2018-07-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2018-08
# Monthly Performance for 2018-08:
#  Empty DataFrame
# Columns: [Sector, author, mean_performance, count, month]
# Index: []
#
# ### get_best_authors_by_sector ###
# Start Date: 2017-08-31 00:00:00, End Date: 2018-08-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
# No authors met the thresholds.
# No Best Authors Found for 2018-09
#
# ### get_best_authors_by_sector ###
# Start Date: 2017-09-30 00:00:00, End Date: 2018-09-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
# No authors met the thresholds.
# No Best Authors Found for 2018-10
#
# ### get_best_authors_by_sector ###
# Start Date: 2017-10-31 00:00:00, End Date: 2018-10-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
# No authors met the thresholds.
# No Best Authors Found for 2018-11
#
# ### get_best_authors_by_sector ###
# Start Date: 2017-11-30 00:00:00, End Date: 2018-11-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
# No authors met the thresholds.
# No Best Authors Found for 2018-12
#
# ### get_best_authors_by_sector ###
# Start Date: 2017-12-31 00:00:00, End Date: 2018-12-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
# No authors met the thresholds.
# No Best Authors Found for 2019-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2018-01-31 00:00:00, End Date: 2019-01-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
# No authors met the thresholds.
# No Best Authors Found for 2019-02
#
# ### get_best_authors_by_sector ###
# Start Date: 2018-02-28 00:00:00, End Date: 2019-02-28 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
# No authors met the thresholds.
# No Best Authors Found for 2019-03
#
# ### get_best_authors_by_sector ###
# Start Date: 2018-03-31 00:00:00, End Date: 2019-03-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
# No authors met the thresholds.
# No Best Authors Found for 2019-04
#
# ### get_best_authors_by_sector ###
# Start Date: 2018-04-30 00:00:00, End Date: 2019-04-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
# No authors met the thresholds.
# No Best Authors Found for 2019-05
#
# ### get_best_authors_by_sector ###
# Start Date: 2018-05-31 00:00:00, End Date: 2019-05-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2019-06
# Monthly Performance for 2019-06:
#  Empty DataFrame
# Columns: [Sector, author, mean_performance, count, month]
# Index: []
#
# ### get_best_authors_by_sector ###
# Start Date: 2018-06-30 00:00:00, End Date: 2019-06-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2019-07
# Monthly Performance for 2019-07:
#  Empty DataFrame
# Columns: [Sector, author, mean_performance, count, month]
# Index: []
#
# ### get_best_authors_by_sector ###
# Start Date: 2018-07-31 00:00:00, End Date: 2019-07-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2019-08
# Monthly Performance for 2019-08:
#  Empty DataFrame
# Columns: [Sector, author, mean_performance, count, month]
# Index: []
#
# ### get_best_authors_by_sector ###
# Start Date: 2018-08-31 00:00:00, End Date: 2019-08-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2019-09
# Monthly Performance for 2019-09:
#  Empty DataFrame
# Columns: [Sector, author, mean_performance, count, month]
# Index: []
#
# ### get_best_authors_by_sector ###
# Start Date: 2018-09-30 00:00:00, End Date: 2019-09-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2019-10
# Monthly Performance for 2019-10:
#  Empty DataFrame
# Columns: [Sector, author, mean_performance, count, month]
# Index: []
#
# ### get_best_authors_by_sector ###
# Start Date: 2018-10-31 00:00:00, End Date: 2019-10-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
# No authors met the thresholds.
# No Best Authors Found for 2019-11
#
# ### get_best_authors_by_sector ###
# Start Date: 2018-11-30 00:00:00, End Date: 2019-11-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
# No authors met the thresholds.
# No Best Authors Found for 2019-12
#
# ### get_best_authors_by_sector ###
# Start Date: 2018-12-31 00:00:00, End Date: 2019-12-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
# No authors met the thresholds.
# No Best Authors Found for 2020-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2019-01-31 00:00:00, End Date: 2020-01-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
# No authors met the thresholds.
# No Best Authors Found for 2020-02
#
# ### get_best_authors_by_sector ###
# Start Date: 2019-02-28 00:00:00, End Date: 2020-02-29 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
# No authors met the thresholds.
# No Best Authors Found for 2020-03
#
# ### get_best_authors_by_sector ###
# Start Date: 2019-03-31 00:00:00, End Date: 2020-03-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
# No authors met the thresholds.
# No Best Authors Found for 2020-04
#
# ### get_best_authors_by_sector ###
# Start Date: 2019-04-30 00:00:00, End Date: 2020-04-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
# No authors met the thresholds.
# No Best Authors Found for 2020-05
#
# ### get_best_authors_by_sector ###
# Start Date: 2019-05-31 00:00:00, End Date: 2020-05-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2020-06
# Monthly Performance for 2020-06:
#            Sector               author  mean_performance  count      month
# 0  Manufacturing       Yes Securities          0.009173      4 2020-06-01
# 1      Utilities        Motilal Oswal          0.020423      1 2020-06-01
# 2      Utilities  Prabhudas Lilladhar          0.020423      1 2020-06-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2019-06-30 00:00:00, End Date: 2020-06-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2020-07
# Monthly Performance for 2020-07:
#  Empty DataFrame
# Columns: [Sector, author, mean_performance, count, month]
# Index: []
#
# ### get_best_authors_by_sector ###
# Start Date: 2019-07-31 00:00:00, End Date: 2020-07-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2020-08
# Monthly Performance for 2020-08:
#        Sector               author  mean_performance  count      month
# 0  Utilities  Prabhudas Lilladhar          0.078445      1 2020-08-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2019-08-31 00:00:00, End Date: 2020-08-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2020-09
# Monthly Performance for 2020-09:
#  Empty DataFrame
# Columns: [Sector, author, mean_performance, count, month]
# Index: []
#
# ### get_best_authors_by_sector ###
# Start Date: 2019-09-30 00:00:00, End Date: 2020-09-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2020-10
# Monthly Performance for 2020-10:
#  Empty DataFrame
# Columns: [Sector, author, mean_performance, count, month]
# Index: []
#
# ### get_best_authors_by_sector ###
# Start Date: 2019-10-31 00:00:00, End Date: 2020-10-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2020-11
# Monthly Performance for 2020-11:
#  Empty DataFrame
# Columns: [Sector, author, mean_performance, count, month]
# Index: []
#
# ### get_best_authors_by_sector ###
# Start Date: 2019-11-30 00:00:00, End Date: 2020-11-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2020-12
# Monthly Performance for 2020-12:
#  Empty DataFrame
# Columns: [Sector, author, mean_performance, count, month]
# Index: []
#
# ### get_best_authors_by_sector ###
# Start Date: 2019-12-31 00:00:00, End Date: 2020-12-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2021-01
# Monthly Performance for 2021-01:
#            Sector         author  mean_performance  count      month
# 0  Manufacturing  Motilal Oswal          0.027249      8 2021-01-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2020-01-31 00:00:00, End Date: 2021-01-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2021-02
# Monthly Performance for 2021-02:
#            Sector               author  mean_performance  count      month
# 0  Manufacturing        Motilal Oswal          0.001599     12 2021-02-01
# 1      Utilities  Prabhudas Lilladhar          0.010854      1 2021-02-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2020-02-28 00:00:00, End Date: 2021-02-28 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2021-03
# Monthly Performance for 2021-03:
#            Sector         author  mean_performance  count      month
# 0  Manufacturing  Motilal Oswal          0.029894      4 2021-03-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2020-03-31 00:00:00, End Date: 2021-03-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2021-04
# Monthly Performance for 2021-04:
#            Sector         author  mean_performance  count      month
# 0  Manufacturing  Motilal Oswal          0.092172      2 2021-04-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2020-04-30 00:00:00, End Date: 2021-04-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2021-05
# Monthly Performance for 2021-05:
#            Sector         author  mean_performance  count      month
# 0  Manufacturing  Motilal Oswal          0.004469     15 2021-05-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2020-05-31 00:00:00, End Date: 2021-05-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2021-06
# Monthly Performance for 2021-06:
#            Sector         author  mean_performance  count      month
# 0  Manufacturing  Motilal Oswal         -0.000373      7 2021-06-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2020-06-30 00:00:00, End Date: 2021-06-30 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2021-07
# Monthly Performance for 2021-07:
#            Sector         author  mean_performance  count      month
# 0  Manufacturing  Motilal Oswal          0.007591      6 2021-07-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2020-07-31 00:00:00, End Date: 2021-07-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1
#
# Calculating monthly performance for: 2021-08
# Monthly Performance for 2021-08:
#            Sector         author  mean_performance  count      month
# 0  Manufacturing  Motilal Oswal         -0.015621     13 2021-08-01
#
# ### get_best_authors_by_sector ###
# Start Date: 2020-08-31 00:00:00, End Date: 2021-08-31 00:00:00
# Max Authors per Sector: 10, Correlation Threshold: 0.0, Performance Threshold: 0.1

# %%
grid_performance_df

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_heatmap(grid_performance_df):
    # Pivot the data to prepare for the heatmap
    heatmap_data = grid_performance_df.pivot(
        index='correlation_threshold', 
        columns='performance_threshold', 
        values='mean_of_mean_performance'
    )
    
    # Plot the heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(
        heatmap_data, 
        annot=True, 
        fmt=".4f", 
        cmap="coolwarm", 
        cbar_kws={'label': 'Average Performance'}
    )
    plt.title('Grid Search Heatmap of Performance')
    plt.xlabel('Performance Threshold')
    plt.ylabel('Correlation Threshold')
    plt.savefig("performance_heatmap.png")
    plt.show()

# Assuming grid_performance_df is already created
plot_heatmap(grid_performance_df)

# %%
results_df
